# %% [markdown]
# ## 1. Load the data

# %%
import pandas as pd

# Format scientific notation from Pandas
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_columns', None)

INPUT_CSV = "/home/sramkova/diploma_thesis_data/pca_with_labels_backup_16_10_2021_9b.csv"

data = pd.read_csv(INPUT_CSV, low_memory=False)
df = data.copy()
df.head(5)
# Out:
#    originated_ip_num  responded_ip_num  connection.time  connection.duration  \
# 0            0.04572           0.04754          0.00936              0.00405
# 1            0.04572           0.25924          0.18505              0.00000
# 2            0.04567           0.01362          0.13157              0.00006
# 3            0.02044           0.03237          0.76812              0.00000
# 4            0.02044           0.03237          0.76715              0.00000
#
#    connection.orig_bytes  connection.orig_pkts  connection.orig_ip_bytes  \
# 0                0.00000               0.00003                   0.00001
# 1                0.00000               0.00001                   0.00000
# 2                0.00000               0.00003                   0.00001
# 3                0.00000               0.00001                   0.00000
# 4                0.00000               0.00001                   0.00000
#
#    connection.resp_bytes  connection.resp_pkts  connection.resp_ip_bytes  \
# 0                0.00001               0.00004                   0.00001
# 1                0.00000               0.00002                   0.00000
# 2                0.00000               0.00004                   0.00001
# 3                0.00000               0.00000                   0.00000
# 4                0.00000               0.00000                   0.00000
#
#         orig_p_cat       resp_p_cat protocol service conn_state  dns_count  \
# 0  orig_reg_or_dyn          resp_80      tcp    http         SF    0.00000
# 1  orig_reg_or_dyn          resp_80      tcp    none     RSTOS0    0.00000
# 2  orig_reg_or_dyn          resp_80      tcp    http       RSTO    0.00000
# 3  orig_reg_or_dyn         resp_reg      tcp    none         S0    0.00000
# 4  orig_reg_or_dyn  resp_well_known      tcp    none         S0    0.00000
#
#    ssh_count  http_count  ssl_count  files_count  orig_orig_total  \
# 0    0.00000     1.00000    0.00000      0.00781          0.00955
# 1    0.00000     0.00000    0.00000      0.00000          0.03799
# 2    0.00000     1.00000    0.00000      0.00781          0.00131
# 3    0.00000     0.00000    0.00000      0.00000          0.33491
# 4    0.00000     0.00000    0.00000      0.00000          0.24313
#
#    orig_orig_connection.time_mean  orig_orig_connection.duration_mean  \
# 0                         0.00934                             0.00235
# 1                         0.17812                             0.00031
# 2                         0.12727                             0.00030
# 3                         0.77773                             0.00019
# 4                         0.77720                             0.00010
#
#    orig_orig_connection.orig_pkts_mean  orig_orig_connection.orig_bytes_mean  \
# 0                              0.00043                               0.00012
# 1                              0.00154                               0.00004
# 2                              0.00041                               0.00001
# 3                              0.00003                               0.00000
# 4                              0.00003                               0.00000
#
#    orig_orig_connection.resp_bytes_mean  orig_orig_connection.resp_pkts_mean  \
# 0                               0.00077                              0.00018
# 1                               0.00663                              0.00060
# 2                               0.00092                              0.00012
# 3                               0.00000                              0.00001
# 4                               0.00000                              0.00001
#
#    orig_orig_orig_p_well_known_count  orig_orig_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.00962
# 1                            0.00000                            0.03806
# 2                            0.00000                            0.00137
# 3                            0.00000                            0.33496
# 4                            0.00000                            0.24318
#
#    orig_orig_resp_p_21_count  orig_orig_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.27778                    0.00125
# 4                    0.27778                    0.00103
#
#    orig_orig_resp_p_53_count  orig_orig_resp_p_80_count  \
# 0                    0.01273                    0.00251
# 1                    0.02629                    0.04960
# 2                    0.00000                    0.00116
# 3                    0.00125                    0.00116
# 4                    0.00125                    0.00116
#
#    orig_orig_resp_p_123_count  orig_orig_resp_p_443_count  \
# 0                     0.00000                     0.00891
# 1                     0.00000                     0.02309
# 2                     0.00000                     0.00189
# 3                     0.00000                     0.00068
# 4                     0.00000                     0.00068
#
#    orig_orig_resp_p_3389_count  orig_orig_resp_p_well_known_count  \
# 0                      0.00000                            0.00000
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.00000
# 3                      0.25000                            0.34864
# 4                      0.25000                            0.21416
#
#    orig_orig_resp_p_reg_count  orig_orig_resp_p_dyn_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.32136                     0.30378
# 4                     0.24717                     0.22816
#
#    orig_orig_dns_count_mean  orig_orig_ssh_count_mean  \
# 0                   0.43571                   0.00000
# 1                   0.22744                   0.00000
# 2                   0.00000                   0.00000
# 3                   0.00000                   0.00000
# 4                   0.00000                   0.00000
#
#    orig_orig_http_count_mean  orig_orig_ssl_count_mean  \
# 0                    0.08571                   0.47143
# 1                    0.45126                   0.29422
# 2                    0.30000                   0.70000
# 3                    0.00000                   0.14274
# 4                    0.00000                   0.08955
#
#    orig_orig_files_count_mean  orig_orig_similar_conns_count  \
# 0                     0.02321                        0.00000
# 1                     0.02098                        0.00000
# 2                     0.02083                        0.00000
# 3                     0.00081                        0.00000
# 4                     0.00081                        0.00000
#
#    orig_orig_similar_dns_qtype_count  orig_orig_similar_dns_rcode_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.00000                            0.00000
# 4                            0.00000                            0.00000
#
#    orig_orig_similar_ssh_auth_attempts_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
#
#    orig_orig_similar_ssh_host_key_count  orig_orig_similar_http_method_count  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00000
# 4                               0.00000                              0.00000
#
#    orig_orig_similar_http_status_code_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
#
#    orig_orig_similar_http_user_agent_count  \
# 0                                  0.00000
# 1                                  0.00000
# 2                                  0.00000
# 3                                  0.00000
# 4                                  0.00000
#
#    orig_orig_similar_ssl_version_count  orig_orig_similar_ssl_cipher_count  \
# 0                              0.00000                             0.00000
# 1                              0.00000                             0.00000
# 2                              0.00000                             0.00000
# 3                              0.00000                             0.00000
# 4                              0.00000                             0.00000
#
#    orig_orig_similar_ssl_curve_count  \
# 0                            0.00000
# 1                            0.00000
# 2                            0.00000
# 3                            0.00000
# 4                            0.00000
#
#    orig_orig_similar_ssl_validation_status_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
#
#    orig_orig_similar_files_source_count  orig_orig_similar_file_md5_count  \
# 0                               0.00000                           0.00000
# 1                               0.00000                           0.00000
# 2                               0.00000                           0.00000
# 3                               0.00000                           0.00000
# 4                               0.00000                           0.00000
#
#   orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# 0                                tcp                               ssl
# 1                                tcp                              http
# 2                                tcp                               ssl
# 3                                tcp                              none
# 4                                tcp                              none
#
#   orig_orig_connection.conn_state_mode  orig_resp_total  \
# 0                                   SF          0.00000
# 1                                   SF          0.00000
# 2                                 RSTO          0.00000
# 3                                   S0          0.00015
# 4                                   S0          0.00015
#
#    orig_resp_connection.time_mean  orig_resp_connection.duration_mean  \
# 0                         0.00903                             0.00000
# 1                         0.17854                             0.00000
# 2                         0.12694                             0.00000
# 3                         0.77511                             0.00000
# 4                         0.77511                             0.00000
#
#    orig_resp_connection.orig_pkts_mean  orig_resp_connection.orig_bytes_mean  \
# 0                              0.00000                               0.00000
# 1                              0.00000                               0.00000
# 2                              0.00000                               0.00000
# 3                              0.00003                               0.00000
# 4                              0.00003                               0.00000
#
#    orig_resp_connection.resp_bytes_mean  orig_resp_connection.resp_pkts_mean  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00002
# 4                               0.00000                              0.00002
#
#    orig_resp_orig_p_well_known_count  orig_resp_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.03333                            0.00000
# 4                            0.03333                            0.00000
#
#    orig_resp_resp_p_21_count  orig_resp_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00000
#
#    orig_resp_resp_p_53_count  orig_resp_resp_p_80_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00000
#
#    orig_resp_resp_p_123_count  orig_resp_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.00000                     0.00000
# 4                     0.00000                     0.00000
#
#    orig_resp_resp_p_3389_count  orig_resp_resp_p_well_known_count  \
# 0                      0.00000                            0.00000
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.00000
# 3                      0.00000                            0.00000
# 4                      0.00000                            0.00000
#
#    orig_resp_resp_p_reg_count  orig_resp_resp_p_dyn_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.00032                     0.00000
# 4                     0.00032                     0.00000
#
#    orig_resp_dns_count_mean  orig_resp_ssh_count_mean  \
# 0                   0.00000                   0.00000
# 1                   0.00000                   0.00000
# 2                   0.00000                   0.00000
# 3                   0.00000                   0.00000
# 4                   0.00000                   0.00000
#
#    orig_resp_http_count_mean  orig_resp_ssl_count_mean  \
# 0                    0.00000                   0.00000
# 1                    0.00000                   0.00000
# 2                    0.00000                   0.00000
# 3                    0.00000                   0.00000
# 4                    0.00000                   0.00000
#
#    orig_resp_files_count_mean  orig_resp_similar_conns_count  \
# 0                     0.00000                        0.00000
# 1                     0.00000                        0.00000
# 2                     0.00000                        0.00000
# 3                     0.00000                        0.00000
# 4                     0.00000                        0.00000
#
#    orig_resp_similar_dns_qtype_count  orig_resp_similar_dns_rcode_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.00000                            0.00000
# 4                            0.00000                            0.00000
#
#    orig_resp_similar_ssh_auth_attempts_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
#
#    orig_resp_similar_ssh_host_key_count  orig_resp_similar_http_method_count  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00000
# 4                               0.00000                              0.00000
#
#    orig_resp_similar_http_status_code_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
#
#    orig_resp_similar_http_user_agent_count  \
# 0                                  0.00000
# 1                                  0.00000
# 2                                  0.00000
# 3                                  0.00000
# 4                                  0.00000
#
#    orig_resp_similar_ssl_version_count  orig_resp_similar_ssl_cipher_count  \
# 0                              0.00000                             0.00000
# 1                              0.00000                             0.00000
# 2                              0.00000                             0.00000
# 3                              0.00000                             0.00000
# 4                              0.00000                             0.00000
#
#    orig_resp_similar_ssl_curve_count  \
# 0                            0.00000
# 1                            0.00000
# 2                            0.00000
# 3                            0.00000
# 4                            0.00000
#
#    orig_resp_similar_ssl_validation_status_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
#
#    orig_resp_similar_files_source_count  orig_resp_similar_file_md5_count  \
# 0                               0.00000                           0.00000
# 1                               0.00000                           0.00000
# 2                               0.00000                           0.00000
# 3                               0.00000                           0.00000
# 4                               0.00000                           0.00000
#
#   orig_resp_connection.protocol_mode orig_resp_connection.service_mode  \
# 0                                  -                                 -
# 1                                  -                                 -
# 2                                  -                                 -
# 3                                tcp                              none
# 4                                tcp                              none
#
#   orig_resp_connection.conn_state_mode  resp_orig_total  \
# 0                                    -          0.00000
# 1                                    -          0.00000
# 2                                    -          0.00000
# 3                                  REJ          0.00034
# 4                                  REJ          0.00042
#
#    resp_orig_connection.time_mean  resp_orig_connection.duration_mean  \
# 0                         0.00903                             0.00000
# 1                         0.17854                             0.00000
# 2                         0.12694                             0.00000
# 3                         0.77578                             0.00000
# 4                         0.77512                             0.00000
#
#    resp_orig_connection.orig_pkts_mean  resp_orig_connection.orig_bytes_mean  \
# 0                              0.00000                               0.00000
# 1                              0.00000                               0.00000
# 2                              0.00000                               0.00000
# 3                              0.00002                               0.00000
# 4                              0.00002                               0.00000
#
#    resp_orig_connection.resp_bytes_mean  resp_orig_connection.resp_pkts_mean  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00001
# 4                               0.00000                              0.00001
#
#    resp_orig_orig_p_well_known_count  resp_orig_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.00478                            0.00025
# 4                            0.00478                            0.00034
#
#    resp_orig_resp_p_21_count  resp_orig_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00000
#
#    resp_orig_resp_p_53_count  resp_orig_resp_p_80_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00063                    0.00000
# 4                    0.00084                    0.00000
#
#    resp_orig_resp_p_123_count  resp_orig_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.00000                     0.00000
# 4                     0.00000                     0.00000
#
#    resp_orig_resp_p_3389_count  resp_orig_resp_p_well_known_count  \
# 0                      0.00000                            0.00000
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.00000
# 3                      0.00000                            0.00000
# 4                      0.00000                            0.00000
#
#    resp_orig_resp_p_reg_count  resp_orig_resp_p_dyn_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.00011                     0.00000
# 4                     0.00011                     0.00000
#
#    resp_orig_dns_count_mean  resp_orig_ssh_count_mean  \
# 0                   0.00000                   0.00000
# 1                   0.00000                   0.00000
# 2                   0.00000                   0.00000
# 3                   0.75000                   0.00000
# 4                   0.80000                   0.00000
#
#    resp_orig_http_count_mean  resp_orig_ssl_count_mean  \
# 0                    0.00000                   0.00000
# 1                    0.00000                   0.00000
# 2                    0.00000                   0.00000
# 3                    0.00000                   0.00000
# 4                    0.00000                   0.00000
#
#    resp_orig_files_count_mean  resp_orig_similar_conns_count  \
# 0                     0.00000                        0.00000
# 1                     0.00000                        0.00000
# 2                     0.00000                        0.00000
# 3                     0.00000                        0.00000
# 4                     0.00000                        0.00000
#
#    resp_orig_similar_dns_qtype_count  resp_orig_similar_dns_rcode_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.00000                            0.00000
# 4                            0.00000                            0.00000
#
#    resp_orig_similar_ssh_auth_attempts_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
#
#    resp_orig_similar_ssh_host_key_count  resp_orig_similar_http_method_count  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00000
# 4                               0.00000                              0.00000
#
#    resp_orig_similar_http_status_code_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
#
#    resp_orig_similar_http_user_agent_count  \
# 0                                  0.00000
# 1                                  0.00000
# 2                                  0.00000
# 3                                  0.00000
# 4                                  0.00000
#
#    resp_orig_similar_ssl_version_count  resp_orig_similar_ssl_cipher_count  \
# 0                              0.00000                             0.00000
# 1                              0.00000                             0.00000
# 2                              0.00000                             0.00000
# 3                              0.00000                             0.00000
# 4                              0.00000                             0.00000
#
#    resp_orig_similar_ssl_curve_count  \
# 0                            0.00000
# 1                            0.00000
# 2                            0.00000
# 3                            0.00000
# 4                            0.00000
#
#    resp_orig_similar_ssl_validation_status_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
#
#    resp_orig_similar_files_source_count  resp_orig_similar_file_md5_count  \
# 0                               0.00000                           0.00000
# 1                               0.00000                           0.00000
# 2                               0.00000                           0.00000
# 3                               0.00000                           0.00000
# 4                               0.00000                           0.00000
#
#   resp_orig_connection.protocol_mode resp_orig_connection.service_mode  \
# 0                                  -                                 -
# 1                                  -                                 -
# 2                                  -                                 -
# 3                                udp                               dns
# 4                                udp                               dns
#
#   resp_orig_connection.conn_state_mode  resp_resp_total  \
# 0                                    -          0.00000
# 1                                    -          0.00037
# 2                                    -          0.03716
# 3                                   SF          0.10058
# 4                                   SF          0.06022
#
#    resp_resp_connection.time_mean  resp_resp_connection.duration_mean  \
# 0                         0.00903                             0.00486
# 1                         0.17820                             0.00001
# 2                         0.12677                             0.00003
# 3                         0.77639                             0.00000
# 4                         0.77585                             0.00000
#
#    resp_resp_connection.orig_pkts_mean  resp_resp_connection.orig_bytes_mean  \
# 0                              0.00008                               0.00000
# 1                              0.00062                               0.00000
# 2                              0.00029                               0.00000
# 3                              0.00001                               0.00000
# 4                              0.00002                               0.00000
#
#    resp_resp_connection.resp_bytes_mean  resp_resp_connection.resp_pkts_mean  \
# 0                               0.00001                              0.00004
# 1                               0.00082                              0.00030
# 2                               0.00021                              0.00015
# 3                               0.00000                              0.00000
# 4                               0.00000                              0.00000
#
#    resp_resp_orig_p_well_known_count  resp_resp_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.00012
# 1                            0.00000                            0.00049
# 2                            0.64516                            0.03483
# 3                            0.00000                            0.10069
# 4                            0.00000                            0.06034
#
#    resp_resp_resp_p_21_count  resp_resp_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.16667                    0.00100
# 4                    0.16667                    0.00100
#
#    resp_resp_resp_p_53_count  resp_resp_resp_p_80_count  \
# 0                    0.00000                    0.00028
# 1                    0.00000                    0.00114
# 2                    0.00000                    0.02707
# 3                    0.00188                    0.00000
# 4                    0.00188                    0.00085
#
#    resp_resp_resp_p_123_count  resp_resp_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.02797
# 3                     0.00000                     0.00030
# 4                     0.00000                     0.00044
#
#    resp_resp_resp_p_3389_count  resp_resp_resp_p_well_known_count  \
# 0                      0.00000                            0.00000
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.01241
# 3                      0.20000                            0.08747
# 4                      0.20000                            0.06328
#
#    resp_resp_resp_p_reg_count  resp_resp_resp_p_dyn_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.20000                     0.11782
# 4                     0.11143                     0.07471
#
#    resp_resp_dns_count_mean  resp_resp_ssh_count_mean  \
# 0                   0.00000                   0.00000
# 1                   0.00000                   0.00000
# 2                   0.00000                   0.00000
# 3                   0.00000                   0.00000
# 4                   0.00000                   0.00000
#
#    resp_resp_http_count_mean  resp_resp_ssl_count_mean  \
# 0                    1.00000                   0.00000
# 1                    0.75000                   0.00000
# 2                    0.31250                   0.59539
# 3                    0.00000                   0.00000
# 4                    0.00203                   0.00203
#
#    resp_resp_files_count_mean  resp_resp_similar_conns_count  \
# 0                     0.00781                        0.00000
# 1                     0.00195                        0.00000
# 2                     0.00691                        0.00000
# 3                     0.00000                        0.00000
# 4                     0.00003                        0.00000
#
#    resp_resp_similar_dns_qtype_count  resp_resp_similar_dns_rcode_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.00000                            0.00000
# 4                            0.00000                            0.00000
#
#    resp_resp_similar_ssh_auth_attempts_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
#
#    resp_resp_similar_ssh_host_key_count  resp_resp_similar_http_method_count  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00000
# 4                               0.00000                              0.00000
#
#    resp_resp_similar_http_status_code_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
#
#    resp_resp_similar_http_user_agent_count  \
# 0                                  0.00000
# 1                                  0.00000
# 2                                  0.00000
# 3                                  0.00000
# 4                                  0.00000
#
#    resp_resp_similar_ssl_version_count  resp_resp_similar_ssl_cipher_count  \
# 0                              0.00000                             0.00000
# 1                              0.00000                             0.00000
# 2                              0.00000                             0.00000
# 3                              0.00000                             0.00000
# 4                              0.00000                             0.00000
#
#    resp_resp_similar_ssl_curve_count  \
# 0                            0.00000
# 1                            0.00000
# 2                            0.00000
# 3                            0.00000
# 4                            0.00000
#
#    resp_resp_similar_ssl_validation_status_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
#
#    resp_resp_similar_files_source_count  resp_resp_similar_file_md5_count  \
# 0                               0.00000                           0.00000
# 1                               0.00000                           0.00000
# 2                               0.00000                           0.00000
# 3                               0.00000                           0.00000
# 4                               0.00000                           0.00000
#
#   resp_resp_connection.protocol_mode resp_resp_connection.service_mode  \
# 0                                tcp                              http
# 1                                tcp                              http
# 2                                tcp                               ssl
# 3                                tcp                              none
# 4                                tcp                              none
#
#   resp_resp_connection.conn_state_mode  cluster  cluster_cat
# 0                                   SF        3            3
# 1                                 RSTO        3            3
# 2                                 RSTO        3            3
# 3                                   S0        1            1
# 4                                   S0        1            1

# %%
GAMMA = 0.08900004897193284

# %%
df = df.sample(1000)

# %%
# (groupby works only on category type)
df['cluster_cat'] = df['cluster_cat'].astype('category')

# %%
# Columns names as constant lists for easier usage:

# columns that contain values of the current main connection
CONN_IDS_COLS = ['connection.uid', 'originated_ip', 'responded_ip']

CONN_NUMERICAL_COLS = ['originated_ip_num', 
                       'responded_ip_num',
                       'connection.time', 
                       'connection.duration', 
                       # originator details
                       # 'connection.orig_p', 
                       'connection.orig_bytes', 
                       'connection.orig_pkts', 
                       'connection.orig_ip_bytes', 
                       # responder details
                       # 'connection.resp_p', 
                       'connection.resp_bytes', 
                       'connection.resp_pkts',
                       'connection.resp_ip_bytes']

CONN_CATEGORICAL_COLS = ['connection.proto', 
                         'connection.service', 
                         'connection.conn_state']

CONN_APP_STATS = ['dns_count', 'ssh_count', 'http_count', 'ssl_count', 'files_count']

# originator originated neighbrouhood columns:
ORIG_ORIG_NUMERICAL_COLS = ['orig_orig_total', 
                            'orig_orig_connection.time_mean', 
                            'orig_orig_connection.duration_mean',
                            # 'orig_orig_connection.orig_p_mean', 
                            'orig_orig_connection.orig_pkts_mean',
                            'orig_orig_connection.orig_bytes_mean',
                            # 'orig_orig_connection.resp_p_mean', 
                            'orig_orig_connection.resp_bytes_mean',
                            'orig_orig_connection.resp_pkts_mean']
                            
ORIG_ORIG_CATEGORICAL_COLS = ['orig_orig_connection.protocol_mode', 
                              'orig_orig_connection.service_mode', 
                              'orig_orig_connection.conn_state_mode']

ORIG_ORIG_PORTS_COLS = ['orig_orig_orig_p_well_known_count', 
                        'orig_orig_orig_p_reg_or_dyn_count', 
                        'orig_orig_resp_p_21_count', 
                        'orig_orig_resp_p_22_count',
                        'orig_orig_resp_p_53_count', 
                        'orig_orig_resp_p_80_count', 
                        'orig_orig_resp_p_123_count', 
                        'orig_orig_resp_p_443_count', 
                        'orig_orig_resp_p_3389_count',
                        'orig_orig_resp_p_well_known_count', 
                        'orig_orig_resp_p_reg_count', 
                        'orig_orig_resp_p_dyn_count']

ORIG_ORIG_APP_STATS_COLS = ['orig_orig_dns_count_mean', 
                            'orig_orig_ssh_count_mean', 
                            'orig_orig_http_count_mean', 
                            'orig_orig_ssl_count_mean', 
                            'orig_orig_files_count_mean']

ORIG_ORIG_SIMILAR_COLS = ['orig_orig_similar_conns_count',
                          'orig_orig_similar_dns_qtype_count', 
                          'orig_orig_similar_dns_rcode_count', 
                          'orig_orig_similar_ssh_auth_attempts_count', 
                          'orig_orig_similar_ssh_host_key_count', 
                          'orig_orig_similar_http_method_count',
                          'orig_orig_similar_http_status_code_count', 
                          'orig_orig_similar_http_user_agent_count',
                          'orig_orig_similar_ssl_version_count', 
                          'orig_orig_similar_ssl_cipher_count', 
                          'orig_orig_similar_ssl_curve_count',
                          'orig_orig_similar_ssl_validation_status_count', 
                          'orig_orig_similar_files_source_count', 
                          'orig_orig_similar_file_md5_count']

# originator responded neighbrouhood columns:
ORIG_RESP_NUMERICAL_COLS = ['orig_resp_total', 
                            'orig_resp_connection.time_mean', 
                            'orig_resp_connection.duration_mean',
                            # 'orig_resp_connection.orig_p_mean', 
                            'orig_resp_connection.orig_pkts_mean',
                            'orig_resp_connection.orig_bytes_mean',
                            # 'orig_resp_connection.resp_p_mean', 
                            'orig_resp_connection.resp_bytes_mean',
                            'orig_resp_connection.resp_pkts_mean']
                            
ORIG_RESP_CATEGORICAL_COLS = ['orig_resp_connection.protocol_mode', 
                              'orig_resp_connection.service_mode', 
                              'orig_resp_connection.conn_state_mode']

ORIG_RESP_PORTS_COLS = ['orig_resp_orig_p_well_known_count', 
                        'orig_resp_orig_p_reg_or_dyn_count', 
                        'orig_resp_resp_p_21_count', 
                        'orig_resp_resp_p_22_count',
                        'orig_resp_resp_p_53_count', 
                        'orig_resp_resp_p_80_count', 
                        'orig_resp_resp_p_123_count', 
                        'orig_resp_resp_p_443_count', 
                        'orig_resp_resp_p_3389_count',
                        'orig_resp_resp_p_well_known_count', 
                        'orig_resp_resp_p_reg_count', 
                        'orig_resp_resp_p_dyn_count']

ORIG_RESP_APP_STATS_COLS = ['orig_resp_dns_count_mean', 
                            'orig_resp_ssh_count_mean', 
                            'orig_resp_http_count_mean', 
                            'orig_resp_ssl_count_mean', 
                            'orig_resp_files_count_mean']

ORIG_RESP_SIMILAR_COLS = ['orig_resp_similar_conns_count',
                          'orig_resp_similar_dns_qtype_count', 
                          'orig_resp_similar_dns_rcode_count', 
                          'orig_resp_similar_ssh_auth_attempts_count', 
                          'orig_resp_similar_ssh_host_key_count', 
                          'orig_resp_similar_http_method_count',
                          'orig_resp_similar_http_status_code_count', 
                          'orig_resp_similar_http_user_agent_count',
                          'orig_resp_similar_ssl_version_count', 
                          'orig_resp_similar_ssl_cipher_count', 
                          'orig_resp_similar_ssl_curve_count',
                          'orig_resp_similar_ssl_validation_status_count', 
                          'orig_resp_similar_files_source_count', 
                          'orig_resp_similar_file_md5_count']

# responder originated neighbrouhood columns:
RESP_ORIG_NUMERICAL_COLS = ['resp_orig_total', 
                            'resp_orig_connection.time_mean', 
                            'resp_orig_connection.duration_mean',
                            # 'resp_orig_connection.orig_p_mean', 
                            'resp_orig_connection.orig_pkts_mean',
                            'resp_orig_connection.orig_bytes_mean',
                            # 'resp_orig_connection.resp_p_mean', 
                            'resp_orig_connection.resp_bytes_mean',
                            'resp_orig_connection.resp_pkts_mean']
                            
RESP_ORIG_CATEGORICAL_COLS = ['resp_orig_connection.protocol_mode', 
                              'resp_orig_connection.service_mode', 
                              'resp_orig_connection.conn_state_mode']

RESP_ORIG_PORTS_COLS = ['resp_orig_orig_p_well_known_count', 
                        'resp_orig_orig_p_reg_or_dyn_count', 
                        'resp_orig_resp_p_21_count', 
                        'resp_orig_resp_p_22_count',
                        'resp_orig_resp_p_53_count', 
                        'resp_orig_resp_p_80_count', 
                        'resp_orig_resp_p_123_count', 
                        'resp_orig_resp_p_443_count', 
                        'resp_orig_resp_p_3389_count',
                        'resp_orig_resp_p_well_known_count', 
                        'resp_orig_resp_p_reg_count', 
                        'resp_orig_resp_p_dyn_count']

RESP_ORIG_APP_STATS_COLS = ['resp_orig_dns_count_mean', 
                            'resp_orig_ssh_count_mean', 
                            'resp_orig_http_count_mean', 
                            'resp_orig_ssl_count_mean', 
                            'resp_orig_files_count_mean']

RESP_ORIG_SIMILAR_COLS = ['resp_orig_similar_conns_count',
                          'resp_orig_similar_dns_qtype_count', 
                          'resp_orig_similar_dns_rcode_count', 
                          'resp_orig_similar_ssh_auth_attempts_count', 
                          'resp_orig_similar_ssh_host_key_count', 
                          'resp_orig_similar_http_method_count',
                          'resp_orig_similar_http_status_code_count', 
                          'resp_orig_similar_http_user_agent_count',
                          'resp_orig_similar_ssl_version_count', 
                          'resp_orig_similar_ssl_cipher_count', 
                          'resp_orig_similar_ssl_curve_count',
                          'resp_orig_similar_ssl_validation_status_count', 
                          'resp_orig_similar_files_source_count', 
                          'resp_orig_similar_file_md5_count']

# responder responded neighbrouhood columns:
RESP_RESP_NUMERICAL_COLS = ['resp_resp_total', 
                            'resp_resp_connection.time_mean', 
                            'resp_resp_connection.duration_mean',
                            # 'resp_resp_connection.orig_p_mean', 
                            'resp_resp_connection.orig_pkts_mean',
                            'resp_resp_connection.orig_bytes_mean',
                            # 'resp_resp_connection.resp_p_mean', 
                            'resp_resp_connection.resp_bytes_mean',
                            'resp_resp_connection.resp_pkts_mean']
                            
RESP_RESP_CATEGORICAL_COLS = ['resp_resp_connection.protocol_mode', 
                              'resp_resp_connection.service_mode', 
                              'resp_resp_connection.conn_state_mode']

RESP_RESP_PORTS_COLS = ['resp_resp_orig_p_well_known_count', 
                        'resp_resp_orig_p_reg_or_dyn_count', 
                        'resp_resp_resp_p_21_count', 
                        'resp_resp_resp_p_22_count',
                        'resp_resp_resp_p_53_count', 
                        'resp_resp_resp_p_80_count', 
                        'resp_resp_resp_p_123_count', 
                        'resp_resp_resp_p_443_count', 
                        'resp_resp_resp_p_3389_count',
                        'resp_resp_resp_p_well_known_count', 
                        'resp_resp_resp_p_reg_count', 
                        'resp_resp_resp_p_dyn_count']

RESP_RESP_APP_STATS_COLS = ['resp_resp_dns_count_mean', 
                            'resp_resp_ssh_count_mean', 
                            'resp_resp_http_count_mean', 
                            'resp_resp_ssl_count_mean', 
                            'resp_resp_files_count_mean']

RESP_RESP_SIMILAR_COLS = ['resp_resp_similar_conns_count',
                          'resp_resp_similar_dns_qtype_count', 
                          'resp_resp_similar_dns_rcode_count', 
                          'resp_resp_similar_ssh_auth_attempts_count', 
                          'resp_resp_similar_ssh_host_key_count', 
                          'resp_resp_similar_http_method_count',
                          'resp_resp_similar_http_status_code_count', 
                          'resp_resp_similar_http_user_agent_count',
                          'resp_resp_similar_ssl_version_count', 
                          'resp_resp_similar_ssl_cipher_count', 
                          'resp_resp_similar_ssl_curve_count',
                          'resp_resp_similar_ssl_validation_status_count', 
                          'resp_resp_similar_files_source_count', 
                          'resp_resp_similar_file_md5_count']

# labels and time in different format:
BACKUP_COLS = ['attacker_label', 'attack_label', 'connection.ts']

# OHE categories of original connection:
OHE_ORIG_P_CAT_COLS = ['orig_p_cat_orig_reg_or_dyn', 
                       'orig_p_cat_orig_well_known']

OHE_RESP_P_CAT_COLS = ['resp_p_cat_resp_123', 
                       'resp_p_cat_resp_21', 
                       'resp_p_cat_resp_22',
                       'resp_p_cat_resp_3389', 
                       'resp_p_cat_resp_443', 
                       'resp_p_cat_resp_53',
                       'resp_p_cat_resp_80', 
                       'resp_p_cat_resp_dyn', 
                       'resp_p_cat_resp_reg',
                       'resp_p_cat_resp_well_known']

OHE_PROTO_CAT_COLS = ['connection.proto_icmp', 
                      'connection.proto_tcp',
                      'connection.proto_udp']

OHE_SERVICE_CAT_COLS = ['connection.service_dce_rpc', 
                        'connection.service_dhcp',
                        'connection.service_dns', 
                        'connection.service_http',
                        'connection.service_imap', 
                        'connection.service_krb_tcp',
                        'connection.service_none', 
                        'connection.service_ntp',
                        'connection.service_pop3', 
                        'connection.service_smtp',
                        'connection.service_socks', 
                        'connection.service_ssh',
                        'connection.service_ssl', 
                        'connection.service_ssl,imap']

OHE_CONN_STATE_CAT_COLS = ['connection.conn_state_OTH', 
                           'connection.conn_state_REJ',
                           'connection.conn_state_RSTO', 
                           'connection.conn_state_RSTOS0',
                           'connection.conn_state_RSTR', 
                           'connection.conn_state_RSTRH',
                           'connection.conn_state_S0', 
                           'connection.conn_state_S1',
                           'connection.conn_state_S2', 
                           'connection.conn_state_S3',
                           'connection.conn_state_SF', 
                           'connection.conn_state_SH',
                           'connection.conn_state_SHR']

# OHE categories of neighbrouhoods:
ORIG_ORIG_OHE_CAT_COLS = ['orig_orig_connection.protocol_mode_icmp',
                          'orig_orig_connection.protocol_mode_tcp',
                          'orig_orig_connection.protocol_mode_udp'
                          
                          'orig_orig_connection.service_mode_dhcp',
                          'orig_orig_connection.service_mode_dns',
                          'orig_orig_connection.service_mode_http',
                          'orig_orig_connection.service_mode_none',
                          'orig_orig_connection.service_mode_ntp',
                          'orig_orig_connection.service_mode_smtp',
                          'orig_orig_connection.service_mode_ssh',
                          'orig_orig_connection.service_mode_ssl',
                          
                          'orig_orig_connection.conn_state_mode_OTH',
                          'orig_orig_connection.conn_state_mode_REJ',
                          'orig_orig_connection.conn_state_mode_RSTO',
                          'orig_orig_connection.conn_state_mode_RSTR',
                          'orig_orig_connection.conn_state_mode_RSTRH',
                          'orig_orig_connection.conn_state_mode_S0',
                          'orig_orig_connection.conn_state_mode_S1',
                          'orig_orig_connection.conn_state_mode_S2',
                          'orig_orig_connection.conn_state_mode_S3',
                          'orig_orig_connection.conn_state_mode_SF',
                          'orig_orig_connection.conn_state_mode_SH',
                          'orig_orig_connection.conn_state_mode_SHR']

ORIG_RESP_OHE_CAT_COLS = ['orig_resp_connection.protocol_mode_-',
                          'orig_resp_connection.protocol_mode_icmp',
                          'orig_resp_connection.protocol_mode_tcp',
                          'orig_resp_connection.protocol_mode_udp',
                          
                          'orig_resp_connection.service_mode_-',
                          'orig_resp_connection.service_mode_dhcp',
                          'orig_resp_connection.service_mode_dns',
                          'orig_resp_connection.service_mode_http',
                          'orig_resp_connection.service_mode_none',
                          'orig_resp_connection.service_mode_ntp',
                          'orig_resp_connection.service_mode_socks',
                          'orig_resp_connection.service_mode_ssh',
                          'orig_resp_connection.service_mode_ssl',
                          'orig_resp_connection.conn_state_mode_-',
                          
                          'orig_resp_connection.conn_state_mode_OTH',
                          'orig_resp_connection.conn_state_mode_REJ',
                          'orig_resp_connection.conn_state_mode_RSTO',
                          'orig_resp_connection.conn_state_mode_RSTR',
                          'orig_resp_connection.conn_state_mode_S0',
                          'orig_resp_connection.conn_state_mode_S1',
                          'orig_resp_connection.conn_state_mode_S2',
                          'orig_resp_connection.conn_state_mode_S3',
                          'orig_resp_connection.conn_state_mode_SF',
                          'orig_resp_connection.conn_state_mode_SH',
                          'orig_resp_connection.conn_state_mode_SHR']

RESP_ORIG_OHE_CAT_COLS = ['resp_orig_connection.protocol_mode_-',
                          'resp_orig_connection.protocol_mode_icmp',
                          'resp_orig_connection.protocol_mode_tcp',
                          'resp_orig_connection.protocol_mode_udp',
                          
                          'resp_orig_connection.service_mode_-',
                          'resp_orig_connection.service_mode_dhcp',
                          'resp_orig_connection.service_mode_dns',
                          'resp_orig_connection.service_mode_http',
                          'resp_orig_connection.service_mode_none',
                          'resp_orig_connection.service_mode_ntp',
                          'resp_orig_connection.service_mode_smtp',
                          'resp_orig_connection.service_mode_ssl',
                          
                          'resp_orig_connection.conn_state_mode_-',
                          'resp_orig_connection.conn_state_mode_OTH',
                          'resp_orig_connection.conn_state_mode_REJ',
                          'resp_orig_connection.conn_state_mode_RSTO',
                          'resp_orig_connection.conn_state_mode_RSTR',
                          'resp_orig_connection.conn_state_mode_S0',
                          'resp_orig_connection.conn_state_mode_S1',
                          'resp_orig_connection.conn_state_mode_S2',
                          'resp_orig_connection.conn_state_mode_S3',
                          'resp_orig_connection.conn_state_mode_SF',
                          'resp_orig_connection.conn_state_mode_SH',
                          'resp_orig_connection.conn_state_mode_SHR']

RESP_RESP_OHE_CAT_COLS = ['resp_resp_connection.protocol_mode_icmp',
                          'resp_resp_connection.protocol_mode_tcp',
                          'resp_resp_connection.protocol_mode_udp',
                          
                          'resp_resp_connection.service_mode_dhcp',
                          'resp_resp_connection.service_mode_dns',
                          'resp_resp_connection.service_mode_http',
                          'resp_resp_connection.service_mode_none',
                          'resp_resp_connection.service_mode_ntp',
                          'resp_resp_connection.service_mode_socks',
                          'resp_resp_connection.service_mode_ssh',
                          'resp_resp_connection.service_mode_ssl',
                          
                          'resp_resp_connection.conn_state_mode_OTH',
                          'resp_resp_connection.conn_state_mode_REJ',
                          'resp_resp_connection.conn_state_mode_RSTO',
                          'resp_resp_connection.conn_state_mode_RSTR',
                          'resp_resp_connection.conn_state_mode_RSTRH',
                          'resp_resp_connection.conn_state_mode_S0',
                          'resp_resp_connection.conn_state_mode_S1',
                          'resp_resp_connection.conn_state_mode_S2',
                          'resp_resp_connection.conn_state_mode_S3',
                          'resp_resp_connection.conn_state_mode_SF',
                          'resp_resp_connection.conn_state_mode_SH',
                          'resp_resp_connection.conn_state_mode_SHR']

INTERPRETATION_COLS = ['uid', 
                       'originated_ip_num', 'originated_ip', 
                       'responded_ip_num', 'responded_ip', 
                       'timestamp', 'connection.time', 
                       'duration', 'connection.duration',
                       'protocol', 'service', 'conn_state',
                       'connection.orig_p', 'o_port', 'orig_p_cat', 'connection.orig_bytes', 'o_bytes', 'o_ip_bytes',
                       'connection.resp_p', 'r_port', 'resp_p_cat', 'connection.resp_bytes', 'r_bytes', 'r_ip_bytes',
                       'dns_count', 'ssh_count', 'http_count', 'ssl_count', 'files_count', 
                       'attacker_label', 'attack_label']

# %%
# Convert dataframe to matrix
df_matrix = df.to_numpy()
df_matrix
# Out:
# array([[0.0457207757554951, 0.0475358155595201, 0.0093568035959296, ...,
#         'SF', 3, 3],
#        [0.0457207760275853, 0.2592353140906388, 0.1850517759563044, ...,
#         'RSTO', 3, 3],
#        [0.0456672074564273, 0.0136217007978715, 0.1315655621659838, ...,
#         'RSTO', 3, 3],
#        ...,
#        [0.3668643378087655, 0.0323719919622737, 0.7666180545913407, ...,
#         'S0', 6, 6],
#        [0.0457384629778772, 0.5760870884619269, 0.1167552996041521, ...,
#         'SF', 3, 3],
#        [0.0457564386158537, 0.0136217007978715, 0.8168156819438636, ...,
#         'RSTO', 9, 9]], dtype=object)

# %%
df['cluster'].value_counts()
# Out:
# 3    18866
# 0    16756
# 6    16283
# 7    11057
# 1    10857
# 9     8796
# 2     8566
# 8     4240
# 4     2549
# 5     2030
# Name: cluster, dtype: int64

# %% [markdown]
# ### Silhouette coefficient evaluation
#
# ```
# Silhouette Score = (average distance between points within a cluster - average distance between all clusters) /
#                    max(average distance between all clusters, average distance between points within a cluster)
#
# ```
#
# - intRA-cluster distance = average distance between each point within a cluster
# - intER-cluster distance = average distance between all clusters
#
# <center>
# <img src="https://latex.codecogs.com/gif.latex?\bg_white&space;SilhouetteScore(dataPoint) = \frac{b(dataPoint) - a(dataPoint)}{max\{a(dataPoint),b(dataPoint)\}}" /></a>
# </center>
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;SilhouetteScore(dataPoint) = \frac{b(dataPoint) - a(dataPoint)}{max\{a(dataPoint),b(dataPoint)\}}" />
#
# <center>
# <img src="https://latex.codecogs.com/gif.latex?\bg_white&space;a(dataPoint) = \frac{1}{|C_i| - 1} * \sum_{j \in C_i, i != j} d({i,j)}" /></a>
# </center>
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;a(dataPoint) = \frac{1}{|C_i| - 1} * \sum_{j \in C_i, i != j} d({i,j)}" />
#
# <center>
# <img src="https://latex.codecogs.com/gif.latex?\bg_white&space;b(dataPoint) = min_{k != i} \frac{1}{|C_k|} * \sum_{j \in C_k} d({i,j)}" /></a>
# </center>
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;b(dataPoint) = min_{k != i} \frac{1}{|C_k|} * \sum_{j \in C_k} d({i,j)}" />

# %%
for col in df.columns:
    print(col)
# Out:
# originated_ip_num
# responded_ip_num
# connection.time
# connection.duration
# connection.orig_bytes
# connection.orig_pkts
# connection.orig_ip_bytes
# connection.resp_bytes
# connection.resp_pkts
# connection.resp_ip_bytes
# orig_p_cat
# resp_p_cat
# protocol
# service
# conn_state
# dns_count
# ssh_count
# http_count
# ssl_count
# files_count
# orig_orig_total
# orig_orig_connection.time_mean
# orig_orig_connection.duration_mean
# orig_orig_connection.orig_pkts_mean
# orig_orig_connection.orig_bytes_mean
# orig_orig_connection.resp_bytes_mean
# orig_orig_connection.resp_pkts_mean
# orig_orig_orig_p_well_known_count
# orig_orig_orig_p_reg_or_dyn_count
# orig_orig_resp_p_21_count
# orig_orig_resp_p_22_count
# orig_orig_resp_p_53_count
# orig_orig_resp_p_80_count
# orig_orig_resp_p_123_count
# orig_orig_resp_p_443_count
# orig_orig_resp_p_3389_count
# orig_orig_resp_p_well_known_count
# orig_orig_resp_p_reg_count
# orig_orig_resp_p_dyn_count
# orig_orig_dns_count_mean
# orig_orig_ssh_count_mean
# orig_orig_http_count_mean
# orig_orig_ssl_count_mean
# orig_orig_files_count_mean
# orig_orig_similar_conns_count
# orig_orig_similar_dns_qtype_count
# orig_orig_similar_dns_rcode_count
# orig_orig_similar_ssh_auth_attempts_count
# orig_orig_similar_ssh_host_key_count
# orig_orig_similar_http_method_count
# orig_orig_similar_http_status_code_count
# orig_orig_similar_http_user_agent_count
# orig_orig_similar_ssl_version_count
# orig_orig_similar_ssl_cipher_count
# orig_orig_similar_ssl_curve_count
# orig_orig_similar_ssl_validation_status_count
# orig_orig_similar_files_source_count
# orig_orig_similar_file_md5_count
# orig_orig_connection.protocol_mode
# orig_orig_connection.service_mode
# orig_orig_connection.conn_state_mode
# orig_resp_total
# orig_resp_connection.time_mean
# orig_resp_connection.duration_mean
# orig_resp_connection.orig_pkts_mean
# orig_resp_connection.orig_bytes_mean
# orig_resp_connection.resp_bytes_mean
# orig_resp_connection.resp_pkts_mean
# orig_resp_orig_p_well_known_count
# orig_resp_orig_p_reg_or_dyn_count
# orig_resp_resp_p_21_count
# orig_resp_resp_p_22_count
# orig_resp_resp_p_53_count
# orig_resp_resp_p_80_count
# orig_resp_resp_p_123_count
# orig_resp_resp_p_443_count
# orig_resp_resp_p_3389_count
# orig_resp_resp_p_well_known_count
# orig_resp_resp_p_reg_count
# orig_resp_resp_p_dyn_count
# orig_resp_dns_count_mean
# orig_resp_ssh_count_mean
# orig_resp_http_count_mean
# orig_resp_ssl_count_mean
# orig_resp_files_count_mean
# orig_resp_similar_conns_count
# orig_resp_similar_dns_qtype_count
# orig_resp_similar_dns_rcode_count
# orig_resp_similar_ssh_auth_attempts_count
# orig_resp_similar_ssh_host_key_count
# orig_resp_similar_http_method_count
# orig_resp_similar_http_status_code_count
# orig_resp_similar_http_user_agent_count
# orig_resp_similar_ssl_version_count
# orig_resp_similar_ssl_cipher_count
# orig_resp_similar_ssl_curve_count
# orig_resp_similar_ssl_validation_status_count
# orig_resp_similar_files_source_count
# orig_resp_similar_file_md5_count
# orig_resp_connection.protocol_mode
# orig_resp_connection.service_mode
# orig_resp_connection.conn_state_mode
# resp_orig_total
# resp_orig_connection.time_mean
# resp_orig_connection.duration_mean
# resp_orig_connection.orig_pkts_mean
# resp_orig_connection.orig_bytes_mean
# resp_orig_connection.resp_bytes_mean
# resp_orig_connection.resp_pkts_mean
# resp_orig_orig_p_well_known_count
# resp_orig_orig_p_reg_or_dyn_count
# resp_orig_resp_p_21_count
# resp_orig_resp_p_22_count
# resp_orig_resp_p_53_count
# resp_orig_resp_p_80_count
# resp_orig_resp_p_123_count
# resp_orig_resp_p_443_count
# resp_orig_resp_p_3389_count
# resp_orig_resp_p_well_known_count
# resp_orig_resp_p_reg_count
# resp_orig_resp_p_dyn_count
# resp_orig_dns_count_mean
# resp_orig_ssh_count_mean
# resp_orig_http_count_mean
# resp_orig_ssl_count_mean
# resp_orig_files_count_mean
# resp_orig_similar_conns_count
# resp_orig_similar_dns_qtype_count
# resp_orig_similar_dns_rcode_count
# resp_orig_similar_ssh_auth_attempts_count
# resp_orig_similar_ssh_host_key_count
# resp_orig_similar_http_method_count
# resp_orig_similar_http_status_code_count
# resp_orig_similar_http_user_agent_count
# resp_orig_similar_ssl_version_count
# resp_orig_similar_ssl_cipher_count
# resp_orig_similar_ssl_curve_count
# resp_orig_similar_ssl_validation_status_count
# resp_orig_similar_files_source_count
# resp_orig_similar_file_md5_count
# resp_orig_connection.protocol_mode
# resp_orig_connection.service_mode
# resp_orig_connection.conn_state_mode
# resp_resp_total
# resp_resp_connection.time_mean
# resp_resp_connection.duration_mean
# resp_resp_connection.orig_pkts_mean
# resp_resp_connection.orig_bytes_mean
# resp_resp_connection.resp_bytes_mean
# resp_resp_connection.resp_pkts_mean
# resp_resp_orig_p_well_known_count
# resp_resp_orig_p_reg_or_dyn_count
# resp_resp_resp_p_21_count
# resp_resp_resp_p_22_count
# resp_resp_resp_p_53_count
# resp_resp_resp_p_80_count
# resp_resp_resp_p_123_count
# resp_resp_resp_p_443_count
# resp_resp_resp_p_3389_count
# resp_resp_resp_p_well_known_count
# resp_resp_resp_p_reg_count
# resp_resp_resp_p_dyn_count
# resp_resp_dns_count_mean
# resp_resp_ssh_count_mean
# resp_resp_http_count_mean
# resp_resp_ssl_count_mean
# resp_resp_files_count_mean
# resp_resp_similar_conns_count
# resp_resp_similar_dns_qtype_count
# resp_resp_similar_dns_rcode_count
# resp_resp_similar_ssh_auth_attempts_count
# resp_resp_similar_ssh_host_key_count
# resp_resp_similar_http_method_count
# resp_resp_similar_http_status_code_count
# resp_resp_similar_http_user_agent_count
# resp_resp_similar_ssl_version_count
# resp_resp_similar_ssl_cipher_count
# resp_resp_similar_ssl_curve_count
# resp_resp_similar_ssl_validation_status_count
# resp_resp_similar_files_source_count
# resp_resp_similar_file_md5_count
# resp_resp_connection.protocol_mode
# resp_resp_connection.service_mode
# resp_resp_connection.conn_state_mode
# cluster
# cluster_cat

# %%
len(df.columns)
# Out:
# 186

# %%
# Inspect the categorical variables
df.select_dtypes('object').nunique()
# Out:
# orig_p_cat                               2
# resp_p_cat                              10
# protocol                                 3
# service                                 14
# conn_state                              13
# orig_orig_connection.protocol_mode       3
# orig_orig_connection.service_mode        8
# orig_orig_connection.conn_state_mode    12
# orig_resp_connection.protocol_mode       4
# orig_resp_connection.service_mode        9
# orig_resp_connection.conn_state_mode    12
# resp_orig_connection.protocol_mode       4
# resp_orig_connection.service_mode        8
# resp_orig_connection.conn_state_mode    12
# resp_resp_connection.protocol_mode       3
# resp_resp_connection.service_mode        8
# resp_resp_connection.conn_state_mode    12
# dtype: int64

# %%
# Get the position of categorical columns
cat_cols_i_list = [df.columns.get_loc(col) for col in list(df.select_dtypes('object').columns)]
print('Categorical columns         : {}'.format(list(df.select_dtypes('object').columns)))
print('Categorical columns indexes : {}'.format(cat_cols_i_list))
# Out:
# Categorical columns         : ['orig_p_cat', 'resp_p_cat', 'protocol', 'service', 'conn_state', 'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode', 'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode', 'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode', 'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode']
# Categorical columns indexes : [10, 11, 12, 13, 14, 58, 59, 60, 99, 100, 101, 140, 141, 142, 181, 182, 183]

# %%
pd.set_option('display.max_columns', None)

# random labels for now:
import numpy as np

df['cluster'] = np.random.randint(0, 11, df.shape[0])

df_numerical = df[['connection.time', 'connection.duration', 'connection.orig_bytes',
       'connection.orig_pkts', 'connection.resp_bytes', 'connection.resp_pkts',
       'originated_ip_num', 'responded_ip_num', 
       #'dns_count', 'ssh_count', 'http_count', 'ssl_count', 'files_count', 
                   'orig_orig_total', 
                    'orig_orig_connection.time_mean', 
                    'orig_orig_connection.duration_mean',
                    'orig_orig_connection.orig_p_mean', 
                    'orig_orig_connection.orig_pkts_mean',
                    'orig_orig_connection.orig_bytes_mean',
                    'orig_orig_connection.resp_p_mean', 
                    'orig_orig_connection.resp_bytes_mean',
                    'orig_orig_connection.resp_pkts_mean',
                    'orig_orig_orig_p_well_known_count', 'orig_orig_orig_p_reg_or_dyn_count', 'orig_orig_resp_p_21_count', 'orig_orig_resp_p_22_count',
                    'orig_orig_resp_p_53_count', 'orig_orig_resp_p_80_count', 'orig_orig_resp_p_123_count', 'orig_orig_resp_p_443_count', 'orig_orig_resp_p_3389_count',
                    'orig_orig_resp_p_well_known_count', 'orig_orig_resp_p_reg_count', 'orig_orig_resp_p_dyn_count',
                   'orig_resp_total', 
                    'orig_resp_connection.time_mean', 
                    'orig_resp_connection.duration_mean',
                    'orig_resp_connection.orig_p_mean', 
                    'orig_resp_connection.orig_pkts_mean',
                    'orig_resp_connection.orig_bytes_mean',
                    'orig_resp_connection.resp_p_mean', 
                    'orig_resp_connection.resp_bytes_mean',
                    'orig_resp_connection.resp_pkts_mean',
                    'orig_resp_orig_p_well_known_count', 'orig_resp_orig_p_reg_or_dyn_count', 'orig_resp_resp_p_21_count', 'orig_resp_resp_p_22_count',
                    'orig_resp_resp_p_53_count', 'orig_resp_resp_p_80_count', 'orig_resp_resp_p_123_count', 'orig_resp_resp_p_443_count', 'orig_resp_resp_p_3389_count',
                    'orig_resp_resp_p_well_known_count', 'orig_resp_resp_p_reg_count', 'orig_resp_resp_p_dyn_count',
                   'resp_orig_total', 
                    'resp_orig_connection.time_mean', 
                    'resp_orig_connection.duration_mean',
                    'resp_orig_connection.orig_p_mean', 
                    'resp_orig_connection.orig_bytes_mean',
                    'resp_orig_connection.orig_pkts_mean',
                    'resp_orig_connection.resp_p_mean', 
                    'resp_orig_connection.resp_bytes_mean',
                    'resp_orig_connection.resp_pkts_mean',
                    'resp_orig_orig_p_well_known_count', 'resp_orig_orig_p_reg_or_dyn_count', 'resp_orig_resp_p_21_count', 'resp_orig_resp_p_22_count',
                    'resp_orig_resp_p_53_count', 'resp_orig_resp_p_80_count', 'resp_orig_resp_p_123_count', 'resp_orig_resp_p_443_count', 'resp_orig_resp_p_3389_count',
                    'resp_orig_resp_p_well_known_count', 'resp_orig_resp_p_reg_count', 'resp_orig_resp_p_dyn_count',
                   'resp_resp_total',
                    'resp_resp_connection.time_mean', 
                    'resp_resp_connection.duration_mean',
                    'resp_resp_connection.orig_p_mean', 
                    'resp_resp_connection.orig_bytes_mean',
                    'resp_resp_connection.orig_pkts_mean',
                    'resp_resp_connection.resp_p_mean', 
                    'resp_resp_connection.resp_bytes_mean',
                    'resp_resp_connection.resp_pkts_mean',
                    'resp_resp_orig_p_well_known_count', 'resp_resp_orig_p_reg_or_dyn_count', 'resp_resp_resp_p_21_count', 'resp_resp_resp_p_22_count',
                    'resp_resp_resp_p_53_count', 'resp_resp_resp_p_80_count', 'resp_resp_resp_p_123_count', 'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
                    'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count', 'resp_resp_resp_p_dyn_count',
        'cluster']]

df_categorical = df[['orig_p_cat', 'resp_p_cat',
       'protocol', 'service', 'conn_state', 
       'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode',
       'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode',
       'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode',
       'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode', 'cluster']]

# %%
df_numerical.head(5)
# Out:
#    connection.time  connection.duration  connection.orig_bytes  \
# 0          0.77916              0.00000                0.00000
# 1          0.80063              0.00000                0.00000
# 2          0.95296              0.00000                0.00000
# 3          0.13368              0.00000                0.00000
# 4          0.80081              0.00000                0.00000
#
#    connection.orig_pkts  connection.resp_bytes  connection.resp_pkts  \
# 0               0.00001                0.00000               0.00000
# 1               0.00001                0.00000               0.00000
# 2               0.00001                0.00000               0.00001
# 3               0.00001                0.00000               0.00001
# 4               0.00001                0.00000               0.00000
#
#    originated_ip_num  responded_ip_num  orig_orig_total  \
# 0            0.02044           0.03237          0.43398
# 1            0.82836           0.03237          0.52968
# 2            0.04576           0.01362          0.00522
# 3            0.04570           0.34849          0.00577
# 4            0.02044           0.03237          0.44277
#
#    orig_orig_connection.time_mean  orig_orig_connection.duration_mean  \
# 0                         0.77921                             0.00044
# 1                         0.79952                             0.00001
# 2                         0.95349                             0.00000
# 3                         0.13360                             0.00007
# 4                         0.80121                             0.00081
#
#    orig_orig_connection.orig_p_mean  orig_orig_connection.orig_pkts_mean  \
# 0                           0.59214                              0.00004
# 1                           0.76580                              0.00003
# 2                           0.00044                              0.00002
# 3                           0.25982                              0.01222
# 4                           0.78710                              0.00021
#
#    orig_orig_connection.orig_bytes_mean  orig_orig_connection.resp_p_mean  \
# 0                               0.00000                           0.12689
# 1                               0.00000                           0.11849
# 2                               0.00000                           0.00040
# 3                               0.00001                           0.00316
# 4                               0.00000                           0.14487
#
#    orig_orig_connection.resp_bytes_mean  orig_orig_connection.resp_pkts_mean  \
# 0                               0.00000                              0.00001
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00001
# 3                               0.06056                              0.00429
# 4                               0.00000                              0.00010
#
#    orig_orig_orig_p_well_known_count  orig_orig_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.43402
# 1                            0.00000                            0.52971
# 2                            0.36150                            0.00000
# 3                            0.25352                            0.00213
# 4                            0.01878                            0.44254
#
#    orig_orig_resp_p_21_count  orig_orig_resp_p_22_count  \
# 0                    0.00000                    0.00068
# 1                    0.33333                    0.00068
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.33333                    0.00068
#
#    orig_orig_resp_p_53_count  orig_orig_resp_p_80_count  \
# 0                    0.00000                    0.00000
# 1                    0.00125                    0.35495
# 2                    0.00000                    0.00000
# 3                    0.00063                    0.00232
# 4                    0.00167                    0.05983
#
#    orig_orig_resp_p_123_count  orig_orig_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00554
# 2                     0.08537                     0.00000
# 3                     0.32927                     0.00216
# 4                     0.00000                     0.00189
#
#    orig_orig_resp_p_3389_count  orig_orig_resp_p_well_known_count  \
# 0                      0.00000                            0.56661
# 1                      0.30000                            0.22405
# 2                      0.00000                            0.01599
# 3                      0.00000                            0.00000
# 4                      0.30000                            0.26947
#
#    orig_orig_resp_p_reg_count  orig_orig_resp_p_dyn_count  orig_resp_total  \
# 0                     0.37885                     0.35202          0.00000
# 1                     0.45773                     0.41982          0.00000
# 2                     0.00000                     0.00000          0.00000
# 3                     0.00000                     0.00000          0.00153
# 4                     0.46817                     0.42634          0.00000
#
#    orig_resp_connection.time_mean  orig_resp_connection.duration_mean  \
# 0                         0.77916                             0.00000
# 1                         0.80063                             0.00000
# 2                         0.95296                             0.00000
# 3                         0.13296                             0.00000
# 4                         0.80081                             0.00000
#
#    orig_resp_connection.orig_p_mean  orig_resp_connection.orig_pkts_mean  \
# 0                           0.00000                              0.00000
# 1                           0.00000                              0.00000
# 2                           0.00000                              0.00000
# 3                           0.00188                              0.00003
# 4                           0.00000                              0.00000
#
#    orig_resp_connection.orig_bytes_mean  orig_resp_connection.resp_p_mean  \
# 0                               0.00000                           0.00000
# 1                               0.00000                           0.00000
# 2                               0.00000                           0.00000
# 3                               0.00000                           0.00206
# 4                               0.00000                           0.00000
#
#    orig_resp_connection.resp_bytes_mean  orig_resp_connection.resp_pkts_mean  \
# 0                               0.00000                              0.00000
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00000
# 4                               0.00000                              0.00000
#
#    orig_resp_orig_p_well_known_count  orig_resp_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.00000
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.05263                            0.00000
# 4                            0.00000                            0.00000
#
#    orig_resp_resp_p_21_count  orig_resp_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00000
#
#    orig_resp_resp_p_53_count  orig_resp_resp_p_80_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00000
#
#    orig_resp_resp_p_123_count  orig_resp_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.06250                     0.00000
# 4                     0.00000                     0.00000
#
#    orig_resp_resp_p_3389_count  orig_resp_resp_p_well_known_count  \
# 0                      0.00000                            0.00000
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.00000
# 3                      0.00000                            0.00000
# 4                      0.00000                            0.00000
#
#    orig_resp_resp_p_reg_count  orig_resp_resp_p_dyn_count  resp_orig_total  \
# 0                     0.00000                     0.00000          0.00025
# 1                     0.00000                     0.00000          0.00000
# 2                     0.00000                     0.00000          0.00000
# 3                     0.00000                     0.00000          0.00000
# 4                     0.00000                     0.00000          0.00101
#
#    resp_orig_connection.time_mean  resp_orig_connection.duration_mean  \
# 0                         0.77953                             0.00000
# 1                         0.80063                             0.00000
# 2                         0.95296                             0.00000
# 3                         0.13368                             0.00000
# 4                         0.80233                             0.00000
#
#    resp_orig_connection.orig_p_mean  resp_orig_connection.orig_bytes_mean  \
# 0                           0.76238                               0.00000
# 1                           0.00000                               0.00000
# 2                           0.00000                               0.00000
# 3                           0.00000                               0.00000
# 4                           0.60202                               0.00000
#
#    resp_orig_connection.orig_pkts_mean  resp_orig_connection.resp_p_mean  \
# 0                              0.00002                           0.00089
# 1                              0.00000                           0.00000
# 2                              0.00000                           0.00000
# 3                              0.00000                           0.00000
# 4                              0.00002                           0.00089
#
#    resp_orig_connection.resp_bytes_mean  resp_orig_connection.resp_pkts_mean  \
# 0                               0.00000                              0.00001
# 1                               0.00000                              0.00000
# 2                               0.00000                              0.00000
# 3                               0.00000                              0.00000
# 4                               0.00001                              0.00001
#
#    resp_orig_orig_p_well_known_count  resp_orig_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.00025
# 1                            0.00000                            0.00000
# 2                            0.00000                            0.00000
# 3                            0.00000                            0.00000
# 4                            0.00000                            0.00101
#
#    resp_orig_resp_p_21_count  resp_orig_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00000
#
#    resp_orig_resp_p_53_count  resp_orig_resp_p_80_count  \
# 0                    0.00063                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00251                    0.00000
#
#    resp_orig_resp_p_123_count  resp_orig_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.00000
# 3                     0.00000                     0.00000
# 4                     0.00000                     0.00000
#
#    resp_orig_resp_p_3389_count  resp_orig_resp_p_well_known_count  \
# 0                      0.00000                            0.00000
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.00000
# 3                      0.00000                            0.00000
# 4                      0.00000                            0.00000
#
#    resp_orig_resp_p_reg_count  resp_orig_resp_p_dyn_count  resp_resp_total  \
# 0                     0.00000                     0.00000          0.11000
# 1                     0.00000                     0.00000          0.08300
# 2                     0.00000                     0.00000          0.00800
# 3                     0.00000                     0.00000          0.00500
# 4                     0.00000                     0.00000          0.26900
#
#    resp_resp_connection.time_mean  resp_resp_connection.duration_mean  \
# 0                         0.77913                             0.00096
# 1                         0.80069                             0.00005
# 2                         0.95305                             0.00002
# 3                         0.13369                             0.00000
# 4                         0.80087                             0.00000
#
#    resp_resp_connection.orig_p_mean  resp_resp_connection.orig_bytes_mean  \
# 0                           0.63738                               0.00000
# 1                           0.61505                               0.00000
# 2                           0.79477                               0.00000
# 3                           0.00188                               0.00000
# 4                           0.91675                               0.00000
#
#    resp_resp_connection.orig_pkts_mean  resp_resp_connection.resp_p_mean  \
# 0                              0.00005                           0.06364
# 1                              0.00003                           0.00134
# 2                              0.00025                           0.00496
# 3                              0.00001                           0.00206
# 4                              0.00001                           0.15848
#
#    resp_resp_connection.resp_bytes_mean  resp_resp_connection.resp_pkts_mean  \
# 0                               0.00000                              0.00003
# 1                               0.00000                              0.00001
# 2                               0.00023                              0.00015
# 3                               0.00000                              0.00001
# 4                               0.00000                              0.00000
#
#    resp_resp_orig_p_well_known_count  resp_resp_orig_p_reg_or_dyn_count  \
# 0                            0.00000                            0.11000
# 1                            0.00000                            0.08300
# 2                            0.04762                            0.00700
# 3                            0.23810                            0.00000
# 4                            0.00000                            0.26900
#
#    resp_resp_resp_p_21_count  resp_resp_resp_p_22_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.00000
# 2                    0.00000                    0.00000
# 3                    0.00000                    0.00000
# 4                    0.00000                    0.00543
#
#    resp_resp_resp_p_53_count  resp_resp_resp_p_80_count  \
# 0                    0.00000                    0.00000
# 1                    0.00000                    0.24412
# 2                    0.00000                    0.00588
# 3                    0.00000                    0.00000
# 4                    0.00575                    0.00294
#
#    resp_resp_resp_p_123_count  resp_resp_resp_p_443_count  \
# 0                     0.00000                     0.00000
# 1                     0.00000                     0.00000
# 2                     0.00000                     0.01174
# 3                     0.23810                     0.00000
# 4                     0.00000                     0.00000
#
#    resp_resp_resp_p_3389_count  resp_resp_resp_p_well_known_count  \
# 0                      0.00000                            0.47853
# 1                      0.00000                            0.00000
# 2                      0.00000                            0.00613
# 3                      0.00000                            0.00000
# 4                      0.00000                            0.22699
#
#    resp_resp_resp_p_reg_count  resp_resp_resp_p_dyn_count  cluster
# 0                     0.03759                     0.03333        2
# 1                     0.00000                     0.00000        1
# 2                     0.00000                     0.00000        9
# 3                     0.00000                     0.00000        0
# 4                     0.26190                     0.31667        9

# %%
df_categorical.head(5)
# Out:
#         orig_p_cat       resp_p_cat protocol service conn_state  \
# 0  orig_reg_or_dyn         resp_reg      tcp    none         S0
# 1  orig_reg_or_dyn          resp_80      tcp    none         S0
# 2  orig_well_known  resp_well_known     icmp    none        OTH
# 3  orig_well_known         resp_123      udp     ntp         SF
# 4  orig_reg_or_dyn         resp_reg      tcp    none         S0
#
#   orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# 0                                tcp                              none
# 1                                tcp                              none
# 2                               icmp                              none
# 3                                udp                               ntp
# 4                                tcp                              none
#
#   orig_orig_connection.conn_state_mode orig_resp_connection.protocol_mode  \
# 0                                   S0                                  -
# 1                                   S0                                  -
# 2                                  OTH                                  -
# 3                                   SF                                udp
# 4                                   S0                                  -
#
#   orig_resp_connection.service_mode orig_resp_connection.conn_state_mode  \
# 0                                 -                                    -
# 1                                 -                                    -
# 2                                 -                                    -
# 3                               ntp                                   S0
# 4                                 -                                    -
#
#   resp_orig_connection.protocol_mode resp_orig_connection.service_mode  \
# 0                                udp                               dns
# 1                                  -                                 -
# 2                                  -                                 -
# 3                                  -                                 -
# 4                                udp                               dns
#
#   resp_orig_connection.conn_state_mode resp_resp_connection.protocol_mode  \
# 0                                   SF                                tcp
# 1                                    -                                tcp
# 2                                    -                                tcp
# 3                                    -                                udp
# 4                                   SF                                tcp
#
#   resp_resp_connection.service_mode resp_resp_connection.conn_state_mode  \
# 0                               ssl                                 RSTR
# 1                              none                                   S0
# 2                               ssl                                 RSTO
# 3                               ntp                                   SF
# 4                              none                                   S0
#
#    cluster
# 0        2
# 1        1
# 2        9
# 3        0
# 4        9

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples
# from kmodes.kprototypes import KPrototypes
from kmodes.util.dissim import matching_dissim
from kmodes.util.dissim import euclidean_dissim
from kmodes.util import encode_features

# %%
dfs_list_num = []
dfs_list_cat = []

for i in range(OPTIMAL_K + 1):
    df_i_num = df_numerical.loc[df_numerical['cluster'] == i].sample(10)
    dfs_list_num.append(df_i_num)
    df_i_cat = df_categorical.loc[df_categorical['cluster'] == i].sample(10)
    dfs_list_cat.append(df_i_cat)

print(len(dfs_list_num))
print(type(dfs_list_num[0]))
# Out:
# 10
# <class 'pandas.core.frame.DataFrame'>

# %%
df_num = dfs_list_num[0]
df_cat = dfs_list_cat[0]

for i in range(1, len(dfs_list_num)): 
    df_num = df_num.append(dfs_list_num[i])
    df_cat = df_cat.append(dfs_list_cat[i])

# %%
df_cat
# Out:
#              orig_p_cat       resp_p_cat protocol service conn_state  \
# 82584   orig_reg_or_dyn          resp_53      udp     dns         SF
# 274676  orig_reg_or_dyn  resp_well_known      tcp    none       RSTO
# 39819   orig_well_known         resp_123      udp     ntp         SF
# 52848   orig_reg_or_dyn          resp_53      udp     dns         SF
# 450658  orig_reg_or_dyn          resp_53      udp     dns         SF
# ...                 ...              ...      ...     ...        ...
# 201536  orig_well_known         resp_123      udp     ntp         SF
# 125984  orig_reg_or_dyn          resp_22      tcp     ssh         SF
# 431994  orig_well_known         resp_123      udp     ntp         SF
# 427740  orig_reg_or_dyn          resp_80      tcp    http       RSTO
# 248667  orig_reg_or_dyn         resp_reg      tcp    none         S0
#
#        orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# 82584                                 udp                               dns
# 274676                                tcp                              none
# 39819                                icmp                              none
# 52848                                 udp                               dns
# 450658                                udp                               dns
# ...                                   ...                               ...
# 201536                                udp                               ntp
# 125984                                tcp                              none
# 431994                                udp                               ntp
# 427740                                tcp                               ssl
# 248667                                tcp                              none
#
#        orig_orig_connection.conn_state_mode  \
# 82584                                    SF
# 274676                                   S0
# 39819                                   OTH
# 52848                                    SF
# 450658                                   SF
# ...                                     ...
# 201536                                   SF
# 125984                                   S0
# 431994                                   SF
# 427740                                 RSTO
# 248667                                   S0
#
#        orig_resp_connection.protocol_mode orig_resp_connection.service_mode  \
# 82584                                   -                                 -
# 274676                               icmp                              none
# 39819                                   -                                 -
# 52848                                 udp                               dns
# 450658                               icmp                              none
# ...                                   ...                               ...
# 201536                                  -                                 -
# 125984                                  -                                 -
# 431994                                  -                                 -
# 427740                                  -                                 -
# 248667                                tcp                              none
#
#        orig_resp_connection.conn_state_mode  \
# 82584                                     -
# 274676                                  OTH
# 39819                                     -
# 52848                                    SF
# 450658                                  OTH
# ...                                     ...
# 201536                                    -
# 125984                                    -
# 431994                                    -
# 427740                                    -
# 248667                                   SF
#
#        resp_orig_connection.protocol_mode resp_orig_connection.service_mode  \
# 82584                                   -                                 -
# 274676                                udp                               dns
# 39819                                 udp                               ntp
# 52848                                 udp                               dns
# 450658                                udp                               dns
# ...                                   ...                               ...
# 201536                                  -                                 -
# 125984                                udp                               dns
# 431994                                udp                               ntp
# 427740                               icmp                              none
# 248667                                udp                               dns
#
#        resp_orig_connection.conn_state_mode  \
# 82584                                     -
# 274676                                   SF
# 39819                                    S0
# 52848                                    SF
# 450658                                   SF
# ...                                     ...
# 201536                                    -
# 125984                                   SF
# 431994                                   S0
# 427740                                  OTH
# 248667                                   SF
#
#        resp_resp_connection.protocol_mode resp_resp_connection.service_mode  \
# 82584                                 udp                               dns
# 274676                                  -                                 -
# 39819                                 udp                               ntp
# 52848                                   -                                 -
# 450658                                udp                               dns
# ...                                   ...                               ...
# 201536                                udp                               ntp
# 125984                                tcp                              none
# 431994                                udp                               ntp
# 427740                                tcp                               ssl
# 248667                                tcp                              none
#
#        resp_resp_connection.conn_state_mode  cluster
# 82584                                    SF        0
# 274676                                    -        0
# 39819                                    SF        0
# 52848                                     -        0
# 450658                                   SF        0
# ...                                     ...      ...
# 201536                                   SF        9
# 125984                                   SF        9
# 431994                                   SF        9
# 427740                                   SF        9
# 248667                                   S0        9
#
# [100 rows x 18 columns]

# %%
df_cat = df_cat.drop('cluster', 1)
df_cat
# Out:
#              orig_p_cat       resp_p_cat protocol service conn_state  \
# 82584   orig_reg_or_dyn          resp_53      udp     dns         SF
# 274676  orig_reg_or_dyn  resp_well_known      tcp    none       RSTO
# 39819   orig_well_known         resp_123      udp     ntp         SF
# 52848   orig_reg_or_dyn          resp_53      udp     dns         SF
# 450658  orig_reg_or_dyn          resp_53      udp     dns         SF
# ...                 ...              ...      ...     ...        ...
# 201536  orig_well_known         resp_123      udp     ntp         SF
# 125984  orig_reg_or_dyn          resp_22      tcp     ssh         SF
# 431994  orig_well_known         resp_123      udp     ntp         SF
# 427740  orig_reg_or_dyn          resp_80      tcp    http       RSTO
# 248667  orig_reg_or_dyn         resp_reg      tcp    none         S0
#
#        orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# 82584                                 udp                               dns
# 274676                                tcp                              none
# 39819                                icmp                              none
# 52848                                 udp                               dns
# 450658                                udp                               dns
# ...                                   ...                               ...
# 201536                                udp                               ntp
# 125984                                tcp                              none
# 431994                                udp                               ntp
# 427740                                tcp                               ssl
# 248667                                tcp                              none
#
#        orig_orig_connection.conn_state_mode  \
# 82584                                    SF
# 274676                                   S0
# 39819                                   OTH
# 52848                                    SF
# 450658                                   SF
# ...                                     ...
# 201536                                   SF
# 125984                                   S0
# 431994                                   SF
# 427740                                 RSTO
# 248667                                   S0
#
#        orig_resp_connection.protocol_mode orig_resp_connection.service_mode  \
# 82584                                   -                                 -
# 274676                               icmp                              none
# 39819                                   -                                 -
# 52848                                 udp                               dns
# 450658                               icmp                              none
# ...                                   ...                               ...
# 201536                                  -                                 -
# 125984                                  -                                 -
# 431994                                  -                                 -
# 427740                                  -                                 -
# 248667                                tcp                              none
#
#        orig_resp_connection.conn_state_mode  \
# 82584                                     -
# 274676                                  OTH
# 39819                                     -
# 52848                                    SF
# 450658                                  OTH
# ...                                     ...
# 201536                                    -
# 125984                                    -
# 431994                                    -
# 427740                                    -
# 248667                                   SF
#
#        resp_orig_connection.protocol_mode resp_orig_connection.service_mode  \
# 82584                                   -                                 -
# 274676                                udp                               dns
# 39819                                 udp                               ntp
# 52848                                 udp                               dns
# 450658                                udp                               dns
# ...                                   ...                               ...
# 201536                                  -                                 -
# 125984                                udp                               dns
# 431994                                udp                               ntp
# 427740                               icmp                              none
# 248667                                udp                               dns
#
#        resp_orig_connection.conn_state_mode  \
# 82584                                     -
# 274676                                   SF
# 39819                                    S0
# 52848                                    SF
# 450658                                   SF
# ...                                     ...
# 201536                                    -
# 125984                                   SF
# 431994                                   S0
# 427740                                  OTH
# 248667                                   SF
#
#        resp_resp_connection.protocol_mode resp_resp_connection.service_mode  \
# 82584                                 udp                               dns
# 274676                                  -                                 -
# 39819                                 udp                               ntp
# 52848                                   -                                 -
# 450658                                udp                               dns
# ...                                   ...                               ...
# 201536                                udp                               ntp
# 125984                                tcp                              none
# 431994                                udp                               ntp
# 427740                                tcp                               ssl
# 248667                                tcp                              none
#
#        resp_resp_connection.conn_state_mode
# 82584                                    SF
# 274676                                    -
# 39819                                    SF
# 52848                                     -
# 450658                                   SF
# ...                                     ...
# 201536                                   SF
# 125984                                   SF
# 431994                                   SF
# 427740                                   SF
# 248667                                   S0
#
# [100 rows x 17 columns]

# %%
df_cat_arr = np.asanyarray(df_cat)
df_cat_arr[0]
# Out:
# array(['orig_reg_or_dyn', 'resp_53', 'udp', 'dns', 'SF', 'udp', 'dns',
#        'SF', '-', '-', '-', '-', '-', '-', 'udp', 'dns', 'SF'],
#       dtype=object)

# %%
df_cat_arr
# Out:
# array([['orig_reg_or_dyn', 'resp_53', 'udp', ..., 'udp', 'dns', 'SF'],
#        ['orig_reg_or_dyn', 'resp_well_known', 'tcp', ..., '-', '-', '-'],
#        ['orig_well_known', 'resp_123', 'udp', ..., 'udp', 'ntp', 'SF'],
#        ...,
#        ['orig_well_known', 'resp_123', 'udp', ..., 'udp', 'ntp', 'SF'],
#        ['orig_reg_or_dyn', 'resp_80', 'tcp', ..., 'tcp', 'ssl', 'SF'],
#        ['orig_reg_or_dyn', 'resp_reg', 'tcp', ..., 'tcp', 'none', 'S0']],
#       dtype=object)

# %%
df_cat_encoded = encode_features(df_cat_arr)
df_cat_encoded
# Out:
# (array([[0, 3, 2, ..., 3, 1, 5],
#         [0, 7, 1, ..., 0, 0, 0],
#         [1, 0, 2, ..., 3, 4, 5],
#         ...,
#         [1, 0, 2, ..., 3, 4, 5],
#         [0, 4, 1, ..., 2, 5, 5],
#         [0, 6, 1, ..., 2, 3, 4]]),
#  [{'orig_reg_or_dyn': 0, 'orig_well_known': 1},
#   {'resp_123': 0,
#    'resp_22': 1,
#    'resp_443': 2,
#    'resp_53': 3,
#    'resp_80': 4,
#    'resp_dyn': 5,
#    'resp_reg': 6,
#    'resp_well_known': 7},
#   {'icmp': 0, 'tcp': 1, 'udp': 2},
#   {'dns': 0, 'http': 1, 'none': 2, 'ntp': 3, 'ssh': 4, 'ssl': 5},
#   {'OTH': 0, 'RSTO': 1, 'RSTR': 2, 'S0': 3, 'SF': 4},
#   {'icmp': 0, 'tcp': 1, 'udp': 2},
#   {'dns': 0, 'http': 1, 'none': 2, 'ntp': 3, 'ssl': 4},
#   {'OTH': 0, 'RSTO': 1, 'S0': 2, 'SF': 3},
#   {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#   {'-': 0, 'dns': 1, 'none': 2, 'ntp': 3},
#   {'-': 0, 'OTH': 1, 'S0': 2, 'S3': 3, 'SF': 4},
#   {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#   {'-': 0, 'dns': 1, 'none': 2, 'ntp': 3},
#   {'-': 0, 'OTH': 1, 'RSTO': 2, 'S0': 3, 'S3': 4, 'SF': 5},
#   {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#   {'-': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssl': 5},
#   {'-': 0, 'OTH': 1, 'RSTO': 2, 'RSTR': 3, 'S0': 4, 'SF': 5}])

# %%
print(len(df_cat_encoded[0]))
print(len(df_cat_encoded[0][0]))
# Out:
# 100
# 17

# %%
df_cat_encoded[0]
# Out:
# array([[0, 3, 2, ..., 3, 1, 5],
#        [0, 7, 1, ..., 0, 0, 0],
#        [1, 0, 2, ..., 3, 4, 5],
#        ...,
#        [1, 0, 2, ..., 3, 4, 5],
#        [0, 4, 1, ..., 2, 5, 5],
#        [0, 6, 1, ..., 2, 3, 4]])

# %%
df_cat_encoded[1]
# Out:
# [{'orig_reg_or_dyn': 0, 'orig_well_known': 1},
#  {'resp_123': 0,
#   'resp_22': 1,
#   'resp_443': 2,
#   'resp_53': 3,
#   'resp_80': 4,
#   'resp_dyn': 5,
#   'resp_reg': 6,
#   'resp_well_known': 7},
#  {'icmp': 0, 'tcp': 1, 'udp': 2},
#  {'dns': 0, 'http': 1, 'none': 2, 'ntp': 3, 'ssh': 4, 'ssl': 5},
#  {'OTH': 0, 'RSTO': 1, 'RSTR': 2, 'S0': 3, 'SF': 4},
#  {'icmp': 0, 'tcp': 1, 'udp': 2},
#  {'dns': 0, 'http': 1, 'none': 2, 'ntp': 3, 'ssl': 4},
#  {'OTH': 0, 'RSTO': 1, 'S0': 2, 'SF': 3},
#  {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#  {'-': 0, 'dns': 1, 'none': 2, 'ntp': 3},
#  {'-': 0, 'OTH': 1, 'S0': 2, 'S3': 3, 'SF': 4},
#  {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#  {'-': 0, 'dns': 1, 'none': 2, 'ntp': 3},
#  {'-': 0, 'OTH': 1, 'RSTO': 2, 'S0': 3, 'S3': 4, 'SF': 5},
#  {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#  {'-': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssl': 5},
#  {'-': 0, 'OTH': 1, 'RSTO': 2, 'RSTR': 3, 'S0': 4, 'SF': 5}]

# %%
# np.sum([[0, 1], [0, 5]], axis=1)

# %%
np.sum(df_cat_encoded[0], axis=1)
# Out:
# array([23, 29, 33, 31, 36, 30, 28, 24, 26, 35, 28, 31, 33, 39, 35, 26, 41,
#        33, 24, 40, 36, 35, 17, 32, 30, 30, 23, 24, 40, 39, 40, 30, 19, 43,
#        22, 35, 37, 21, 35, 21, 23, 39, 35, 26, 26, 29, 45, 26, 17, 24, 27,
#        39, 24, 33, 31, 29, 26, 22, 34, 39, 22, 29, 36, 45, 27, 30, 26, 33,
#        31, 39, 24, 44, 14, 30, 26, 24, 26, 40, 53, 26, 39, 44, 23, 39, 24,
#        24, 24, 35, 26, 35, 29, 35, 35, 26, 24, 30, 34, 39, 29, 43])

# %%
sum_dif = 0
obj_cat = df_cat_encoded[0][0]
for obj_cat2 in df_cat_encoded[0]:
    print(np.sum(obj_cat != obj_cat2))
# Out:
# 0
# 16
# 10
# 9
# 6
# 6
# 12
# 10
# 13
# 13
# 11
# 15
# 16
# 8
# 13
# 10
# 16
# 10
# 14
# 10
# 6
# 13
# 11
# 13
# 11
# 10
# 0
# 10
# 16
# 16
# 16
# 3
# 9
# 16
# 1
# 13
# 6
# 10
# 16
# 13
# 0
# 16
# 13
# 10
# 10
# 11
# 13
# 13
# 13
# 10
# 8
# 16
# 10
# 10
# 11
# 7
# 10
# 11
# 8
# 16
# 1
# 4
# 6
# 13
# 15
# 5
# 10
# 10
# 11
# 16
# 10
# 14
# 10
# 12
# 10
# 10
# 10
# 6
# 13
# 10
# 16
# 16
# 9
# 8
# 10
# 8
# 7
# 13
# 10
# 13
# 7
# 13
# 16
# 10
# 7
# 5
# 11
# 8
# 12
# 16

# %%
cat_sim = [] 
for cat_object in df_cat_encoded[0]:
    dissim_val = np.sum(matching_dissim(cat_object, df_cat_encoded[0]))
    print(dissim_val)
    print()
    cat_sim.append(dissim_val)
print(len(cat_sim))
print(cat_sim)

# %%
matching_dissim(df_cat_encoded[0][0], df_cat_encoded[0])
# Out:
# array([ 0, 16, 10,  9,  6,  6, 12, 10, 13, 13, 11, 15, 16,  8, 13, 10, 16,
#        10, 14, 10,  6, 13, 11, 13, 11, 10,  0, 10, 16, 16, 16,  3,  9, 16,
#         1, 13,  6, 10, 16, 13,  0, 16, 13, 10, 10, 11, 13, 13, 13, 10,  8,
#        16, 10, 10, 11,  7, 10, 11,  8, 16,  1,  4,  6, 13, 15,  5, 10, 10,
#        11, 16, 10, 14, 10, 12, 10, 10, 10,  6, 13, 10, 16, 16,  9,  8, 10,
#         8,  7, 13, 10, 13,  7, 13, 16, 10,  7,  5, 11,  8, 12, 16])

# %%
def compute_custom_silhouette(df_numerical, df_categorical, cluster_col_name):
    # if string used as metric specifier, one from https://github.com/scikit-learn/scikit-learn/blob/main/sklearn/metrics/pairwise.py has to be used
    num_sim = silhouette_samples(X=df_numerical.to_numpy(), labels=df_numerical[cluster_col_name].to_numpy(), metric='euclidean')
    print(len(num_sim))
    print(num_sim)
    print(silhouette_score(X=df_numerical.to_numpy(), labels=df_numerical[cluster_col_name].to_numpy(), metric='euclidean'))
    
    cat_sim = [] # np.sum(df_categorical, axis=1)
    for cat_object in df_categorical:
        cat_sim.append(np.sum(matching_dissim(cat_object, df_categorical)))
    print(len(cat_sim))
    print(cat_sim)
    
    #return num_sim
#     cat_sim = silhouette_samples(X=df_categorical, labels=df_numerical[cluster_col_name], metric=matching_dissim)
#     print(cat_sim)
    return num_sim, cat_sim

# %%
# sample_vals_num, sample_vals_cat = compute_custom_silhouette(df_num, df_cat_encoded[0], 'cluster')
sample_num_vals, sample_cat_vals = compute_custom_silhouette(df_num, df_cat_encoded[0], 'cluster')
# Out:
# 100
# [ 0.01382108  0.21938803  0.03369385  0.19205204  0.18990135  0.28381737
#   0.14459961  0.28175022  0.20472173  0.14986963 -0.09544662  0.23799489
#   0.1348915  -0.11949925  0.1935331   0.12465659  0.23387767  0.23448063
#   0.11777858 -0.06925295  0.14596685  0.01661122 -0.10505212  0.06870285
#   0.09655182 -0.10767204  0.18125498  0.11975545 -0.14166507 -0.03494059
#   0.20526635  0.2015661   0.21258898  0.24917097  0.02726643  0.25873076
#   0.18878906  0.19387268  0.04776682  0.12231338  0.03459815  0.22758314
#   0.1995095   0.02380349  0.21733954  0.17708593  0.22428024  0.13869142
#   0.14552795  0.07189179  0.07247317  0.06572092  0.08902487  0.00503956
#   0.0932817  -0.00494678  0.0842377   0.0453694   0.09086    -0.00764806
#   0.24720927  0.19899126  0.19840586  0.12222197  0.2459646   0.21276903
#   0.19281378  0.1152772   0.10450974  0.13148955  0.09220024  0.12271166
#   0.19423805  0.12893744 -0.0999054   0.15401878  0.14432327  0.13244073
#   0.16495996  0.16182568  0.06990852  0.00799597  0.01830941  0.02830723
#   0.09638773 -0.00669861  0.02034192  0.1001367  -0.02022841  0.02065666
#   0.28002133  0.16422668  0.25423862  0.27579472  0.11544093  0.15918518
#   0.14986415  0.05120862  0.26971139  0.28931395]
# 0.1195672288733377
# 100
# [1054, 1071, 1218, 1287, 1177, 1086, 1045, 969, 1065, 756, 1024, 1435, 940, 1214, 756, 768, 1037, 776, 1189, 1085, 1177, 756, 1168, 905, 1140, 1018, 1054, 781, 979, 891, 908, 1075, 879, 990, 998, 756, 1232, 980, 988, 1085, 1054, 891, 756, 768, 768, 907, 1012, 1065, 1051, 781, 920, 891, 969, 776, 803, 923, 768, 988, 1289, 891, 998, 1073, 1242, 1012, 1114, 1154, 768, 1078, 803, 891, 781, 984, 879, 801, 768, 969, 768, 1231, 1099, 768, 891, 936, 877, 1214, 781, 954, 918, 756, 978, 756, 904, 756, 988, 768, 918, 1154, 827, 1214, 1037, 919]

# %%
ultimate_gamma = kprototype.gamma
ultimate_gamma
# Out:
# 0.10987684341100577

# %%
combined_distance = []
for i in range(len(sample_num_vals)):
    combined_distance.append(sample_num_vals[i] + ultimate_gamma * sample_cat_vals[i])

# %%
# best is 1, worst is -1, 0 indicates overlapping clusters
sum(combined_distance) / len(combined_distance)
# Out:
# 106.38146249165706

# %%
# # Computing Silhouette:
# from kmodes.util.dissim import euclidean_dissim


# def compute_avg_dist_within_cluster(example_num, example_cat, cluster_num, cluster_cat):
#     distance_num = 0
#     distance_cat = 0
    
#     for i in range(0, len(cluster_num)):
#         distance_num += euclidean_dissim(example_num, cluster_num)

        
# def compute_custom_silhouette(dfs_list_num, dfs_list_cat, cluster_col_name):
#     # 1. for each example: average distance to all examples in the same cluster:
    
#     distances = []
#     # for each cluster
#     for cl_i in range(0, len(dfs_list_num)):
#         # for each example in cluster
#         avg_dist = 0
#         for ex_i in range(0, len(dfs_list_num[cl_i])):
#             avg_dist_num, avg_dist_cat += compute_avg_dist_within_cluster(dfs_list_num[cl_i][ex_i], dfs_list_cat[cl_i][ex_i], dfs_list_num[cl_i], dfs_list_cat[cl_i])
#         print('Cluster ' + str(cl_i) + ': ')
#         print('Examples: ' + str(len(dfs_list_num[cl_i])))
#         print('All distances within cluster:' + str(avg_dist_num) + ', ' + str(avg_dist_cat))
#         avg_dist_num = 1 / len(dfs_list_num[cl_i]) * avg_dist_num
#         avg_dist_cat = 1 / len(dfs_list_num[cl_i]) * avg_dist_cat
#         print('Avg distance within cluster:' + str(avg_dist_num) + ', ' + str(avg_dist_cat))
#         distances.append((avg_dist_num, avg_dist_cat))

# %%
X = [[0.0,1.0],[1.0,1.0]]
dfTest = pd.DataFrame(X)
dfTest.to_numpy().dtype
# Out:
# dtype('float64')

# %%
dfTest.to_numpy()
# Out:
# array([[0., 1.],
#        [1., 1.]])

# %%
dfTest.to_numpy().T
# Out:
# array([[0., 1.],
#        [1., 1.]])

# %%
df_without_labels = df.drop(['cluster', 'cluster_cat'], axis=1)
df_without_labels
# Out:
#         originated_ip_num  responded_ip_num  connection.time  \
# 0                 0.04572           0.04754          0.00936
# 1                 0.04572           0.25924          0.18505
# 2                 0.04567           0.01362          0.13157
# 3                 0.02044           0.03237          0.76812
# 4                 0.02044           0.03237          0.76715
# ...                   ...               ...              ...
# 472340            0.50789           0.03237          0.93604
# 472341            0.91496           0.03237          0.91409
# 472342            0.36686           0.03237          0.76662
# 472343            0.04574           0.57609          0.11676
# 472344            0.04576           0.01362          0.81682
#
#         connection.duration  connection.orig_bytes  connection.orig_pkts  \
# 0                   0.00405                0.00000               0.00003
# 1                   0.00000                0.00000               0.00001
# 2                   0.00006                0.00000               0.00003
# 3                   0.00000                0.00000               0.00001
# 4                   0.00000                0.00000               0.00001
# ...                     ...                    ...                   ...
# 472340              0.00000                0.00000               0.00001
# 472341              0.00000                0.00000               0.00001
# 472342              0.00000                0.00000               0.00001
# 472343              0.00000                0.00000               0.00001
# 472344              0.00001                0.00000               0.00026
#
#         connection.orig_ip_bytes  connection.resp_bytes  connection.resp_pkts  \
# 0                        0.00001                0.00001               0.00004
# 1                        0.00000                0.00000               0.00002
# 2                        0.00001                0.00000               0.00004
# 3                        0.00000                0.00000               0.00000
# 4                        0.00000                0.00000               0.00000
# ...                          ...                    ...                   ...
# 472340                   0.00000                0.00000               0.00000
# 472341                   0.00000                0.00000               0.00000
# 472342                   0.00000                0.00000               0.00000
# 472343                   0.00000                0.00000               0.00001
# 472344                   0.00007                0.00032               0.00030
#
#         connection.resp_ip_bytes       orig_p_cat       resp_p_cat protocol  \
# 0                        0.00001  orig_reg_or_dyn          resp_80      tcp
# 1                        0.00000  orig_reg_or_dyn          resp_80      tcp
# 2                        0.00001  orig_reg_or_dyn          resp_80      tcp
# 3                        0.00000  orig_reg_or_dyn         resp_reg      tcp
# 4                        0.00000  orig_reg_or_dyn  resp_well_known      tcp
# ...                          ...              ...              ...      ...
# 472340                   0.00000  orig_reg_or_dyn         resp_reg      tcp
# 472341                   0.00000  orig_reg_or_dyn         resp_dyn      tcp
# 472342                   0.00000  orig_reg_or_dyn         resp_reg      tcp
# 472343                   0.00000  orig_well_known         resp_123      udp
# 472344                   0.00043  orig_reg_or_dyn         resp_443      tcp
#
#        service conn_state  dns_count  ssh_count  http_count  ssl_count  \
# 0         http         SF    0.00000    0.00000     1.00000    0.00000
# 1         none     RSTOS0    0.00000    0.00000     0.00000    0.00000
# 2         http       RSTO    0.00000    0.00000     1.00000    0.00000
# 3         none         S0    0.00000    0.00000     0.00000    0.00000
# 4         none         S0    0.00000    0.00000     0.00000    0.00000
# ...        ...        ...        ...        ...         ...        ...
# 472340    none         S0    0.00000    0.00000     0.00000    0.00000
# 472341    none         S0    0.00000    0.00000     0.00000    0.00000
# 472342    none         S0    0.00000    0.00000     0.00000    0.00000
# 472343     ntp         SF    0.00000    0.00000     0.00000    0.00000
# 472344     ssl         SF    0.00000    0.00000     0.00000    1.00000
#
#         files_count  orig_orig_total  orig_orig_connection.time_mean  \
# 0           0.00781          0.00955                         0.00934
# 1           0.00000          0.03799                         0.17812
# 2           0.00781          0.00131                         0.12727
# 3           0.00000          0.33491                         0.77773
# 4           0.00000          0.24313                         0.77720
# ...             ...              ...                             ...
# 472340      0.00000          0.81739                         0.93958
# 472341      0.00000          0.33395                         0.91710
# 472342      0.00000          0.64647                         0.77589
# 472343      0.00000          0.00247                         0.11361
# 472344      0.00781          0.00117                         0.82345
#
#         orig_orig_connection.duration_mean  \
# 0                                  0.00235
# 1                                  0.00031
# 2                                  0.00030
# 3                                  0.00019
# 4                                  0.00010
# ...                                    ...
# 472340                             0.00000
# 472341                             0.00000
# 472342                             0.00024
# 472343                             0.00141
# 472344                             0.00001
#
#         orig_orig_connection.orig_pkts_mean  \
# 0                                   0.00043
# 1                                   0.00154
# 2                                   0.00041
# 3                                   0.00003
# 4                                   0.00003
# ...                                     ...
# 472340                              0.00002
# 472341                              0.00002
# 472342                              0.00008
# 472343                              0.03292
# 472344                              0.00031
#
#         orig_orig_connection.orig_bytes_mean  \
# 0                                    0.00012
# 1                                    0.00004
# 2                                    0.00001
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00001
# 472343                               0.00010
# 472344                               0.00001
#
#         orig_orig_connection.resp_bytes_mean  \
# 0                                    0.00077
# 1                                    0.00663
# 2                                    0.00092
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00001
# 472343                               0.19555
# 472344                               0.00068
#
#         orig_orig_connection.resp_pkts_mean  \
# 0                                   0.00018
# 1                                   0.00060
# 2                                   0.00012
# 3                                   0.00001
# 4                                   0.00001
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00004
# 472343                              0.00902
# 472344                              0.00012
#
#         orig_orig_orig_p_well_known_count  orig_orig_orig_p_reg_or_dyn_count  \
# 0                                 0.00000                            0.00962
# 1                                 0.00000                            0.03806
# 2                                 0.00000                            0.00137
# 3                                 0.00000                            0.33496
# 4                                 0.00000                            0.24318
# ...                                   ...                                ...
# 472340                            0.00000                            0.81741
# 472341                            0.00000                            0.33400
# 472342                            0.00469                            0.64642
# 472343                            0.12676                            0.00069
# 472344                            0.01408                            0.00103
#
#         orig_orig_resp_p_21_count  orig_orig_resp_p_22_count  \
# 0                         0.00000                    0.00000
# 1                         0.00000                    0.00000
# 2                         0.00000                    0.00000
# 3                         0.27778                    0.00125
# 4                         0.27778                    0.00103
# ...                           ...                        ...
# 472340                    0.88889                    0.00160
# 472341                    0.00000                    0.00000
# 472342                    0.33333                    0.30351
# 472343                    0.00000                    0.00000
# 472344                    0.00000                    0.00000
#
#         orig_orig_resp_p_53_count  orig_orig_resp_p_80_count  \
# 0                         0.01273                    0.00251
# 1                         0.02629                    0.04960
# 2                         0.00000                    0.00116
# 3                         0.00125                    0.00116
# 4                         0.00125                    0.00116
# ...                           ...                        ...
# 472340                    0.00271                    0.01679
# 472341                    0.00000                    0.00000
# 472342                    0.00167                    0.00347
# 472343                    0.00083                    0.00077
# 472344                    0.00063                    0.00077
#
#         orig_orig_resp_p_123_count  orig_orig_resp_p_443_count  \
# 0                          0.00000                     0.00891
# 1                          0.00000                     0.02309
# 2                          0.00000                     0.00189
# 3                          0.00000                     0.00068
# 4                          0.00000                     0.00068
# ...                            ...                         ...
# 472340                     0.00000                     0.00662
# 472341                     0.00000                     0.00000
# 472342                     0.00000                     0.00270
# 472343                     0.16463                     0.00000
# 472344                     0.01829                     0.00108
#
#         orig_orig_resp_p_3389_count  orig_orig_resp_p_well_known_count  \
# 0                           0.00000                            0.00000
# 1                           0.00000                            0.00000
# 2                           0.00000                            0.00000
# 3                           0.25000                            0.34864
# 4                           0.25000                            0.21416
# ...                             ...                                ...
# 472340                      0.70000                            0.44380
# 472341                      0.00000                            0.16798
# 472342                      0.50000                            0.42527
# 472343                      0.00000                            0.00000
# 472344                      0.00000                            0.00000
#
#         orig_orig_resp_p_reg_count  orig_orig_resp_p_dyn_count  \
# 0                          0.00000                     0.00000
# 1                          0.00000                     0.00000
# 2                          0.00000                     0.00000
# 3                          0.32136                     0.30378
# 4                          0.24717                     0.22816
# ...                            ...                         ...
# 472340                     0.91983                     0.92438
# 472341                     0.38980                     0.36636
# 472342                     0.45912                     0.51369
# 472343                     0.00020                     0.00000
# 472344                     0.00000                     0.00000
#
#         orig_orig_dns_count_mean  orig_orig_ssh_count_mean  \
# 0                        0.43571                   0.00000
# 1                        0.22744                   0.00000
# 2                        0.00000                   0.00000
# 3                        0.00000                   0.00000
# 4                        0.00000                   0.00000
# ...                          ...                       ...
# 472340                   0.00008                   0.00017
# 472341                   0.00000                   0.00000
# 472342                   0.00011                   0.27404
# 472343                   0.10811                   0.00000
# 472344                   0.16667                   0.00000
#
#         orig_orig_http_count_mean  orig_orig_ssl_count_mean  \
# 0                         0.08571                   0.47143
# 1                         0.45126                   0.29422
# 2                         0.30000                   0.70000
# 3                         0.00000                   0.14274
# 4                         0.00000                   0.08955
# ...                           ...                       ...
# 472340                    0.00311                   0.00210
# 472341                    0.00000                   0.00000
# 472342                    0.00308                   0.08639
# 472343                    0.08108                   0.05405
# 472344                    0.22222                   0.44444
#
#         orig_orig_files_count_mean  orig_orig_similar_conns_count  \
# 0                          0.02321                        0.00000
# 1                          0.02098                        0.00000
# 2                          0.02083                        0.00000
# 3                          0.00081                        0.00000
# 4                          0.00081                        0.00000
# ...                            ...                            ...
# 472340                     0.00006                        0.00000
# 472341                     0.00000                        0.00000
# 472342                     0.00051                        0.00000
# 472343                     0.00169                        0.00863
# 472344                     0.01273                        0.00000
#
#         orig_orig_similar_dns_qtype_count  orig_orig_similar_dns_rcode_count  \
# 0                                 0.00000                            0.00000
# 1                                 0.00000                            0.00000
# 2                                 0.00000                            0.00000
# 3                                 0.00000                            0.00000
# 4                                 0.00000                            0.00000
# ...                                   ...                                ...
# 472340                            0.00000                            0.00000
# 472341                            0.00000                            0.00000
# 472342                            0.00000                            0.00000
# 472343                            0.00000                            0.00000
# 472344                            0.00000                            0.00000
#
#         orig_orig_similar_ssh_auth_attempts_count  \
# 0                                         0.00000
# 1                                         0.00000
# 2                                         0.00000
# 3                                         0.00000
# 4                                         0.00000
# ...                                           ...
# 472340                                    0.00000
# 472341                                    0.00000
# 472342                                    0.00000
# 472343                                    0.00000
# 472344                                    0.00000
#
#         orig_orig_similar_ssh_host_key_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         orig_orig_similar_http_method_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00000
# 472343                              0.00000
# 472344                              0.00000
#
#         orig_orig_similar_http_status_code_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
# ...                                          ...
# 472340                                   0.00000
# 472341                                   0.00000
# 472342                                   0.00000
# 472343                                   0.00000
# 472344                                   0.00000
#
#         orig_orig_similar_http_user_agent_count  \
# 0                                       0.00000
# 1                                       0.00000
# 2                                       0.00000
# 3                                       0.00000
# 4                                       0.00000
# ...                                         ...
# 472340                                  0.00000
# 472341                                  0.00000
# 472342                                  0.00000
# 472343                                  0.00000
# 472344                                  0.00000
#
#         orig_orig_similar_ssl_version_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00000
# 472343                              0.00000
# 472344                              0.00000
#
#         orig_orig_similar_ssl_cipher_count  orig_orig_similar_ssl_curve_count  \
# 0                                  0.00000                            0.00000
# 1                                  0.00000                            0.00000
# 2                                  0.00000                            0.00000
# 3                                  0.00000                            0.00000
# 4                                  0.00000                            0.00000
# ...                                    ...                                ...
# 472340                             0.00000                            0.00000
# 472341                             0.00000                            0.00000
# 472342                             0.00000                            0.00000
# 472343                             0.00000                            0.00000
# 472344                             0.00000                            0.00000
#
#         orig_orig_similar_ssl_validation_status_count  \
# 0                                             0.00000
# 1                                             0.00000
# 2                                             0.00000
# 3                                             0.00000
# 4                                             0.00000
# ...                                               ...
# 472340                                        0.00000
# 472341                                        0.00000
# 472342                                        0.00000
# 472343                                        0.00000
# 472344                                        0.00000
#
#         orig_orig_similar_files_source_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         orig_orig_similar_file_md5_count orig_orig_connection.protocol_mode  \
# 0                                0.00000                                tcp
# 1                                0.00000                                tcp
# 2                                0.00000                                tcp
# 3                                0.00000                                tcp
# 4                                0.00000                                tcp
# ...                                  ...                                ...
# 472340                           0.00000                                tcp
# 472341                           0.00000                                tcp
# 472342                           0.00000                                tcp
# 472343                           0.00000                                udp
# 472344                           0.00000                                tcp
#
#        orig_orig_connection.service_mode orig_orig_connection.conn_state_mode  \
# 0                                    ssl                                   SF
# 1                                   http                                   SF
# 2                                    ssl                                 RSTO
# 3                                   none                                   S0
# 4                                   none                                   S0
# ...                                  ...                                  ...
# 472340                              none                                   S0
# 472341                              none                                   S0
# 472342                              none                                   S0
# 472343                               ntp                                   SF
# 472344                               ssl                                   SF
#
#         orig_resp_total  orig_resp_connection.time_mean  \
# 0               0.00000                         0.00903
# 1               0.00000                         0.17854
# 2               0.00000                         0.12694
# 3               0.00015                         0.77511
# 4               0.00015                         0.77511
# ...                 ...                             ...
# 472340          0.00061                         0.93858
# 472341          0.00000                         0.91712
# 472342          0.00046                         0.77497
# 472343          0.00015                         0.11153
# 472344          0.00000                         0.82326
#
#         orig_resp_connection.duration_mean  \
# 0                                  0.00000
# 1                                  0.00000
# 2                                  0.00000
# 3                                  0.00000
# 4                                  0.00000
# ...                                    ...
# 472340                             0.00019
# 472341                             0.00000
# 472342                             0.00037
# 472343                             0.01090
# 472344                             0.00000
#
#         orig_resp_connection.orig_pkts_mean  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00003
# 4                                   0.00003
# ...                                     ...
# 472340                              0.00028
# 472341                              0.00000
# 472342                              0.00039
# 472343                              0.00014
# 472344                              0.00000
#
#         orig_resp_connection.orig_bytes_mean  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00001
# 472341                               0.00000
# 472342                               0.00001
# 472343                               0.00000
# 472344                               0.00000
#
#         orig_resp_connection.resp_bytes_mean  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00001
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         orig_resp_connection.resp_pkts_mean  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00002
# 4                                   0.00002
# ...                                     ...
# 472340                              0.00005
# 472341                              0.00000
# 472342                              0.00003
# 472343                              0.00006
# 472344                              0.00000
#
#         orig_resp_orig_p_well_known_count  orig_resp_orig_p_reg_or_dyn_count  \
# 0                                 0.00000                            0.00000
# 1                                 0.00000                            0.00000
# 2                                 0.00000                            0.00000
# 3                                 0.03333                            0.00000
# 4                                 0.03333                            0.00000
# ...                                   ...                                ...
# 472340                            0.06667                            0.00030
# 472341                            0.00000                            0.00000
# 472342                            0.06667                            0.00015
# 472343                            0.00000                            0.00015
# 472344                            0.00000                            0.00000
#
#         orig_resp_resp_p_21_count  orig_resp_resp_p_22_count  \
# 0                         0.00000                    0.00000
# 1                         0.00000                    0.00000
# 2                         0.00000                    0.00000
# 3                         0.00000                    0.00000
# 4                         0.00000                    0.00000
# ...                           ...                        ...
# 472340                    0.00000                    0.00000
# 472341                    0.00000                    0.00000
# 472342                    0.00000                    0.00000
# 472343                    0.00000                    0.00000
# 472344                    0.00000                    0.00000
#
#         orig_resp_resp_p_53_count  orig_resp_resp_p_80_count  \
# 0                         0.00000                    0.00000
# 1                         0.00000                    0.00000
# 2                         0.00000                    0.00000
# 3                         0.00000                    0.00000
# 4                         0.00000                    0.00000
# ...                           ...                        ...
# 472340                    0.00000                    0.00000
# 472341                    0.00000                    0.00000
# 472342                    0.00000                    0.00000
# 472343                    0.00000                    0.00000
# 472344                    0.00000                    0.00000
#
#         orig_resp_resp_p_123_count  orig_resp_resp_p_443_count  \
# 0                          0.00000                     0.00000
# 1                          0.00000                     0.00000
# 2                          0.00000                     0.00000
# 3                          0.00000                     0.00000
# 4                          0.00000                     0.00000
# ...                            ...                         ...
# 472340                     0.00000                     0.00000
# 472341                     0.00000                     0.00000
# 472342                     0.00000                     0.00000
# 472343                     0.00000                     0.00000
# 472344                     0.00000                     0.00000
#
#         orig_resp_resp_p_3389_count  orig_resp_resp_p_well_known_count  \
# 0                           0.00000                            0.00000
# 1                           0.00000                            0.00000
# 2                           0.00000                            0.00000
# 3                           0.00000                            0.00000
# 4                           0.00000                            0.00000
# ...                             ...                                ...
# 472340                      0.00000                            0.00141
# 472341                      0.00000                            0.00000
# 472342                      0.00000                            0.00141
# 472343                      0.00000                            0.00000
# 472344                      0.00000                            0.00000
#
#         orig_resp_resp_p_reg_count  orig_resp_resp_p_dyn_count  \
# 0                          0.00000                     0.00000
# 1                          0.00000                     0.00000
# 2                          0.00000                     0.00000
# 3                          0.00032                     0.00000
# 4                          0.00032                     0.00000
# ...                            ...                         ...
# 472340                     0.00000                     0.00599
# 472341                     0.00000                     0.00000
# 472342                     0.00032                     0.00000
# 472343                     0.00032                     0.00000
# 472344                     0.00000                     0.00000
#
#         orig_resp_dns_count_mean  orig_resp_ssh_count_mean  \
# 0                        0.00000                   0.00000
# 1                        0.00000                   0.00000
# 2                        0.00000                   0.00000
# 3                        0.00000                   0.00000
# 4                        0.00000                   0.00000
# ...                          ...                       ...
# 472340                   0.00000                   0.00000
# 472341                   0.00000                   0.00000
# 472342                   0.00000                   0.00000
# 472343                   0.00000                   0.00000
# 472344                   0.00000                   0.00000
#
#         orig_resp_http_count_mean  orig_resp_ssl_count_mean  \
# 0                         0.00000                   0.00000
# 1                         0.00000                   0.00000
# 2                         0.00000                   0.00000
# 3                         0.00000                   0.00000
# 4                         0.00000                   0.00000
# ...                           ...                       ...
# 472340                    0.00000                   0.00000
# 472341                    0.00000                   0.00000
# 472342                    0.00000                   0.00000
# 472343                    0.00000                   0.00000
# 472344                    0.00000                   0.00000
#
#         orig_resp_files_count_mean  orig_resp_similar_conns_count  \
# 0                          0.00000                        0.00000
# 1                          0.00000                        0.00000
# 2                          0.00000                        0.00000
# 3                          0.00000                        0.00000
# 4                          0.00000                        0.00000
# ...                            ...                            ...
# 472340                     0.00000                        0.00000
# 472341                     0.00000                        0.00000
# 472342                     0.00000                        0.00000
# 472343                     0.00000                        0.00000
# 472344                     0.00000                        0.00000
#
#         orig_resp_similar_dns_qtype_count  orig_resp_similar_dns_rcode_count  \
# 0                                 0.00000                            0.00000
# 1                                 0.00000                            0.00000
# 2                                 0.00000                            0.00000
# 3                                 0.00000                            0.00000
# 4                                 0.00000                            0.00000
# ...                                   ...                                ...
# 472340                            0.00000                            0.00000
# 472341                            0.00000                            0.00000
# 472342                            0.00000                            0.00000
# 472343                            0.00000                            0.00000
# 472344                            0.00000                            0.00000
#
#         orig_resp_similar_ssh_auth_attempts_count  \
# 0                                         0.00000
# 1                                         0.00000
# 2                                         0.00000
# 3                                         0.00000
# 4                                         0.00000
# ...                                           ...
# 472340                                    0.00000
# 472341                                    0.00000
# 472342                                    0.00000
# 472343                                    0.00000
# 472344                                    0.00000
#
#         orig_resp_similar_ssh_host_key_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         orig_resp_similar_http_method_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00000
# 472343                              0.00000
# 472344                              0.00000
#
#         orig_resp_similar_http_status_code_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
# ...                                          ...
# 472340                                   0.00000
# 472341                                   0.00000
# 472342                                   0.00000
# 472343                                   0.00000
# 472344                                   0.00000
#
#         orig_resp_similar_http_user_agent_count  \
# 0                                       0.00000
# 1                                       0.00000
# 2                                       0.00000
# 3                                       0.00000
# 4                                       0.00000
# ...                                         ...
# 472340                                  0.00000
# 472341                                  0.00000
# 472342                                  0.00000
# 472343                                  0.00000
# 472344                                  0.00000
#
#         orig_resp_similar_ssl_version_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00000
# 472343                              0.00000
# 472344                              0.00000
#
#         orig_resp_similar_ssl_cipher_count  orig_resp_similar_ssl_curve_count  \
# 0                                  0.00000                            0.00000
# 1                                  0.00000                            0.00000
# 2                                  0.00000                            0.00000
# 3                                  0.00000                            0.00000
# 4                                  0.00000                            0.00000
# ...                                    ...                                ...
# 472340                             0.00000                            0.00000
# 472341                             0.00000                            0.00000
# 472342                             0.00000                            0.00000
# 472343                             0.00000                            0.00000
# 472344                             0.00000                            0.00000
#
#         orig_resp_similar_ssl_validation_status_count  \
# 0                                             0.00000
# 1                                             0.00000
# 2                                             0.00000
# 3                                             0.00000
# 4                                             0.00000
# ...                                               ...
# 472340                                        0.00000
# 472341                                        0.00000
# 472342                                        0.00000
# 472343                                        0.00000
# 472344                                        0.00000
#
#         orig_resp_similar_files_source_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         orig_resp_similar_file_md5_count orig_resp_connection.protocol_mode  \
# 0                                0.00000                                  -
# 1                                0.00000                                  -
# 2                                0.00000                                  -
# 3                                0.00000                                tcp
# 4                                0.00000                                tcp
# ...                                  ...                                ...
# 472340                           0.00000                               icmp
# 472341                           0.00000                                  -
# 472342                           0.00000                               icmp
# 472343                           0.00000                                tcp
# 472344                           0.00000                                  -
#
#        orig_resp_connection.service_mode orig_resp_connection.conn_state_mode  \
# 0                                      -                                    -
# 1                                      -                                    -
# 2                                      -                                    -
# 3                                   none                                  REJ
# 4                                   none                                  REJ
# ...                                  ...                                  ...
# 472340                              none                                  OTH
# 472341                                 -                                    -
# 472342                              none                                  OTH
# 472343                              none                                   SF
# 472344                                 -                                    -
#
#         resp_orig_total  resp_orig_connection.time_mean  \
# 0               0.00000                         0.00903
# 1               0.00000                         0.17854
# 2               0.00000                         0.12694
# 3               0.00034                         0.77578
# 4               0.00042                         0.77512
# ...                 ...                             ...
# 472340          0.01393                         0.93803
# 472341          0.00050                         0.91779
# 472342          0.00008                         0.77532
# 472343          0.00050                         0.11146
# 472344          0.00017                         0.82299
#
#         resp_orig_connection.duration_mean  \
# 0                                  0.00000
# 1                                  0.00000
# 2                                  0.00000
# 3                                  0.00000
# 4                                  0.00000
# ...                                    ...
# 472340                             0.00000
# 472341                             0.00000
# 472342                             0.00023
# 472343                             0.00096
# 472344                             0.00000
#
#         resp_orig_connection.orig_pkts_mean  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00002
# 4                                   0.00002
# ...                                     ...
# 472340                              0.00002
# 472341                              0.00002
# 472342                              0.00008
# 472343                              0.00004
# 472344                              0.00002
#
#         resp_orig_connection.orig_bytes_mean  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         resp_orig_connection.resp_bytes_mean  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00001
# 472341                               0.00001
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         resp_orig_connection.resp_pkts_mean  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00001
# 4                                   0.00001
# ...                                     ...
# 472340                              0.00001
# 472341                              0.00001
# 472342                              0.00004
# 472343                              0.00001
# 472344                              0.00000
#
#         resp_orig_orig_p_well_known_count  resp_orig_orig_p_reg_or_dyn_count  \
# 0                                 0.00000                            0.00000
# 1                                 0.00000                            0.00000
# 2                                 0.00000                            0.00000
# 3                                 0.00478                            0.00025
# 4                                 0.00478                            0.00034
# ...                                   ...                                ...
# 472340                            0.00478                            0.01385
# ...
# 0                                 0.00000                            0.00012
# 1                                 0.00000                            0.00049
# 2                                 0.64516                            0.03483
# 3                                 0.00000                            0.10069
# 4                                 0.00000                            0.06034
# ...                                   ...                                ...
# 472340                            0.00000                            0.23927
# 472341                            0.00000                            0.09566
# 472342                            0.00000                            0.25067
# 472343                            0.80645                            0.00000
# 472344                            0.54839                            0.01692
#
#         resp_resp_resp_p_21_count  resp_resp_resp_p_22_count  \
# 0                         0.00000                    0.00000
# 1                         0.00000                    0.00000
# 2                         0.00000                    0.00000
# 3                         0.16667                    0.00100
# 4                         0.16667                    0.00100
# ...                           ...                        ...
# 472340                    0.33333                    0.00100
# 472341                    0.00000                    0.00000
# 472342                    0.33333                    0.00100
# 472343                    0.00000                    0.00000
# 472344                    0.00000                    0.00000
#
#         resp_resp_resp_p_53_count  resp_resp_resp_p_80_count  \
# 0                         0.00000                    0.00028
# 1                         0.00000                    0.00114
# 2                         0.00000                    0.02707
# 3                         0.00188                    0.00000
# 4                         0.00188                    0.00085
# ...                           ...                        ...
# 472340                    0.01129                    0.00057
# 472341                    0.00376                    0.00000
# 472342                    0.00188                    0.00256
# 472343                    0.00000                    0.00000
# 472344                    0.00000                    0.01311
#
#         resp_resp_resp_p_123_count  resp_resp_resp_p_443_count  \
# 0                          0.00000                     0.00000
# 1                          0.00000                     0.00000
# 2                          0.00000                     0.02797
# 3                          0.00000                     0.00030
# 4                          0.00000                     0.00044
# ...                            ...                         ...
# 472340                     0.00000                     0.00015
# 472341                     0.00000                     0.00000
# 472342                     0.00000                     0.00148
# 472343                     0.80645                     0.00000
# 472344                     0.00000                     0.01361
#
#         resp_resp_resp_p_3389_count  resp_resp_resp_p_well_known_count  \
# 0                           0.00000                            0.00000
# 1                           0.00000                            0.00000
# 2                           0.00000                            0.01241
# 3                           0.20000                            0.08747
# 4                           0.20000                            0.06328
# ...                             ...                                ...
# 472340                      0.20000                            0.17990
# 472341                      0.00000                            0.05831
# 472342                      0.80000                            0.18114
# 472343                      0.00000                            0.00000
# 472344                      0.00000                            0.01055
#
#         resp_resp_resp_p_reg_count  resp_resp_resp_p_dyn_count  \
# 0                          0.00000                     0.00000
# 1                          0.00000                     0.00000
# 2                          0.00000                     0.00000
# 3                          0.20000                     0.11782
# 4                          0.11143                     0.07471
# ...                            ...                         ...
# 472340                     0.48635                     0.31034
# 472341                     0.20444                     0.10920
# 472342                     0.48984                     0.50575
# 472343                     0.00000                     0.00000
# 472344                     0.00000                     0.00000
#
#         resp_resp_dns_count_mean  resp_resp_ssh_count_mean  \
# 0                        0.00000                   0.00000
# 1                        0.00000                   0.00000
# 2                        0.00000                   0.00000
# 3                        0.00000                   0.00000
# 4                        0.00000                   0.00000
# ...                          ...                       ...
# 472340                   0.00051                   0.00051
# 472341                   0.00000                   0.00000
# 472342                   0.00000                   0.00000
# 472343                   0.00000                   0.00000
# 472344                   0.00000                   0.00000
#
#         resp_resp_http_count_mean  resp_resp_ssl_count_mean  \
# 0                         1.00000                   0.00000
# 1                         0.75000                   0.00000
# 2                         0.31250                   0.59539
# 3                         0.00000                   0.00000
# 4                         0.00203                   0.00203
# ...                           ...                       ...
# 472340                    0.00000                   0.00000
# 472341                    0.00000                   0.00000
# 472342                    0.01125                   0.00489
# 472343                    0.00000                   0.00000
# 472344                    0.29032                   0.58065
#
#         resp_resp_files_count_mean  resp_resp_similar_conns_count  \
# 0                          0.00781                        0.00000
# 1                          0.00195                        0.00000
# 2                          0.00691                        0.00000
# 3                          0.00000                        0.00000
# 4                          0.00003                        0.00000
# ...                            ...                            ...
# 472340                     0.00000                        0.00000
# 472341                     0.00000                        0.00000
# 472342                     0.00007                        0.00000
# 472343                     0.00000                        0.06069
# 472344                     0.00670                        0.00000
#
#         resp_resp_similar_dns_qtype_count  resp_resp_similar_dns_rcode_count  \
# 0                                 0.00000                            0.00000
# 1                                 0.00000                            0.00000
# 2                                 0.00000                            0.00000
# 3                                 0.00000                            0.00000
# 4                                 0.00000                            0.00000
# ...                                   ...                                ...
# 472340                            0.00000                            0.00000
# 472341                            0.00000                            0.00000
# 472342                            0.00000                            0.00000
# 472343                            0.00000                            0.00000
# 472344                            0.00000                            0.00000
#
#         resp_resp_similar_ssh_auth_attempts_count  \
# 0                                         0.00000
# 1                                         0.00000
# 2                                         0.00000
# 3                                         0.00000
# 4                                         0.00000
# ...                                           ...
# 472340                                    0.00000
# 472341                                    0.00000
# 472342                                    0.00000
# 472343                                    0.00000
# 472344                                    0.00000
#
#         resp_resp_similar_ssh_host_key_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         resp_resp_similar_http_method_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00000
# 472343                              0.00000
# 472344                              0.00000
#
#         resp_resp_similar_http_status_code_count  \
# 0                                        0.00000
# 1                                        0.00000
# 2                                        0.00000
# 3                                        0.00000
# 4                                        0.00000
# ...                                          ...
# 472340                                   0.00000
# 472341                                   0.00000
# 472342                                   0.00000
# 472343                                   0.00000
# 472344                                   0.00000
#
#         resp_resp_similar_http_user_agent_count  \
# 0                                       0.00000
# 1                                       0.00000
# 2                                       0.00000
# 3                                       0.00000
# 4                                       0.00000
# ...                                         ...
# 472340                                  0.00000
# 472341                                  0.00000
# 472342                                  0.00000
# 472343                                  0.00000
# 472344                                  0.00000
#
#         resp_resp_similar_ssl_version_count  \
# 0                                   0.00000
# 1                                   0.00000
# 2                                   0.00000
# 3                                   0.00000
# 4                                   0.00000
# ...                                     ...
# 472340                              0.00000
# 472341                              0.00000
# 472342                              0.00000
# 472343                              0.00000
# 472344                              0.00000
#
#         resp_resp_similar_ssl_cipher_count  resp_resp_similar_ssl_curve_count  \
# 0                                  0.00000                            0.00000
# 1                                  0.00000                            0.00000
# 2                                  0.00000                            0.00000
# 3                                  0.00000                            0.00000
# 4                                  0.00000                            0.00000
# ...                                    ...                                ...
# 472340                             0.00000                            0.00000
# 472341                             0.00000                            0.00000
# 472342                             0.00000                            0.00000
# 472343                             0.00000                            0.00000
# 472344                             0.00000                            0.00000
#
#         resp_resp_similar_ssl_validation_status_count  \
# 0                                             0.00000
# 1                                             0.00000
# 2                                             0.00000
# 3                                             0.00000
# 4                                             0.00000
# ...                                               ...
# 472340                                        0.00000
# 472341                                        0.00000
# 472342                                        0.00000
# 472343                                        0.00000
# 472344                                        0.00000
#
#         resp_resp_similar_files_source_count  \
# 0                                    0.00000
# 1                                    0.00000
# 2                                    0.00000
# 3                                    0.00000
# 4                                    0.00000
# ...                                      ...
# 472340                               0.00000
# 472341                               0.00000
# 472342                               0.00000
# 472343                               0.00000
# 472344                               0.00000
#
#         resp_resp_similar_file_md5_count resp_resp_connection.protocol_mode  \
# 0                                0.00000                                tcp
# 1                                0.00000                                tcp
# 2                                0.00000                                tcp
# 3                                0.00000                                tcp
# 4                                0.00000                                tcp
# ...                                  ...                                ...
# 472340                           0.00000                                tcp
# 472341                           0.00000                                tcp
# 472342                           0.00000                                tcp
# 472343                           0.00000                                udp
# 472344                           0.00000                                tcp
#
#        resp_resp_connection.service_mode resp_resp_connection.conn_state_mode
# 0                                   http                                   SF
# 1                                   http                                 RSTO
# 2                                    ssl                                 RSTO
# 3                                   none                                   S0
# 4                                   none                                   S0
# ...                                  ...                                  ...
# 472340                              none                                   S0
# 472341                              none                                   S0
# 472342                              none                                   S0
# 472343                               ntp                                   SF
# 472344                               ssl                                 RSTO
#
# [472345 rows x 184 columns]

# %%
df_only_labels = df[['cluster', 'cluster_cat']]
df_only_labels
# Out:
#         cluster cluster_cat
# 0             3           3
# 1             3           3
# 2             3           3
# 3             1           1
# 4             1           1
# ...         ...         ...
# 472340        6           6
# 472341        1           1
# 472342        6           6
# 472343        3           3
# 472344        9           9
#
# [472345 rows x 2 columns]

# %%
from datetime import datetime
from sklearn.metrics import davies_bouldin_score
from sklearn import metrics

print('Start at ' + datetime.now().strftime("%H:%M:%S") + '.')
sil_score = metrics.silhouette_score(df_without_labels, df_only_labels, metric=chunga)
print('Silhouette Score for k = ' + str(k + 1) + ': ' + str(sil_score))
    
print('End at ' + datetime.now().strftime("%H:%M:%S") + '.')
    
print('--')
# Out:
# Start at 21:49:43.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-0256ef9c37dc> in <module>
#       4
#       5 print('Start at ' + datetime.now().strftime("%H:%M:%S") + '.')
# ----> 6 sil_score = metrics.silhouette_score(df_without_labels, df_only_labels, metric=chunga)
#       7 print('Silhouette Score for k = ' + str(k + 1) + ': ' + str(sil_score))
#       8
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     212
#     213     """
# --> 214     X, labels = check_X_y(X, labels, accept_sparse=['csc', 'csr'])
#     215
#     216     # Check for non-zero diagonal entries in precomputed distance matrix
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'orig_reg_or_dyn'

# %%
df
# Out:
#         originated_ip_num  responded_ip_num  connection.time  \
# 318879            0.02044           0.03237          0.76997
# 211256            0.04574           0.01362          0.76758
# 349221            0.36686           0.03237          0.77372
# 176657            0.04569           0.01362          0.17844
# 414104            0.02325           0.03237          0.78725
# ...                   ...               ...              ...
# 336122            0.96948           0.03237          0.00314
# 89146             0.04574           0.73395          0.91031
# 194066            0.36686           0.03237          0.76664
# 89715             0.04226           0.01362          0.09961
# 255922            0.36686           0.03237          0.77518
#
#         connection.duration  connection.orig_bytes  connection.orig_pkts  \
# 318879              0.00057                0.00000               0.00011
# 211256              0.00002                0.00000               0.00003
# 349221              0.00046                0.00000               0.00008
# 176657              0.00001                0.00000               0.00018
# 414104              0.00000                0.00000               0.00001
# ...                     ...                    ...                   ...
# 336122              0.00000                0.00000               0.00001
# 89146               0.00000                0.00000               0.00001
# 194066              0.00000                0.00000               0.00001
# 89715               0.00000                0.00000               0.00001
# 255922              0.00000                0.00000               0.00001
#
#         connection.orig_ip_bytes  connection.resp_bytes  connection.resp_pkts  \
# 318879                   0.00005                0.00001               0.00026
# 211256                   0.00001                0.00000               0.00003
# 349221                   0.00004                0.00001               0.00015
# 176657                   0.00004                0.00033               0.00024
# 414104                   0.00000                0.00000               0.00000
# ...                          ...                    ...                   ...
# 336122                   0.00000                0.00000               0.00000
# 89146                    0.00000                0.00000               0.00000
# 194066                   0.00000                0.00000               0.00000
# 89715                    0.00000                0.00000               0.00001
# 255922                   0.00000                0.00000               0.00000
#
#         connection.resp_ip_bytes       orig_p_cat resp_p_cat protocol service  \
# 318879                   0.00001  orig_reg_or_dyn    resp_22      tcp     ssh
# 211256                   0.00000  orig_reg_or_dyn    resp_80      tcp    http
# 349221                   0.00001  orig_reg_or_dyn    resp_22      tcp     ssh
# 176657                   0.00041  orig_reg_or_dyn   resp_443      tcp     ssl
# 414104                   0.00000  orig_reg_or_dyn    resp_80      tcp    none
# ...                          ...              ...        ...      ...     ...
# 336122                   0.00000  orig_reg_or_dyn   resp_reg      tcp    none
# 89146                    0.00000  orig_reg_or_dyn   resp_443      tcp    none
# 194066                   0.00000  orig_reg_or_dyn   resp_reg      tcp    none
# 89715                    0.00000  orig_reg_or_dyn    resp_53      udp     dns
# 255922                   0.00000  orig_reg_or_dyn   resp_reg      tcp    none
#
#        conn_state  dns_count  ssh_count  http_count  ssl_count  files_count  \
# 318879         SF    0.00000    1.00000     0.00000    0.00000      0.00000
# 211256       RSTO    0.00000    0.00000     1.00000    0.00000      0.00781
# 349221         SF    0.00000    1.00000     0.00000    0.00000      0.00000
# 176657       RSTO    0.00000    0.00000     0.00000    1.00000      0.00781
# 414104         S0    0.00000    0.00000     0.00000    0.00000      0.00000
# ...           ...        ...        ...         ...        ...          ...
# 336122         S0    0.00000    0.00000     0.00000    0.00000      0.00000
# 89146          S0    0.00000    0.00000     0.00000    0.00000      0.00000
# 194066         S0    0.00000    0.00000     0.00000    0.00000      0.00000
# 89715          SF    1.00000    0.00000     0.00000    0.00000      0.00000
# 255922         S0    0.00000    0.00000     0.00000    0.00000      0.00000
#
#         orig_orig_total  orig_orig_connection.time_mean  \
# 318879          0.46084                         0.77926
# 211256          0.00131                         0.77686
# 349221          0.86507                         0.78238
# 176657          0.00089                         0.17213
# 414104          0.09336                         0.79747
# ...                 ...                             ...
# 336122          0.27459                         0.00302
# 89146           0.02356                         0.91483
# 194066          0.65045                         0.77591
# 89715           0.03009                         0.09602
# 255922          0.72808                         0.78289
#
#         orig_orig_connection.duration_mean  \
# 318879                             0.00038
# 211256                             0.00031
# 349221                             0.00023
# 176657                             0.00001
# 414104                             0.00003
# ...                                    ...
# 336122                             0.00000
# 89146                              0.00024
# 194066                             0.00024
# 89715                              0.00000
# 255922                             0.00027
#
#         orig_orig_connection.orig_pkts_mean  \
# 318879                              0.00020
# 211256                              0.00056
# 349221                              0.00011
# 176657                              0.00030
# 414104                              0.00003
# ...                                     ...
# 336122                              0.00002
# 89146                               0.00004
# 194066                              0.00008
# 89715                               0.00002
# 255922                              0.00011
#
#         orig_orig_connection.orig_bytes_mean  \
# 318879                               0.00002
# 211256                               0.00001
# 349221                               0.00001
# 176657                               0.00001
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00001
# 89715                                0.00000
# 255922                               0.00001
#
#         orig_orig_connection.resp_bytes_mean  \
# 318879                               0.00002
# 211256                               0.00092
# 349221                               0.00001
# 176657                               0.00087
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00001
# 194066                               0.00001
# 89715                                0.00001
# 255922                               0.00001
#
#         orig_orig_connection.resp_pkts_mean  \
# 318879                              0.00013
# 211256                              0.00016
# 349221                              0.00007
# 176657                              0.00011
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00001
# 194066                              0.00004
# 89715                               0.00001
# 255922                              0.00006
#
#         orig_orig_orig_p_well_known_count  orig_orig_orig_p_reg_or_dyn_count  \
# 318879                            0.00000                            0.46088
# 211256                            0.00000                            0.00137
# 349221                            0.00000                            0.86508
# 176657                            0.00000                            0.00096
# 414104                            0.00000                            0.09343
# ...                                   ...                                ...
# 336122                            0.00469                            0.27458
# 89146                             0.00000                            0.02363
# 194066                            0.00469                            0.65041
# 89715                             0.00000                            0.03016
# 255922                            0.00000                            0.72810
#
#         orig_orig_resp_p_21_count  orig_orig_resp_p_22_count  \
# 318879                    0.00000                    0.74949
# 211256                    0.00000                    0.00000
# 349221                    0.33333                    0.75336
# 176657                    0.00000                    0.00000
# 414104                    0.00000                    0.00000
# ...                           ...                        ...
# 336122                    0.22222                    0.00046
# 89146                     0.00000                    0.00000
# 194066                    0.33333                    0.31012
# 89715                     0.00000                    0.00000
# 255922                    0.33333                    0.51881
#
#         orig_orig_resp_p_53_count  orig_orig_resp_p_80_count  \
# 318879                    0.00000                    0.00000
# 211256                    0.00000                    0.00116
# 349221                    0.00167                    0.00347
# 176657                    0.00000                    0.00116
# 414104                    0.00000                    0.26115
# ...                           ...                        ...
# 336122                    0.00125                    0.00077
# 89146                     0.00000                    0.00019
# 194066                    0.00167                    0.00347
# 89715                     0.09161                    0.00000
# 255922                    0.00167                    0.00347
#
#         orig_orig_resp_p_123_count  orig_orig_resp_p_443_count  \
# 318879                     0.00000                     0.00000
# 211256                     0.00000                     0.00189
# 349221                     0.00000                     0.00311
# 176657                     0.00000                     0.00108
# 414104                     0.00000                     0.00095
# ...                            ...                         ...
# 336122                     0.00000                     0.00095
# 89146                      0.00000                     0.04631
# 194066                     0.00000                     0.00270
# 89715                      0.00000                     0.00000
# 255922                     0.00000                     0.00311
#
#         orig_orig_resp_p_3389_count  orig_orig_resp_p_well_known_count  \
# 318879                      0.00000                            0.03375
# 211256                      0.00000                            0.00000
# 349221                      0.40000                            0.24968
# 176657                      0.00000                            0.00000
# 414104                      0.00000                            0.00000
# ...                             ...                                ...
# 336122                      0.25000                            0.14666
# 89146                       0.00000                            0.00000
# 194066                      0.50000                            0.42527
# 89715                       0.00000                            0.00000
# 255922                      0.40000                            0.26592
#
#         orig_orig_resp_p_reg_count  orig_orig_resp_p_dyn_count  \
# 318879                     0.00000                     0.00000
# 211256                     0.00000                     0.00000
# 349221                     0.45206                     0.50978
# 176657                     0.00000                     0.00000
# 414104                     0.00000                     0.00000
# ...                            ...                         ...
# 336122                     0.30933                     0.36506
# 89146                      0.00000                     0.00000
# 194066                     0.45912                     0.51369
# 89715                      0.00000                     0.00000
# 255922                     0.45206                     0.50978
#
#         orig_orig_dns_count_mean  orig_orig_ssh_count_mean  \
# 318879                   0.00000                   0.94589
# 211256                   0.00000                   0.00000
# 349221                   0.00008                   0.50536
# 176657                   0.00000                   0.00000
# 414104                   0.00000                   0.00000
# ...                          ...                       ...
# 336122                   0.00025                   0.00025
# 89146                    0.00000                   0.00000
# 194066                   0.00011                   0.27849
# 89715                    1.00000                   0.00000
# 255922                   0.00009                   0.41400
#
#         orig_orig_http_count_mean  orig_orig_ssl_count_mean  \
# 318879                    0.00000                   0.01908
# 211256                    0.30000                   0.70000
# 349221                    0.00262                   0.01183
# 176657                    0.28571                   0.35714
# 414104                    0.00147                   0.00000
# ...                           ...                       ...
# 336122                    0.00500                   0.00075
# 89146                     0.00291                   0.04651
# 194066                    0.00306                   0.08586
# 89715                     0.00000                   0.00000
# 255922                    0.00311                   0.01981
#
#         orig_orig_files_count_mean  orig_orig_similar_conns_count  \
# 318879                     0.00039                        0.00000
# 211256                     0.02292                        0.00000
# 349221                     0.00026                        0.00000
# 176657                     0.01339                        0.00000
# 414104                     0.00003                        0.00000
# ...                            ...                            ...
# 336122                     0.00002                        0.00000
# 89146                      0.00206                        0.00000
# 194066                     0.00051                        0.00000
# 89715                      0.00000                        0.00000
# 255922                     0.00043                        0.00000
#
#         orig_orig_similar_dns_qtype_count  orig_orig_similar_dns_rcode_count  \
# 318879                            0.00000                            0.00000
# 211256                            0.00000                            0.00000
# 349221                            0.00000                            0.00000
# 176657                            0.00000                            0.00000
# 414104                            0.00000                            0.00000
# ...                                   ...                                ...
# 336122                            0.00000                            0.00000
# 89146                             0.00000                            0.00000
# 194066                            0.00000                            0.00000
# 89715                             0.00000                            0.00000
# 255922                            0.00000                            0.00000
#
#         orig_orig_similar_ssh_auth_attempts_count  \
# 318879                                    0.00000
# 211256                                    0.00000
# 349221                                    0.00000
# 176657                                    0.00000
# 414104                                    0.00000
# ...                                           ...
# 336122                                    0.00000
# 89146                                     0.00000
# 194066                                    0.00000
# 89715                                     0.00000
# 255922                                    0.00000
#
#         orig_orig_similar_ssh_host_key_count  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         orig_orig_similar_http_method_count  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00000
# 194066                              0.00000
# 89715                               0.00000
# 255922                              0.00000
#
#         orig_orig_similar_http_status_code_count  \
# 318879                                   0.00000
# 211256                                   0.00000
# 349221                                   0.00000
# 176657                                   0.00000
# 414104                                   0.00000
# ...                                          ...
# 336122                                   0.00000
# 89146                                    0.00000
# 194066                                   0.00000
# 89715                                    0.00000
# 255922                                   0.00000
#
#         orig_orig_similar_http_user_agent_count  \
# 318879                                  0.00000
# 211256                                  0.00000
# 349221                                  0.00000
# 176657                                  0.00000
# 414104                                  0.00000
# ...                                         ...
# 336122                                  0.00000
# 89146                                   0.00000
# 194066                                  0.00000
# 89715                                   0.00000
# 255922                                  0.00000
#
#         orig_orig_similar_ssl_version_count  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00000
# 194066                              0.00000
# 89715                               0.00000
# 255922                              0.00000
#
#         orig_orig_similar_ssl_cipher_count  orig_orig_similar_ssl_curve_count  \
# 318879                             0.00000                            0.00000
# 211256                             0.00000                            0.00000
# 349221                             0.00000                            0.00000
# 176657                             0.00000                            0.00000
# 414104                             0.00000                            0.00000
# ...                                    ...                                ...
# 336122                             0.00000                            0.00000
# 89146                              0.00000                            0.00000
# 194066                             0.00000                            0.00000
# 89715                              0.00000                            0.00000
# 255922                             0.00000                            0.00000
#
#         orig_orig_similar_ssl_validation_status_count  \
# 318879                                        0.00000
# 211256                                        0.00000
# 349221                                        0.00000
# 176657                                        0.00000
# 414104                                        0.00000
# ...                                               ...
# 336122                                        0.00000
# 89146                                         0.00000
# 194066                                        0.00000
# 89715                                         0.00000
# 255922                                        0.00000
#
#         orig_orig_similar_files_source_count  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         orig_orig_similar_file_md5_count orig_orig_connection.protocol_mode  \
# 318879                           0.00000                                tcp
# 211256                           0.00000                                tcp
# 349221                           0.00000                                tcp
# 176657                           0.00000                                tcp
# 414104                           0.00000                                tcp
# ...                                  ...                                ...
# 336122                           0.00000                                tcp
# 89146                            0.00000                                tcp
# 194066                           0.00000                                tcp
# 89715                            0.00000                                udp
# 255922                           0.00000                                tcp
#
#        orig_orig_connection.service_mode orig_orig_connection.conn_state_mode  \
# 318879                              none                                   SF
# 211256                               ssl                                 RSTO
# 349221                              none                                   S0
# 176657                              none                                 RSTO
# 414104                              none                                   S0
# ...                                  ...                                  ...
# 336122                              none                                   S0
# 89146                               none                                   S0
# 194066                              none                                   S0
# 89715                                dns                                   SF
# 255922                              none                                   S0
#
#         orig_resp_total  orig_resp_connection.time_mean  \
# 318879          0.00000                         0.77806
# 211256          0.00000                         0.77576
# 349221          0.00000                         0.78169
# 176657          0.00000                         0.17216
# 414104          0.00000                         0.79474
# ...                 ...                             ...
# 336122          0.00046                         0.00325
# 89146           0.00000                         0.91347
# 194066          0.00046                         0.77497
# 89715           0.00122                         0.09600
# 255922          0.00061                         0.78307
#
#         orig_resp_connection.duration_mean  \
# 318879                             0.00000
# 211256                             0.00000
# 349221                             0.00000
# 176657                             0.00000
# 414104                             0.00000
# ...                                    ...
# 336122                             0.00034
# 89146                              0.00000
# 194066                             0.00037
# 89715                              0.00000
# 255922                             0.00038
#
#         orig_resp_connection.orig_pkts_mean  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00023
# 89146                               0.00000
# 194066                              0.00039
# 89715                               0.00004
# 255922                              0.00033
#
#         orig_resp_connection.orig_bytes_mean  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00001
# 89715                                0.00000
# 255922                               0.00001
#
#         orig_resp_connection.resp_bytes_mean  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00001
# 255922                               0.00000
#
#         orig_resp_connection.resp_pkts_mean  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00005
# 89146                               0.00000
# 194066                              0.00003
# 89715                               0.00002
# 255922                              0.00002
#
#         orig_resp_orig_p_well_known_count  orig_resp_orig_p_reg_or_dyn_count  \
# 318879                            0.00000                            0.00000
# 211256                            0.00000                            0.00000
# 349221                            0.00000                            0.00000
# 176657                            0.00000                            0.00000
# 414104                            0.00000                            0.00000
# ...                                   ...                                ...
# 336122                            0.03333                            0.00030
# 89146                             0.00000                            0.00000
# 194066                            0.06667                            0.00015
# 89715                             0.03333                            0.00106
# 255922                            0.06667                            0.00030
#
#         orig_resp_resp_p_21_count  orig_resp_resp_p_22_count  \
# 318879                    0.00000                    0.00000
# 211256                    0.00000                    0.00000
# 349221                    0.00000                    0.00000
# 176657                    0.00000                    0.00000
# 414104                    0.00000                    0.00000
# ...                           ...                        ...
# 336122                    0.00000                    0.00000
# 89146                     0.00000                    0.00000
# 194066                    0.00000                    0.00000
# 89715                     0.00000                    0.00000
# 255922                    0.00000                    0.00000
#
#         orig_resp_resp_p_53_count  orig_resp_resp_p_80_count  \
# 318879                    0.00000                    0.00000
# 211256                    0.00000                    0.00000
# 349221                    0.00000                    0.00000
# 176657                    0.00000                    0.00000
# 414104                    0.00000                    0.00000
# ...                           ...                        ...
# 336122                    0.00000                    0.00000
# 89146                     0.00000                    0.00000
# 194066                    0.00000                    0.00000
# 89715                     0.00678                    0.00000
# 255922                    0.00000                    0.00000
#
#         orig_resp_resp_p_123_count  orig_resp_resp_p_443_count  \
# 318879                     0.00000                     0.00000
# 211256                     0.00000                     0.00000
# 349221                     0.00000                     0.00000
# 176657                     0.00000                     0.00000
# 414104                     0.00000                     0.00000
# ...                            ...                         ...
# 336122                     0.00000                     0.00000
# 89146                      0.00000                     0.00000
# 194066                     0.00000                     0.00000
# 89715                      0.00000                     0.00000
# 255922                     0.00000                     0.00000
#
#         orig_resp_resp_p_3389_count  orig_resp_resp_p_well_known_count  \
# 318879                      0.00000                            0.00000
# 211256                      0.00000                            0.00000
# 349221                      0.00000                            0.00000
# 176657                      0.00000                            0.00000
# 414104                      0.00000                            0.00000
# ...                             ...                                ...
# 336122                      0.00000                            0.00071
# 89146                       0.00000                            0.00000
# 194066                      0.00000                            0.00141
# 89715                       0.00000                            0.00071
# 255922                      0.00000                            0.00141
#
#         orig_resp_resp_p_reg_count  orig_resp_resp_p_dyn_count  \
# 318879                     0.00000                     0.00000
# 211256                     0.00000                     0.00000
# 349221                     0.00000                     0.00000
# 176657                     0.00000                     0.00000
# 414104                     0.00000                     0.00000
# ...                            ...                         ...
# 336122                     0.00032                     0.00299
# 89146                      0.00000                     0.00000
# 194066                     0.00032                     0.00000
# 89715                      0.00000                     0.00000
# 255922                     0.00064                     0.00000
#
#         orig_resp_dns_count_mean  orig_resp_ssh_count_mean  \
# 318879                   0.00000                   0.00000
# 211256                   0.00000                   0.00000
# 349221                   0.00000                   0.00000
# 176657                   0.00000                   0.00000
# 414104                   0.00000                   0.00000
# ...                          ...                       ...
# 336122                   0.00000                   0.00000
# 89146                    0.00000                   0.00000
# 194066                   0.00000                   0.00000
# 89715                    0.62500                   0.00000
# 255922                   0.00000                   0.00000
#
#         orig_resp_http_count_mean  orig_resp_ssl_count_mean  \
# 318879                    0.00000                   0.00000
# 211256                    0.00000                   0.00000
# 349221                    0.00000                   0.00000
# 176657                    0.00000                   0.00000
# 414104                    0.00000                   0.00000
# ...                           ...                       ...
# 336122                    0.00000                   0.00000
# 89146                     0.00000                   0.00000
# 194066                    0.00000                   0.00000
# 89715                     0.00000                   0.00000
# 255922                    0.00000                   0.00000
#
#         orig_resp_files_count_mean  orig_resp_similar_conns_count  \
# 318879                     0.00000                        0.00000
# 211256                     0.00000                        0.00000
# 349221                     0.00000                        0.00000
# 176657                     0.00000                        0.00000
# 414104                     0.00000                        0.00000
# ...                            ...                            ...
# 336122                     0.00000                        0.00000
# 89146                      0.00000                        0.00000
# 194066                     0.00000                        0.00000
# 89715                      0.00000                        0.00000
# 255922                     0.00000                        0.00000
#
#         orig_resp_similar_dns_qtype_count  orig_resp_similar_dns_rcode_count  \
# 318879                            0.00000                            0.00000
# 211256                            0.00000                            0.00000
# 349221                            0.00000                            0.00000
# 176657                            0.00000                            0.00000
# 414104                            0.00000                            0.00000
# ...                                   ...                                ...
# 336122                            0.00000                            0.00000
# 89146                             0.00000                            0.00000
# 194066                            0.00000                            0.00000
# 89715                             0.00000                            0.00000
# 255922                            0.00000                            0.00000
#
#         orig_resp_similar_ssh_auth_attempts_count  \
# 318879                                    0.00000
# 211256                                    0.00000
# 349221                                    0.00000
# 176657                                    0.00000
# 414104                                    0.00000
# ...                                           ...
# 336122                                    0.00000
# 89146                                     0.00000
# 194066                                    0.00000
# 89715                                     0.00000
# 255922                                    0.00000
#
#         orig_resp_similar_ssh_host_key_count  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         orig_resp_similar_http_method_count  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00000
# 194066                              0.00000
# 89715                               0.00000
# 255922                              0.00000
#
#         orig_resp_similar_http_status_code_count  \
# 318879                                   0.00000
# 211256                                   0.00000
# 349221                                   0.00000
# 176657                                   0.00000
# 414104                                   0.00000
# ...                                          ...
# 336122                                   0.00000
# 89146                                    0.00000
# 194066                                   0.00000
# 89715                                    0.00000
# 255922                                   0.00000
#
#         orig_resp_similar_http_user_agent_count  \
# 318879                                  0.00000
# 211256                                  0.00000
# 349221                                  0.00000
# 176657                                  0.00000
# 414104                                  0.00000
# ...                                         ...
# 336122                                  0.00000
# 89146                                   0.00000
# 194066                                  0.00000
# 89715                                   0.00000
# 255922                                  0.00000
#
#         orig_resp_similar_ssl_version_count  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00000
# 194066                              0.00000
# 89715                               0.00000
# 255922                              0.00000
#
#         orig_resp_similar_ssl_cipher_count  orig_resp_similar_ssl_curve_count  \
# 318879                             0.00000                            0.00000
# 211256                             0.00000                            0.00000
# 349221                             0.00000                            0.00000
# 176657                             0.00000                            0.00000
# 414104                             0.00000                            0.00000
# ...                                    ...                                ...
# 336122                             0.00000                            0.00000
# 89146                              0.00000                            0.00000
# 194066                             0.00000                            0.00000
# 89715                              0.00000                            0.00000
# 255922                             0.00000                            0.00000
#
#         orig_resp_similar_ssl_validation_status_count  \
# 318879                                        0.00000
# 211256                                        0.00000
# 349221                                        0.00000
# 176657                                        0.00000
# 414104                                        0.00000
# ...                                               ...
# 336122                                        0.00000
# 89146                                         0.00000
# 194066                                        0.00000
# 89715                                         0.00000
# 255922                                        0.00000
#
#         orig_resp_similar_files_source_count  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         orig_resp_similar_file_md5_count orig_resp_connection.protocol_mode  \
# 318879                           0.00000                                  -
# 211256                           0.00000                                  -
# 349221                           0.00000                                  -
# 176657                           0.00000                                  -
# 414104                           0.00000                                  -
# ...                                  ...                                ...
# 336122                           0.00000                                tcp
# 89146                            0.00000                                  -
# 194066                           0.00000                               icmp
# 89715                            0.00000                                udp
# 255922                           0.00000                               icmp
#
#        orig_resp_connection.service_mode orig_resp_connection.conn_state_mode  \
# 318879                                 -                                    -
# 211256                                 -                                    -
# 349221                                 -                                    -
# 176657                                 -                                    -
# 414104                                 -                                    -
# ...                                  ...                                  ...
# 336122                              none                                   SF
# 89146                                  -                                    -
# 194066                              none                                  OTH
# 89715                                dns                                   SF
# 255922                              none                                  OTH
#
#         resp_orig_total  resp_orig_connection.time_mean  \
# 318879          0.00864                         0.77794
# 211256          0.00008                         0.77714
# 349221          0.31093                         0.78098
# 176657          0.00017                         0.17325
# 414104          0.00000                         0.79474
# ...                 ...                             ...
# 336122          0.00017                         0.00340
# 89146           0.00000                         0.91347
# 194066          0.00034                         0.77483
# 89715           0.00117                         0.09573
# 255922          0.00034                         0.78348
#
#         resp_orig_connection.duration_mean  \
# 318879                             0.00000
# 211256                             0.00000
# 349221                             0.00000
# 176657                             0.00000
# 414104                             0.00000
# ...                                    ...
# 336122                             0.00034
# 89146                              0.00000
# 194066                             0.00010
# 89715                              0.00000
# 255922                             0.00011
#
#         resp_orig_connection.orig_pkts_mean  \
# 318879                              0.00002
# 211256                              0.00002
# 349221                              0.00002
# 176657                              0.00002
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00008
# 89146                               0.00000
# 194066                              0.00009
# 89715                               0.00002
# 255922                              0.00009
#
#         resp_orig_connection.orig_bytes_mean  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         resp_orig_connection.resp_bytes_mean  \
# 318879                               0.00001
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         resp_orig_connection.resp_pkts_mean  \
# 318879                              0.00001
# 211256                              0.00000
# 349221                              0.00001
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00004
# 89146                               0.00000
# 194066                              0.00001
# 89715                               0.00001
# 255922                              0.00001
#
#         resp_orig_orig_p_well_known_count  resp_orig_orig_p_reg_or_dyn_count  \
# 318879                            0.00478                            0.00856
# 211256                            0.00478                            0.00000
# 349221                            0.00957                            0.31076
# 176657                            0.00957                            0.00000
# 414104                            0.00000                            0.00000
# ...                                   ...                                ...
# 336122                            0.00000                            0.00017
# 89146                             0.00000                            0.00000
# ...
# 414104                            0.03226                            0.00343
# ...                                   ...                                ...
# 336122                            0.00000                            0.24982
# 89146                             0.00000                            0.02036
# 194066                            0.03226                            0.33407
# 89715                             0.64516                            0.05077
# 255922                            0.00000                            0.37687
#
#         resp_resp_resp_p_21_count  resp_resp_resp_p_22_count  \
# 318879                    0.00000                    0.78789
# 211256                    0.00000                    0.00000
# 349221                    0.00000                    0.83792
# 176657                    0.00000                    0.00000
# 414104                    0.00000                    0.00000
# ...                           ...                        ...
# 336122                    0.33333                    0.00100
# 89146                     0.00000                    0.00000
# 194066                    0.33333                    0.17409
# 89715                     0.00000                    0.00000
# 255922                    0.33333                    0.50525
#
#         resp_resp_resp_p_53_count  resp_resp_resp_p_80_count  \
# 318879                    0.00188                    0.00000
# 211256                    0.00000                    0.02052
# 349221                    0.00188                    0.00000
# 176657                    0.00000                    0.03163
# 414104                    0.00000                    0.00798
# ...                           ...                        ...
# 336122                    0.00188                    0.00085
# 89146                     0.00000                    0.00000
# 194066                    0.00188                    0.00256
# 89715                     0.38946                    0.00000
# 255922                    0.00188                    0.00228
#
#         resp_resp_resp_p_123_count  resp_resp_resp_p_443_count  \
# 318879                     0.00000                     0.00000
# 211256                     0.00000                     0.02131
# 349221                     0.00000                     0.00000
# 176657                     0.00000                     0.03285
# 414104                     0.00000                     0.00000
# ...                            ...                         ...
# 336122                     0.00000                     0.00104
# 89146                      0.00000                     0.02456
# 194066                     0.00000                     0.00148
# 89715                      0.00000                     0.00000
# 255922                     0.00000                     0.00133
#
#         resp_resp_resp_p_3389_count  resp_resp_resp_p_well_known_count  \
# 318879                      0.00000                            0.00062
# 211256                      0.00000                            0.01055
# 349221                      0.00000                            0.00062
# 176657                      0.00000                            0.01179
# 414104                      0.00000                            0.00062
# ...                             ...                                ...
# 336122                      0.40000                            0.17866
# 89146                       0.00000                            0.00000
# 194066                      0.10000                            0.43983
# 89715                       0.00000                            0.01241
# 255922                      0.20000                            0.26365
#
#         resp_resp_resp_p_reg_count  resp_resp_resp_p_dyn_count  \
# 318879                     0.00000                     0.00000
# 211256                     0.00000                     0.00000
# 349221                     0.00000                     0.00000
# 176657                     0.00000                     0.00000
# 414104                     0.00000                     0.00000
# ...                            ...                         ...
# 336122                     0.49397                     0.49713
# 89146                      0.00000                     0.00000
# 194066                     0.48762                     0.31034
# 89715                      0.00000                     0.00000
# 255922                     0.47810                     0.31322
#
#         resp_resp_dns_count_mean  resp_resp_ssh_count_mean  \
# 318879                   0.00000                   0.97529
# 211256                   0.00000                   0.00000
# 349221                   0.00000                   0.96603
# 176657                   0.00000                   0.00000
# 414104                   0.00000                   0.00000
# ...                          ...                       ...
# 336122                   0.00000                   0.00000
# 89146                    0.00000                   0.00000
# 194066                   0.00000                   0.12587
# 89715                    0.95392                   0.00000
# 255922                   0.00000                   0.31858
#
#         resp_resp_http_count_mean  resp_resp_ssl_count_mean  \
# 318879                    0.00000                   0.00000
# 211256                    0.30901                   0.60515
# 349221                    0.00000                   0.00000
# 176657                    0.29261                   0.57386
# 414104                    0.24138                   0.00000
# ...                           ...                       ...
# 336122                    0.01031                   0.00196
# 89146                     0.00000                   0.00000
# 194066                    0.00294                   0.15266
# 89715                     0.00000                   0.00000
# 255922                    0.00228                   0.04556
#
#         resp_resp_files_count_mean  resp_resp_similar_conns_count  \
# 318879                     0.00000                        0.00000
# 211256                     0.00694                        0.00000
# 349221                     0.00000                        0.00000
# 176657                     0.00635                        0.00000
# 414104                     0.00781                        0.00000
# ...                            ...                            ...
# 336122                     0.00002                        0.00000
# 89146                      0.00000                        0.00000
# 194066                     0.00034                        0.00000
# 89715                      0.00000                        0.00000
# 255922                     0.00035                        0.00000
#
#         resp_resp_similar_dns_qtype_count  resp_resp_similar_dns_rcode_count  \
# 318879                            0.00000                            0.00000
# 211256                            0.00000                            0.00000
# 349221                            0.00000                            0.00000
# 176657                            0.00000                            0.00000
# 414104                            0.00000                            0.00000
# ...                                   ...                                ...
# 336122                            0.00000                            0.00000
# 89146                             0.00000                            0.00000
# 194066                            0.00000                            0.00000
# 89715                             0.00000                            0.00000
# 255922                            0.00000                            0.00000
#
#         resp_resp_similar_ssh_auth_attempts_count  \
# 318879                                    0.00000
# 211256                                    0.00000
# 349221                                    0.00000
# 176657                                    0.00000
# 414104                                    0.00000
# ...                                           ...
# 336122                                    0.00000
# 89146                                     0.00000
# 194066                                    0.00000
# 89715                                     0.00000
# 255922                                    0.00000
#
#         resp_resp_similar_ssh_host_key_count  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         resp_resp_similar_http_method_count  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00000
# 194066                              0.00000
# 89715                               0.00000
# 255922                              0.00000
#
#         resp_resp_similar_http_status_code_count  \
# 318879                                   0.00000
# 211256                                   0.00000
# 349221                                   0.00000
# 176657                                   0.00000
# 414104                                   0.00000
# ...                                          ...
# 336122                                   0.00000
# 89146                                    0.00000
# 194066                                   0.00000
# 89715                                    0.00000
# 255922                                   0.00000
#
#         resp_resp_similar_http_user_agent_count  \
# 318879                                  0.00000
# 211256                                  0.00000
# 349221                                  0.00000
# 176657                                  0.00000
# 414104                                  0.00000
# ...                                         ...
# 336122                                  0.00000
# 89146                                   0.00000
# 194066                                  0.00000
# 89715                                   0.00000
# 255922                                  0.00000
#
#         resp_resp_similar_ssl_version_count  \
# 318879                              0.00000
# 211256                              0.00000
# 349221                              0.00000
# 176657                              0.00000
# 414104                              0.00000
# ...                                     ...
# 336122                              0.00000
# 89146                               0.00000
# 194066                              0.00000
# 89715                               0.00000
# 255922                              0.00000
#
#         resp_resp_similar_ssl_cipher_count  resp_resp_similar_ssl_curve_count  \
# 318879                             0.00000                            0.00000
# 211256                             0.00000                            0.00000
# 349221                             0.00000                            0.00000
# 176657                             0.00000                            0.00000
# 414104                             0.00000                            0.00000
# ...                                    ...                                ...
# 336122                             0.00000                            0.00000
# 89146                              0.00000                            0.00000
# 194066                             0.00000                            0.00000
# 89715                              0.00000                            0.00000
# 255922                             0.00000                            0.00000
#
#         resp_resp_similar_ssl_validation_status_count  \
# 318879                                        0.00000
# 211256                                        0.00000
# 349221                                        0.00000
# 176657                                        0.00000
# 414104                                        0.00000
# ...                                               ...
# 336122                                        0.00000
# 89146                                         0.00000
# 194066                                        0.00000
# 89715                                         0.00000
# 255922                                        0.00000
#
#         resp_resp_similar_files_source_count  \
# 318879                               0.00000
# 211256                               0.00000
# 349221                               0.00000
# 176657                               0.00000
# 414104                               0.00000
# ...                                      ...
# 336122                               0.00000
# 89146                                0.00000
# 194066                               0.00000
# 89715                                0.00000
# 255922                               0.00000
#
#         resp_resp_similar_file_md5_count resp_resp_connection.protocol_mode  \
# 318879                           0.00000                                tcp
# 211256                           0.00000                                tcp
# 349221                           0.00000                                tcp
# 176657                           0.00000                                tcp
# 414104                           0.00000                                tcp
# ...                                  ...                                ...
# 336122                           0.00000                                tcp
# 89146                            0.00000                                tcp
# 194066                           0.00000                                tcp
# 89715                            0.00000                                udp
# 255922                           0.00000                                tcp
#
#        resp_resp_connection.service_mode resp_resp_connection.conn_state_mode  \
# 318879                              none                                   SF
# 211256                               ssl                                 RSTO
# 349221                              none                                   SF
# 176657                               ssl                                 RSTO
# 414104                              none                                   S0
# ...                                  ...                                  ...
# 336122                              none                                   S0
# 89146                               none                                   S0
# 194066                              none                                   S0
# 89715                                dns                                   SF
# 255922                              none                                   S0
#
#         cluster cluster_cat
# 318879        8           8
# 211256        0           0
# 349221        8           8
# 176657        3           3
# 414104        0           0
# ...         ...         ...
# 336122        4           4
# 89146         0           0
# 194066        6           6
# 89715         2           2
# 255922        6           6
#
# [100000 rows x 186 columns]

# %%
# Get the position of categorical columns
cat_cols_i_list = [df.columns.get_loc(col) for col in list(df.select_dtypes('object').columns)]
print('Categorical columns         : {}'.format(list(df.select_dtypes('object').columns)))
print('Categorical columns indexes : {}'.format(cat_cols_i_list))
# Out:
# Categorical columns         : ['orig_p_cat', 'resp_p_cat', 'protocol', 'service', 'conn_state', 'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode', 'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode', 'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode', 'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode']
# Categorical columns indexes : [10, 11, 12, 13, 14, 58, 59, 60, 99, 100, 101, 140, 141, 142, 181, 182, 183]

# %%
# cat_cols_i_list
num_df = df.drop(list(df.select_dtypes('object').columns)+['cluster','cluster_cat'], axis=1)
cat_df = df[list(df.select_dtypes('object').columns)]
label_df = df['cluster']

# %%
# def add_num_score_to_all_rows(num_df):
# add_num_score_to_all_rows(num_df)


def compute_num_score(row1, row2):
    return -1

comp_df = pd.concat([num_df,label_df], axis=1)
comp_df['ai'] = 0
cluster_numbers = comp_df['cluster'].unique()
for cluster_number in cluster_numbers:
    clu_df = comp_df[comp_df['cluster'] == cluster_number]
    for row in clu_df.iterrows():
        row_index = row[0] #TODO is really index?
        for subrow in clu_df.iterrows():
            if(subrow[0] == row_index):
                continue
            compute_num_score(row, subrow)
            
            raise Exception()
    
    print(len(clu_df))
# Out:
# 327000
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-76-5f80378eff69> in <module>
#       9     for row in clu_df.iterrows():
#      10         print(row[0])
# ---> 11         raise Exception()
#      12
#      13     print(len(clu_df))
#
# Exception:
