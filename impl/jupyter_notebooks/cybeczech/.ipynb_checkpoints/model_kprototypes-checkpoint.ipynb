# %% [markdown]
# ## 1. Load the data

# %%
import pandas as pd

# Format scientific notation from Pandas
pd.set_option('display.float_format', lambda x: '%.5f' % x)

INPUT_CSV = "/home/sramkova/diploma_thesis_data/FINAL_neighbourhood_both_days.csv"

data = pd.read_csv(INPUT_CSV, low_memory=False)
selected_df = data.copy()
selected_df.head(5)
# Out:
#    originated_ip_num  responded_ip_num  connection.time  connection.duration  \
# 0            0.04226           0.40550          0.21127              0.00000
# 1            0.04226           0.07519          0.20171              0.00052
# 2            0.04226           0.79730          0.20766              0.00056
# 3            0.04226           0.79730          0.20766              0.00056
# 4            0.04226           0.71842          0.20773              0.00029
#
#    connection.orig_p  connection.orig_bytes  connection.orig_pkts  \
# 0            0.84330                0.00000               0.00003
# 1            0.75884                0.00007               0.00039
# 2            0.75059                0.00000               0.00011
# 3            0.75057                0.00000               0.00004
# 4            0.75108                0.00000               0.00048
#
#    connection.resp_p  connection.resp_bytes  connection.resp_pkts  ...  \
# ...

# %%
# shuffle 
selected_df = selected_df.sample(frac=1).reset_index(drop=True)
selected_df.head(5)
# Out:
#    originated_ip_num  responded_ip_num  connection.time  connection.duration  \
# 0            0.36686           0.03237          0.77482              0.00000
# 1            0.02044           0.03237          0.77749              0.00000
# 2            0.04576           0.01362          0.76999              0.00001
# 3            0.02044           0.03237          0.90436              0.00000
# 4            0.04226           0.01362          0.10761              0.00000
#
#    connection.orig_p  connection.orig_bytes  connection.orig_pkts  \
# 0            0.59859                0.00000               0.00001
# 1            0.56107                0.00000               0.00001
# 2            0.76119                0.00000               0.00003
# 3            0.50620                0.00000               0.00001
# 4            0.92970                0.00000               0.00001
#
#    connection.resp_p  connection.resp_bytes  connection.resp_pkts  ...  \
# ...

# %%
for col in selected_df.columns:
    print(col)
# Out:
# originated_ip_num
# responded_ip_num
# connection.time
# connection.duration
# connection.orig_p
# connection.orig_bytes
# connection.orig_pkts
# connection.resp_p
# connection.resp_bytes
# connection.resp_pkts
# orig_orig_total
# orig_orig_connection.time_mean
# orig_orig_connection.duration_mean
# orig_orig_connection.orig_p_mean
# orig_orig_connection.orig_pkts_mean
# orig_orig_connection.orig_bytes_mean
# orig_orig_connection.resp_p_mean
# orig_orig_connection.resp_bytes_mean
# orig_orig_connection.resp_pkts_mean
# orig_orig_orig_p_well_known_count
# orig_orig_orig_p_reg_or_dyn_count
# orig_orig_resp_p_21_count
# orig_orig_resp_p_22_count
# orig_orig_resp_p_53_count
# orig_orig_resp_p_80_count
# orig_orig_resp_p_123_count
# orig_orig_resp_p_443_count
# orig_orig_resp_p_3389_count
# orig_orig_resp_p_well_known_count
# orig_orig_resp_p_reg_count
# orig_orig_resp_p_dyn_count
# orig_resp_total
# orig_resp_connection.time_mean
# orig_resp_connection.duration_mean
# ...

# %% [markdown]
# ## 3. K-prototypes
#
# (https://towardsdatascience.com/the-k-prototype-as-clustering-algorithm-for-mixed-data-type-categorical-and-numerical-fe7c50538ebb
# )
#
# (https://github.com/nicodv/kmodes/blob/master/kmodes/kprototypes.py)
#
# ### Parameters of kmodes.kprototypes.KPrototypes:
#
# ```
# num_dissim:
#         Dissimilarity function used by the algorithm for numerical variables.
#         (default is euclidian_dissim)
#
# cat_dissim:
#         For categorical variables.
#         (default is matching_dissim)
#
# init:
#         Initial centroids.
#
# gamma:
#         Weighing factor determining relative importance of numerical vs. categorical attributes.
#         (default is None, calculated from data)
#
# n_jobs:
#         Number of jobs to use for the computation - each n_init runs in parallel. If -1 all CPUs are used.
#         (default is 1)
# ```
#
# ### Attributes:
#
# ```
# cluster_centroids_
#
# labels_:
#         Labels of each point (cluster l affiliation)
#
# cost_:
#         Sum distance of all points to their respective cluster centroids.
#
# n_iter_:
#         The number of iterations the algorithm ran for.
#
# epoch_costs_:
#         Cost at each epoch.
#
# gamma:
#         The (potentially calculated) weighing factor.
# ```

# %%
import numpy as np
from kmodes.kprototypes import KPrototypes

# %%
print('Dimension data: {} rows and {} columns'.format(len(selected_df), len(selected_df.columns)))
# Out:
# Dimension data: 472345 rows and 164 columns

# %%
# selected_df.info()

# %%
# Inspect the categorical variables
selected_df.select_dtypes('object').nunique()
# Out:
# orig_orig_connection.protocol_mode           3
# orig_orig_connection.service_mode            8
# orig_orig_connection.conn_state_mode        12
# orig_resp_connection.protocol_mode           4
# orig_resp_connection.service_mode           10
# orig_resp_connection.conn_state_mode        13
# resp_orig_connection.protocol_mode           4
# resp_orig_connection.service_mode            8
# resp_orig_connection.conn_state_mode        12
# resp_resp_connection.protocol_mode           4
# resp_resp_connection.service_mode            9
# resp_resp_connection.conn_state_mode        14
# uid                                     472345
# originated_ip                              275
# responded_ip                              2678
# timestamp                               472345
# protocol                                     3
# service                                     14
# conn_state                                  13
# orig_p_cat                                   2
# ...

# %%
# Numerical
pd.set_option('display.max_columns', None)
selected_df.describe()
# Out:
#        originated_ip_num  responded_ip_num  connection.time  \
# count       472345.00000      472345.00000     472345.00000
# mean             0.19622           0.11202          0.61717
# std              0.30174           0.20981          0.34293
# min              0.00000           0.00000          0.00000
# 25%              0.04226           0.01362          0.17747
# 50%              0.04570           0.03237          0.78051
# 75%              0.30541           0.03237          0.85220
# max              1.00000           1.00000          1.00000
#
#        connection.duration  connection.orig_p  connection.orig_bytes  \
# count         472345.00000       472345.00000           472345.00000
# mean               0.00049            0.63449                0.00002
# std                0.00634            0.29035                0.00398
# min                0.00000            0.00000                0.00000
# 25%                0.00000            0.53659                0.00000
# ...

# %%
df = selected_df.filter([
                    # numerical
                    'connection.time', 'connection.duration', 
                        # 'connection.orig_p', 
                    'connection.orig_bytes', 'connection.orig_pkts',
                        # 'connection.resp_p', 
                    'connection.resp_bytes', 'connection.resp_pkts',
                    'originated_ip_num', 
                    'responded_ip_num', 
                    # categorical
                    'orig_p_cat', 
                    'resp_p_cat',
                    'protocol',
                    'service', 
                    'conn_state',
    
    
                    # originator neighbourhood
                    'orig_orig_total', 
                    'orig_orig_connection.time_mean', 
                    'orig_orig_connection.duration_mean',
                    'orig_orig_connection.orig_p_mean', 
                    'orig_orig_connection.orig_pkts_mean',
                    'orig_orig_connection.orig_bytes_mean',
                    'orig_orig_connection.resp_p_mean', 
                    'orig_orig_connection.resp_bytes_mean',
                    'orig_orig_connection.resp_pkts_mean',
                    'orig_orig_orig_p_well_known_count', 'orig_orig_orig_p_reg_or_dyn_count', 'orig_orig_resp_p_21_count', 'orig_orig_resp_p_22_count',
                    'orig_orig_resp_p_53_count', 'orig_orig_resp_p_80_count', 'orig_orig_resp_p_123_count', 'orig_orig_resp_p_443_count', 'orig_orig_resp_p_3389_count',
                    'orig_orig_resp_p_well_known_count', 'orig_orig_resp_p_reg_count', 'orig_orig_resp_p_dyn_count',
    
                    # originator categorical neighbourhood 
                    'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode',
                    
                    # originator neighbourhood 2 
                    'orig_resp_total', 
                    'orig_resp_connection.time_mean', 
                    'orig_resp_connection.duration_mean',
                    'orig_resp_connection.orig_p_mean', 
                    'orig_resp_connection.orig_pkts_mean',
                    'orig_resp_connection.orig_bytes_mean',
                    'orig_resp_connection.resp_p_mean', 
                    'orig_resp_connection.resp_bytes_mean',
                    'orig_resp_connection.resp_pkts_mean',
                    'orig_resp_orig_p_well_known_count', 'orig_resp_orig_p_reg_or_dyn_count', 'orig_resp_resp_p_21_count', 'orig_resp_resp_p_22_count',
                    'orig_resp_resp_p_53_count', 'orig_resp_resp_p_80_count', 'orig_resp_resp_p_123_count', 'orig_resp_resp_p_443_count', 'orig_resp_resp_p_3389_count',
                    'orig_resp_resp_p_well_known_count', 'orig_resp_resp_p_reg_count', 'orig_resp_resp_p_dyn_count',
    
                    # originator categorical neighbourhood 
                    'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode',
                    
    
                    # responder neighbourhood
                    'resp_orig_total', 
                    'resp_orig_connection.time_mean', 
                    'resp_orig_connection.duration_mean',
                    'resp_orig_connection.orig_p_mean', 
                    'resp_orig_connection.orig_bytes_mean',
                    'resp_orig_connection.orig_pkts_mean',
                    'resp_orig_connection.resp_p_mean', 
                    'resp_orig_connection.resp_bytes_mean',
                    'resp_orig_connection.resp_pkts_mean',
                    'resp_orig_orig_p_well_known_count', 'resp_orig_orig_p_reg_or_dyn_count', 'resp_orig_resp_p_21_count', 'resp_orig_resp_p_22_count',
                    'resp_orig_resp_p_53_count', 'resp_orig_resp_p_80_count', 'resp_orig_resp_p_123_count', 'resp_orig_resp_p_443_count', 'resp_orig_resp_p_3389_count',
                    'resp_orig_resp_p_well_known_count', 'resp_orig_resp_p_reg_count', 'resp_orig_resp_p_dyn_count',
    
                    # responder categorical neighbourhood
                    'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode',
                    
                    # responder neighbourhood
                    'resp_resp_total',
                    'resp_resp_connection.time_mean', 
                    'resp_resp_connection.duration_mean',
                    'resp_resp_connection.orig_p_mean', 
                    'resp_resp_connection.orig_bytes_mean',
                    'resp_resp_connection.orig_pkts_mean',
                    'resp_resp_connection.resp_p_mean', 
                    'resp_resp_connection.resp_bytes_mean',
                    'resp_resp_connection.resp_pkts_mean',
                    'resp_resp_orig_p_well_known_count', 'resp_resp_orig_p_reg_or_dyn_count', 'resp_resp_resp_p_21_count', 'resp_resp_resp_p_22_count',
                    'resp_resp_resp_p_53_count', 'resp_resp_resp_p_80_count', 'resp_resp_resp_p_123_count', 'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
                    'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count', 'resp_resp_resp_p_dyn_count',

                    # responder neighbourhood 
                    'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode'], 
    axis=1)

# %%
df.head()
# Out:
#    connection.time  connection.duration  connection.orig_bytes  \
# 0          0.77482              0.00000                0.00000
# 1          0.77749              0.00000                0.00000
# 2          0.76999              0.00001                0.00000
# 3          0.90436              0.00000                0.00000
# 4          0.10761              0.00000                0.00000
#
#    connection.orig_pkts  connection.resp_bytes  connection.resp_pkts  \
# 0               0.00001                0.00000               0.00000
# 1               0.00001                0.00000               0.00000
# 2               0.00003                0.00000               0.00003
# 3               0.00001                0.00000               0.00000
# 4               0.00001                0.00000               0.00001
#
#    originated_ip_num  responded_ip_num       orig_p_cat resp_p_cat protocol  \
# 0            0.36686           0.03237  orig_reg_or_dyn   resp_dyn      tcp
# ...

# %%
df.columns
# Out:
# Index(['connection.time', 'connection.duration', 'connection.orig_bytes',
#        'connection.orig_pkts', 'connection.resp_bytes', 'connection.resp_pkts',
#        'originated_ip_num', 'responded_ip_num', 'orig_p_cat', 'resp_p_cat',
#        ...
#        'resp_resp_resp_p_80_count', 'resp_resp_resp_p_123_count',
#        'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
#        'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count',
#        'resp_resp_resp_p_dyn_count', 'resp_resp_connection.protocol_mode',
#        'resp_resp_connection.service_mode',
#        'resp_resp_connection.conn_state_mode'],
#       dtype='object', length=109)

# %%
# Get the position of categorical columns
cat_cols_i_list = [df.columns.get_loc(col) for col in list(df.select_dtypes('object').columns)]
print('Categorical columns         : {}'.format(list(df.select_dtypes('object').columns)))
print('Categorical columns indexes : {}'.format(cat_cols_i_list))
# Out:
# Categorical columns         : ['orig_p_cat', 'resp_p_cat', 'protocol', 'service', 'conn_state', 'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode', 'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode', 'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode', 'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode']
# Categorical columns indexes : [8, 9, 10, 11, 12, 34, 35, 36, 58, 59, 60, 82, 83, 84, 106, 107, 108]

# %%
# Convert dataframe to matrix
df_matrix = df.to_numpy()
df_matrix
# Out:
# array([[0.7748215133288903, 0.0, 0.0, ..., 'tcp', 'none', 'S0'],
#        [0.7774900701330193, 0.0, 0.0, ..., 'tcp', 'none', 'S0'],
#        [0.769993477124213, 9.788769491399792e-06, 3.1790604785110256e-08,
#         ..., 'tcp', 'none', 'OTH'],
#        ...,
#        [0.7756886199695437, 0.0, 0.0, ..., 'tcp', 'none', 'S0'],
#        [0.8202732782909576, 0.0, 0.0, ..., 'tcp', 'none', 'S0'],
#        [0.1935804379595599, 1.5422254127429457e-05,
#         3.1790604785110256e-08, ..., 'tcp', 'ssl', 'RSTO']], dtype=object)

# %%
from datetime import datetime

# Choose optimal K using Elbow method
cost = []
print_info = []
computed_clusters = []

print('Start at ' + datetime.now().strftime("%H:%M:%S") + '.')
#for cluster in range(1, 15):
for cluster in range(10, 12):
    try:
        kprototype = KPrototypes(n_jobs=-1, n_clusters=cluster, init='Huang', random_state=0)
        kprototype.fit_predict(X=df_matrix, categorical=cat_cols_i_list)
        computed_clusters.append(kprototype)
        cost.append(kprototype.cost_)
        print_str = 'Cluster initiation: {:2} ({}), gamma: {}'.format(cluster, 
                                                                    datetime.now().strftime("%H:%M:%S"), 
                                                                    kprototype.gamma)
        print_info.append(print_str)
        print(print_str)
    except:
        break
print('Done at ' + datetime.now().strftime("%H:%M:%S") + '.')
# Out:
# Start at 09:04:33.
# Cluster initiation: 10 (09:37:41), gamma: 0.10987684341100562
# Cluster initiation: 11 (10:22:46), gamma: 0.10987684341100562
# Done at 10:22:46.

# %%
cost
# Out:
# [468013.00263661373, 451655.4564335947]

# %%
#df_cost = pd.DataFrame({'Cluster': range(1, 15), 'Cost': cost})
df_cost = pd.DataFrame({'Cluster': range(10, 12), 'Cost': cost})

# %%
print_info
# Out:
# ['Cluster initiation: 10 (09:37:41), gamma: 0.10987684341100562',
#  'Cluster initiation: 11 (10:22:46), gamma: 0.10987684341100562']

# %%
df_cost
# Out:
#    Cluster         Cost
# 0       10 468013.00264
# 1       11 451655.45643

# %%
# Import module for data visualization
from plotnine import *
import plotnine

plotnine.options.figure_size = (8, 4.8)
(
    ggplot(data = df_cost)+
    geom_line(aes(x = 'Cluster',
                  y = 'Cost'))+
    geom_point(aes(x = 'Cluster',
                   y = 'Cost'))+
    geom_label(aes(x = 'Cluster',
                   y = 'Cost',
                   label = 'Cluster'),
               size = 10,
               nudge_y = 1000) +
    labs(title = 'Optimal number of clusters k (using the Elbow Method)')+
    xlab('number of clusters')+
    ylab('cost')+
    theme_minimal()
)
# Out:
# <ggplot: (8737426677029)>

# %% [markdown]
# Optimal `k` will be chosen as 10.

# %%
# Fit the cluster
OPTIMAL_K = 9 ####################### ----- !!!! change

# kprototype = KPrototypes(n_jobs = -1, n_clusters = OPTIMAL_K, init = 'Huang', random_state = 0)
# kprototype.fit_predict(dfMatrix, categorical = catColumnsPos)

#kprototype = computed_clusters[OPTIMAL_K]
kprototype = computed_clusters[0]

# %%
# Cluster centorid
kprototype.cluster_centroids_
# Out:
# array([['0.1185199657242777', '6.479276254152513e-05',
#         '6.739394991259436e-07', ..., 'udp', 'dns', 'SF'],
#        ['0.010189336492878384', '3.5943431386982372e-06',
#         '1.2997882340021129e-09', ..., 'tcp', 'none', 'S0'],
#        ['0.8762968295933392', '0.00036222760005553034',
#         '7.818495961188269e-07', ..., 'udp', 'ntp', 'SF'],
#        ...,
#        ['0.8555975985870573', '0.00014889993599615002',
#         '4.2825589669651724e-07', ..., 'udp', 'dns', 'SF'],
#        ['0.11345411220925711', '0.00014377179830835652',
#         '3.048000829706536e-07', ..., 'udp', 'ntp', 'SF'],
#        ['0.811008645402814', '4.519725833868244e-05',
#         '2.2069544740842242e-08', ..., 'tcp', 'none', 'S0']], dtype='<U32')

# %%
# Check the iteration of the clusters created
kprototype.n_iter_
# Out:
# 9

# %%
# Check the cost of the clusters created
kprototype.cost_
# Out:
# 468013.00263661373

# %%
# df.drop('Cluster Labels', axis=1, inplace=True)
# df.drop('cluster', axis=1, inplace=True)
# df.head()

# %%
# Add cluster labels to original dataframe
df['cluster'] = kprototype.labels_
df['cluster_cat'] = df['cluster']

# (groupby works only on category type)
df['cluster_cat'] = df['cluster_cat'].astype('category')

# %%
df.head()
# Out:
#    connection.time  connection.duration  connection.orig_bytes  \
# 0          0.77482              0.00000                0.00000
# 1          0.77749              0.00000                0.00000
# 2          0.76999              0.00001                0.00000
# 3          0.90436              0.00000                0.00000
# 4          0.10761              0.00000                0.00000
#
#    connection.orig_pkts  connection.resp_bytes  connection.resp_pkts  \
# 0               0.00001                0.00000               0.00000
# 1               0.00001                0.00000               0.00000
# 2               0.00003                0.00000               0.00003
# 3               0.00001                0.00000               0.00000
# 4               0.00001                0.00000               0.00001
#
#    originated_ip_num  responded_ip_num       orig_p_cat resp_p_cat protocol  \
# 0            0.36686           0.03237  orig_reg_or_dyn   resp_dyn      tcp
# ...

# %%
df.columns
# Out:
# Index(['connection.time', 'connection.duration', 'connection.orig_bytes',
#        'connection.orig_pkts', 'connection.resp_bytes', 'connection.resp_pkts',
#        'originated_ip_num', 'responded_ip_num', 'orig_p_cat', 'resp_p_cat',
#        ...
#        'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
#        'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count',
#        'resp_resp_resp_p_dyn_count', 'resp_resp_connection.protocol_mode',
#        'resp_resp_connection.service_mode',
#        'resp_resp_connection.conn_state_mode', 'cluster', 'cluster_cat'],
#       dtype='object', length=111)

# %%
df['cluster'].value_counts()
# Out:
# 6    74302
# 3    73988
# 5    62568
# 9    56945
# 4    50680
# 7    47214
# 0    41458
# 2    27007
# 8    26193
# 1    11990
# Name: cluster, dtype: int64

# %%
# Cluster interpretation
# (using average for numerical, mode for categorical attributes)

#df.rename(columns = {'cluster':'Total'}, inplace = True)
df.groupby('cluster_cat').agg(
    {
        'cluster':'count',
        'protocol': lambda x: x.value_counts().index[0],
        'service': lambda x: x.value_counts().index[0],
        'conn_state': lambda x: x.value_counts().index[0],
        'orig_p_cat' : lambda x: x.value_counts().index[0],
        'resp_p_cat': lambda x: x.value_counts().index[0],
        'connection.time': 'mean',
        'connection.duration': 'mean',
        #'connection.orig_p': 'mean', 
        'connection.orig_bytes': 'mean', 
        #'connection.resp_p': 'mean', 
        'connection.resp_bytes': 'mean'
    }
).reset_index()
# Out:
#   cluster_cat  cluster protocol service conn_state       orig_p_cat  \
# 0           0    41458      udp     dns         SF  orig_reg_or_dyn
# 1           1    11990      tcp    none         S0  orig_reg_or_dyn
# 2           2    27007      udp     ntp         SF  orig_well_known
# 3           3    73988      tcp    none         S0  orig_reg_or_dyn
# 4           4    50680      tcp    none         S0  orig_reg_or_dyn
# 5           5    62568      tcp     ssl         SF  orig_reg_or_dyn
# 6           6    74302      tcp     ssl         SF  orig_reg_or_dyn
# 7           7    47214      udp     dns         SF  orig_reg_or_dyn
# 8           8    26193      udp     ntp         SF  orig_well_known
# 9           9    56945      tcp    none         S0  orig_reg_or_dyn
#
#   resp_p_cat  connection.time  connection.duration  connection.orig_bytes  \
# 0    resp_53          0.11852              0.00006                0.00000
# ...

# %%
df.groupby('cluster_cat').agg(
    {
        'cluster':'count',
        # responder neighbourhood
        'orig_orig_total': 'mean', 
        'orig_orig_connection.protocol_mode': lambda x: x.value_counts().index[0],
        'orig_orig_connection.service_mode': lambda x: x.value_counts().index[0],
        'orig_orig_connection.conn_state_mode': lambda x: x.value_counts().index[0],
        'orig_orig_connection.time_mean': 'mean',
        'orig_orig_connection.duration_mean': 'mean', 
        'orig_orig_connection.orig_bytes_mean': 'mean', 
        'orig_orig_connection.orig_pkts_mean': 'mean',
        'orig_orig_connection.resp_bytes_mean': 'mean',
        'orig_orig_connection.resp_pkts_mean': 'mean'
#         'orig_connection.time_median': 'mean',
#         'orig_connection.duration_median': 'mean', 
#         'orig_connection.orig_bytes_median': 'mean', 
#         'orig_connection.orig_pkts_median': 'mean',
#         'orig_connection.resp_bytes_median': 'mean',
#         'orig_connection.resp_pkts_median': 'mean'
    }
).reset_index()
# Out:
#   cluster_cat  cluster  orig_orig_total orig_orig_connection.protocol_mode  \
# 0           0    41458          0.01305                                udp
# 1           1    11990          0.45738                                tcp
# 2           2    27007          0.00360                               icmp
# 3           3    73988          0.43362                                tcp
# 4           4    50680          0.35011                                tcp
# 5           5    62568          0.00773                                tcp
# 6           6    74302          0.01458                                tcp
# 7           7    47214          0.04583                                udp
# 8           8    26193          0.00347                               icmp
# 9           9    56945          0.75785                                tcp
#
#   orig_orig_connection.service_mode orig_orig_connection.conn_state_mode  \
# ...

# %%
df.groupby('cluster_cat').agg(
    {
        'cluster':'count',
        # responder neighbourhood
        'orig_resp_total': 'mean', 
        'orig_resp_connection.protocol_mode': lambda x: x.value_counts().index[0],
        'orig_resp_connection.service_mode': lambda x: x.value_counts().index[0],
        'orig_resp_connection.conn_state_mode': lambda x: x.value_counts().index[0],
        'orig_resp_connection.time_mean': 'mean',
        'orig_resp_connection.duration_mean': 'mean', 
        'orig_resp_connection.orig_bytes_mean': 'mean', 
        'orig_resp_connection.orig_pkts_mean': 'mean',
        'orig_resp_connection.resp_bytes_mean': 'mean',
        'orig_resp_connection.resp_pkts_mean': 'mean'
#         'orig_connection.time_median': 'mean',
#         'orig_connection.duration_median': 'mean', 
#         'orig_connection.orig_bytes_median': 'mean', 
#         'orig_connection.orig_pkts_median': 'mean',
#         'orig_connection.resp_bytes_median': 'mean',
#         'orig_connection.resp_pkts_median': 'mean'
    }
).reset_index()
# Out:
#   cluster_cat  cluster  orig_resp_total orig_resp_connection.protocol_mode  \
# 0           0    41458          0.00724                               icmp
# 1           1    11990          0.00866                                tcp
# 2           2    27007          0.00073                                  -
# 3           3    73988          0.00096                                  -
# 4           4    50680          0.00000                                  -
# 5           5    62568          0.00034                                  -
# 6           6    74302          0.00176                                  -
# 7           7    47214          0.04455                                  -
# 8           8    26193          0.00093                                  -
# 9           9    56945          0.00410                               icmp
#
#   orig_resp_connection.service_mode orig_resp_connection.conn_state_mode  \
# ...

# %%
df.groupby('cluster_cat').agg(
    {
        'cluster':'count',
        # responder neighbourhood
        'resp_orig_total': 'mean', 
        'resp_orig_connection.protocol_mode': lambda x: x.value_counts().index[0],
        'resp_orig_connection.service_mode': lambda x: x.value_counts().index[0],
        'resp_orig_connection.conn_state_mode': lambda x: x.value_counts().index[0],
        'resp_orig_connection.time_mean': 'mean',
        'resp_orig_connection.duration_mean': 'mean', 
        'resp_orig_connection.orig_bytes_mean': 'mean', 
        'resp_orig_connection.orig_pkts_mean': 'mean',
        'resp_orig_connection.resp_bytes_mean': 'mean',
        'resp_orig_connection.resp_pkts_mean': 'mean'
#         'resp_connection.time_median': 'mean',
#         'resp_connection.duration_median': 'mean', 
#         'resp_connection.orig_bytes_median': 'mean', 
#         'resp_connection.orig_pkts_median': 'mean',
#         'resp_connection.resp_bytes_median': 'mean',
#         'resp_connection.resp_pkts_median': 'mean'
    }
).reset_index()
# Out:
#   cluster_cat  cluster  resp_orig_total resp_orig_connection.protocol_mode  \
# 0           0    41458          0.00175                                udp
# 1           1    11990          0.00171                                tcp
# 2           2    27007          0.00178                                  -
# 3           3    73988          0.02029                                udp
# 4           4    50680          0.00002                                  -
# 5           5    62568          0.00006                                  -
# 6           6    74302          0.00015                                  -
# 7           7    47214          0.00534                                udp
# 8           8    26193          0.00163                                  -
# 9           9    56945          0.02007                                udp
#
#   resp_orig_connection.service_mode resp_orig_connection.conn_state_mode  \
# ...

# %%
df.groupby('cluster_cat').agg(
    {
        'cluster':'count',
        # responder neighbourhood
        'resp_resp_total': 'mean', 
        'resp_resp_connection.protocol_mode': lambda x: x.value_counts().index[0],
        'resp_resp_connection.service_mode': lambda x: x.value_counts().index[0],
        'resp_resp_connection.conn_state_mode': lambda x: x.value_counts().index[0],
        'resp_resp_connection.time_mean': 'mean',
        'resp_resp_connection.duration_mean': 'mean', 
        'resp_resp_connection.orig_bytes_mean': 'mean', 
        'resp_resp_connection.orig_pkts_mean': 'mean',
        'resp_resp_connection.resp_bytes_mean': 'mean',
        'resp_resp_connection.resp_pkts_mean': 'mean'
#         'resp_connection.time_median': 'mean',
#         'resp_connection.duration_median': 'mean', 
#         'resp_connection.orig_bytes_median': 'mean', 
#         'resp_connection.orig_pkts_median': 'mean',
#         'resp_connection.resp_bytes_median': 'mean',
#         'resp_connection.resp_pkts_median': 'mean'
    }
).reset_index()
# Out:
#   cluster_cat  cluster  resp_resp_total resp_resp_connection.protocol_mode  \
# 0           0    41458          0.01156                                udp
# 1           1    11990          0.51391                                tcp
# 2           2    27007          0.00763                                udp
# 3           3    73988          0.14443                                tcp
# 4           4    50680          0.10742                                tcp
# 5           5    62568          0.01273                                tcp
# 6           6    74302          0.01823                                tcp
# 7           7    47214          0.03865                                udp
# 8           8    26193          0.00848                                udp
# 9           9    56945          0.37572                                tcp
#
#   resp_resp_connection.service_mode resp_resp_connection.conn_state_mode  \
# ...

# %%
centroids = pd.DataFrame(kprototype.cluster_centroids_, columns = [
                    # numerical
                    'connection.time', 'connection.duration', 
                        # 'connection.orig_p', 
                    'connection.orig_bytes', 'connection.orig_pkts',
                        # 'connection.resp_p', 
                    'connection.resp_bytes', 'connection.resp_pkts',
                    'originated_ip_num', 
                    'responded_ip_num', 
                    # categorical
                    'orig_p_cat', 
                    'resp_p_cat',
                    'protocol',
                    'service', 
                    'conn_state',
    
    
                    # originator neighbourhood
                    'orig_orig_total', 
                    'orig_orig_connection.time_mean', 
                    'orig_orig_connection.duration_mean',
                    'orig_orig_connection.orig_p_mean', 
                    'orig_orig_connection.orig_pkts_mean',
                    'orig_orig_connection.orig_bytes_mean',
                    'orig_orig_connection.resp_p_mean', 
                    'orig_orig_connection.resp_bytes_mean',
                    'orig_orig_connection.resp_pkts_mean',
                    'orig_orig_orig_p_well_known_count', 'orig_orig_orig_p_reg_or_dyn_count', 'orig_orig_resp_p_21_count', 'orig_orig_resp_p_22_count',
                    'orig_orig_resp_p_53_count', 'orig_orig_resp_p_80_count', 'orig_orig_resp_p_123_count', 'orig_orig_resp_p_443_count', 'orig_orig_resp_p_3389_count',
                    'orig_orig_resp_p_well_known_count', 'orig_orig_resp_p_reg_count', 'orig_orig_resp_p_dyn_count',
    
                    # originator categorical neighbourhood 
                    'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode',
                    
                    # originator neighbourhood 2 
                    'orig_resp_total', 
                    'orig_resp_connection.time_mean', 
                    'orig_resp_connection.duration_mean',
                    'orig_resp_connection.orig_p_mean', 
                    'orig_resp_connection.orig_pkts_mean',
                    'orig_resp_connection.orig_bytes_mean',
                    'orig_resp_connection.resp_p_mean', 
                    'orig_resp_connection.resp_bytes_mean',
                    'orig_resp_connection.resp_pkts_mean',
                    'orig_resp_orig_p_well_known_count', 'orig_resp_orig_p_reg_or_dyn_count', 'orig_resp_resp_p_21_count', 'orig_resp_resp_p_22_count',
                    'orig_resp_resp_p_53_count', 'orig_resp_resp_p_80_count', 'orig_resp_resp_p_123_count', 'orig_resp_resp_p_443_count', 'orig_resp_resp_p_3389_count',
                    'orig_resp_resp_p_well_known_count', 'orig_resp_resp_p_reg_count', 'orig_resp_resp_p_dyn_count',
    
                    # originator categorical neighbourhood 
                    'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode',
                    
    
                    # responder neighbourhood
                    'resp_orig_total', 
                    'resp_orig_connection.time_mean', 
                    'resp_orig_connection.duration_mean',
                    'resp_orig_connection.orig_p_mean', 
                    'resp_orig_connection.orig_bytes_mean',
                    'resp_orig_connection.orig_pkts_mean',
                    'resp_orig_connection.resp_p_mean', 
                    'resp_orig_connection.resp_bytes_mean',
                    'resp_orig_connection.resp_pkts_mean',
                    'resp_orig_orig_p_well_known_count', 'resp_orig_orig_p_reg_or_dyn_count', 'resp_orig_resp_p_21_count', 'resp_orig_resp_p_22_count',
                    'resp_orig_resp_p_53_count', 'resp_orig_resp_p_80_count', 'resp_orig_resp_p_123_count', 'resp_orig_resp_p_443_count', 'resp_orig_resp_p_3389_count',
                    'resp_orig_resp_p_well_known_count', 'resp_orig_resp_p_reg_count', 'resp_orig_resp_p_dyn_count',
    
                    # responder categorical neighbourhood
                    'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode',
                    
                    # responder neighbourhood
                    'resp_resp_total',
                    'resp_resp_connection.time_mean', 
                    'resp_resp_connection.duration_mean',
                    'resp_resp_connection.orig_p_mean', 
                    'resp_resp_connection.orig_bytes_mean',
                    'resp_resp_connection.orig_pkts_mean',
                    'resp_resp_connection.resp_p_mean', 
                    'resp_resp_connection.resp_bytes_mean',
                    'resp_resp_connection.resp_pkts_mean',
                    'resp_resp_orig_p_well_known_count', 'resp_resp_orig_p_reg_or_dyn_count', 'resp_resp_resp_p_21_count', 'resp_resp_resp_p_22_count',
                    'resp_resp_resp_p_53_count', 'resp_resp_resp_p_80_count', 'resp_resp_resp_p_123_count', 'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
                    'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count', 'resp_resp_resp_p_dyn_count',

                    # responder neighbourhood 
                    'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode'])
# https://stackoverflow.com/questions/51148457/how-to-find-the-set-of-influential-features-in-clusters/53081779#53081779
centroids
# Out:
#         connection.time     connection.duration   connection.orig_bytes  \
# 0    0.1185199657242777   6.479276254152513e-05   6.739394991259436e-07
# 1  0.010189336492878384  3.5943431386982372e-06  1.2997882340021129e-09
# 2    0.8762968295933392  0.00036222760005553034   7.818495961188269e-07
# 3    0.8186733946639497   0.0005243565381945974  2.4837278370026917e-07
# 4    0.8250377700798193  0.00021741906439986408    8.88771652313669e-09
# 5   0.11256189826655474   0.0009021827229241244   5.908250522994571e-06
# 6    0.8591541153502544   0.0013119668791774699  0.00013585391507513523
# 7    0.8555975985870573  0.00014889993599615002  4.2825589669651724e-07
# 8   0.11345411220925711  0.00014377179830835652   3.048000829706536e-07
# 9     0.811008645402814   4.519725833868244e-05  2.2069544740842242e-08
#
#      connection.orig_pkts   connection.resp_bytes    connection.resp_pkts  \
# 0  2.0737149025544537e-05   2.313457355179899e-06   5.600057552480197e-05
# ...

# %%
from sklearn.decomposition import PCA

data_num_cols = selected_df.filter([
                    # numerical
                    'connection.time', 'connection.duration', 
                        # 'connection.orig_p', 
                    'connection.orig_bytes', 'connection.orig_pkts',
                        # 'connection.resp_p', 
                    'connection.resp_bytes', 'connection.resp_pkts',
                    'originated_ip_num', 
                    'responded_ip_num', 

                    # originator neighbourhood
                    'orig_orig_total', 
                    'orig_orig_connection.time_mean', 
                    'orig_orig_connection.duration_mean',
                    'orig_orig_connection.orig_p_mean', 
                    'orig_orig_connection.orig_pkts_mean',
                    'orig_orig_connection.orig_bytes_mean',
                    'orig_orig_connection.resp_p_mean', 
                    'orig_orig_connection.resp_bytes_mean',
                    'orig_orig_connection.resp_pkts_mean',
                    'orig_orig_orig_p_well_known_count', 'orig_orig_orig_p_reg_or_dyn_count', 'orig_orig_resp_p_21_count', 'orig_orig_resp_p_22_count',
                    'orig_orig_resp_p_53_count', 'orig_orig_resp_p_80_count', 'orig_orig_resp_p_123_count', 'orig_orig_resp_p_443_count', 'orig_orig_resp_p_3389_count',
                    'orig_orig_resp_p_well_known_count', 'orig_orig_resp_p_reg_count', 'orig_orig_resp_p_dyn_count',
                    
                    # originator neighbourhood 2 
                    'orig_resp_total', 
                    'orig_resp_connection.time_mean', 
                    'orig_resp_connection.duration_mean',
                    'orig_resp_connection.orig_p_mean', 
                    'orig_resp_connection.orig_pkts_mean',
                    'orig_resp_connection.orig_bytes_mean',
                    'orig_resp_connection.resp_p_mean', 
                    'orig_resp_connection.resp_bytes_mean',
                    'orig_resp_connection.resp_pkts_mean',
                    'orig_resp_orig_p_well_known_count', 'orig_resp_orig_p_reg_or_dyn_count', 'orig_resp_resp_p_21_count', 'orig_resp_resp_p_22_count',
                    'orig_resp_resp_p_53_count', 'orig_resp_resp_p_80_count', 'orig_resp_resp_p_123_count', 'orig_resp_resp_p_443_count', 'orig_resp_resp_p_3389_count',
                    'orig_resp_resp_p_well_known_count', 'orig_resp_resp_p_reg_count', 'orig_resp_resp_p_dyn_count',
                    
    
                    # responder neighbourhood
                    'resp_orig_total', 
                    'resp_orig_connection.time_mean', 
                    'resp_orig_connection.duration_mean',
                    'resp_orig_connection.orig_p_mean', 
                    'resp_orig_connection.orig_bytes_mean',
                    'resp_orig_connection.orig_pkts_mean',
                    'resp_orig_connection.resp_p_mean', 
                    'resp_orig_connection.resp_bytes_mean',
                    'resp_orig_connection.resp_pkts_mean',
                    'resp_orig_orig_p_well_known_count', 'resp_orig_orig_p_reg_or_dyn_count', 'resp_orig_resp_p_21_count', 'resp_orig_resp_p_22_count',
                    'resp_orig_resp_p_53_count', 'resp_orig_resp_p_80_count', 'resp_orig_resp_p_123_count', 'resp_orig_resp_p_443_count', 'resp_orig_resp_p_3389_count',
                    'resp_orig_resp_p_well_known_count', 'resp_orig_resp_p_reg_count', 'resp_orig_resp_p_dyn_count',
                    
                    # responder neighbourhood
                    'resp_resp_total',
                    'resp_resp_connection.time_mean', 
                    'resp_resp_connection.duration_mean',
                    'resp_resp_connection.orig_p_mean', 
                    'resp_resp_connection.orig_bytes_mean',
                    'resp_resp_connection.orig_pkts_mean',
                    'resp_resp_connection.resp_p_mean', 
                    'resp_resp_connection.resp_bytes_mean',
                    'resp_resp_connection.resp_pkts_mean',
                    'resp_resp_orig_p_well_known_count', 'resp_resp_orig_p_reg_or_dyn_count', 'resp_resp_resp_p_21_count', 'resp_resp_resp_p_22_count',
                    'resp_resp_resp_p_53_count', 'resp_resp_resp_p_80_count', 'resp_resp_resp_p_123_count', 'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
                    'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count', 'resp_resp_resp_p_dyn_count',
    
                    # categorical    
                    'orig_p_cat_orig_reg_or_dyn', 'orig_p_cat_orig_well_known', 
                    'resp_p_cat_resp_123', 'resp_p_cat_resp_21', 'resp_p_cat_resp_22', 'resp_p_cat_resp_3389', 'resp_p_cat_resp_443', 'resp_p_cat_resp_53', 'resp_p_cat_resp_80', 
                      'resp_p_cat_resp_dyn', 'resp_p_cat_resp_reg', 'resp_p_cat_resp_well_known',
                    'connection.proto_icmp', 'connection.proto_tcp', 'connection.proto_udp',
                    'connection.service_dce_rpc', 'connection.service_dhcp', 'connection.service_dns', 'connection.service_http', 'connection.service_imap', 
                      'connection.service_krb_tcp', 'connection.service_none', 'connection.service_ntp', 'connection.service_pop3', 'connection.service_smtp', 
                      'connection.service_socks', 'connection.service_ssh', 'connection.service_ssl', 'connection.service_ssl,imap', 
                    'connection.conn_state_OTH', 'connection.conn_state_REJ', 'connection.conn_state_RSTO', 'connection.conn_state_RSTOS0', 'connection.conn_state_RSTR', 
                      'connection.conn_state_RSTRH', 'connection.conn_state_S0', 'connection.conn_state_S1', 'connection.conn_state_S2', 'connection.conn_state_S3', 
                      'connection.conn_state_SF', 'connection.conn_state_SH', 'connection.conn_state_SHR'], axis=1)
n_components = len(data_num_cols.columns)
whiten = False
random_state = 2018
pca = PCA(n_components=n_components, whiten=whiten, random_state=random_state)

# %%
pca_X = pca.fit_transform(data_num_cols)
pca_X = pd.DataFrame(data=pca_X)

print(f"Variance Explained by all {n_components} principal components: {sum(pca.explained_variance_ratio_)}")
# Out:
# Variance Explained by all 134 principal components: 0.9999999999999992

# %%
importanceOfPrincipalComponents = pd.DataFrame(data=pca.explained_variance_ratio_)
importanceOfPrincipalComponents = importanceOfPrincipalComponents.T
print('Variance Captured by First 7 Principal Components: ', importanceOfPrincipalComponents.loc[:,0:8].sum(axis=1).values)
print('Variance Captured by First 5 Principal Components: ', importanceOfPrincipalComponents.loc[:,0:6].sum(axis=1).values)
print('Variance Captured by First 2 Principal Components: ', importanceOfPrincipalComponents.loc[:,0:2].sum(axis=1).values)
print('Variance Captured by First Principal Component: ', importanceOfPrincipalComponents.loc[:,0:1].sum(axis=1).values)
# Out:
# Variance Captured by First 7 Principal Components:  [0.82820364]
# Variance Captured by First 5 Principal Components:  [0.78177509]
# Variance Captured by First 2 Principal Components:  [0.54263284]
# Variance Captured by First Principal Component:  [0.42659004]

# %%
pca_X['cluster'] = kprototype.labels_
pca_X
# Out:
#               0        1        2        3        4        5        6  \
# 0       1.50308 -0.33180  0.02402  0.34127  0.09629 -0.28843  0.28265
# 1       1.35421 -0.31438  0.02189  0.14599 -0.00594  0.02801 -0.13523
# 2      -0.15473  0.71181 -0.24798 -0.59579 -0.61676  1.03360  0.62284
# 3      -0.64287 -1.14888 -0.74269 -0.00669 -0.60354  0.34116 -0.72619
# 4      -1.77951 -0.57163 -0.11010  1.21133 -0.20527 -0.16871  0.01237
# ...         ...      ...      ...      ...      ...      ...      ...
# 472340 -0.10785  1.19700 -0.74652 -0.95247 -0.13114 -0.13982 -0.58200
# 472341 -0.52240  0.98313 -0.69674 -0.71296  0.40128 -0.33839 -0.26450
# 472342  1.88585 -0.42265 -0.08842  0.50287  0.32908 -0.24517  0.03448
# 472343  1.11069 -0.05196 -0.09073 -0.12350 -0.16091  0.59500 -0.50203
# 472344 -0.50180  1.24561  0.25217  0.39445 -0.60831  1.06712  0.67621
#
#               7        8        9       10       11       12       13  \
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mcm
import numpy as np

pca_X_array = np.array(pca_X)
# plt.rcParams["figure.figsize"] = (5.0,5.0) # https://stackoverflow.com/questions/332289/how-do-you-change-the-size-of-figures-drawn-with-matplotlib

# colors = ['blue', 'lightblue', 'green', 'lightgreen', 'red', 'lightred', 'cyan', 'lightcyan', 'magenta', 'lightmagenta', 'yellow', 'lightyellow']
colors = mcm.rainbow(np.linspace(0, 1, OPTIMAL_K + 1))

# plot the clusters
for i in range(OPTIMAL_K + 1):   
    plt.scatter(
        pca_X_array[kprototype.labels_ == i, 0], pca_X_array[kprototype.labels_ == i, 1],
        s=50, c=[colors[i]], # warning if not array
        marker='o', edgecolor='black',
        label='cluster ' + str(i)
    )

plt.legend(scatterpoints=1)
plt.grid()
plt.show()
# Out:
# /home/sramkova/.local/lib/python3.8/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.

# %%
# join dfs
labels_df = selected_df[['uid', 
                         'originated_ip_num', 'originated_ip', 
                         'responded_ip_num', 'responded_ip', 
                         'timestamp', 'connection.time', 
                         'duration', 'connection.duration',
                         'protocol', 'service', 'conn_state',
                         'connection.orig_p', 'o_port', 'orig_p_cat', 'connection.orig_bytes', 'o_bytes',
                         'connection.resp_p', 'r_port', 'resp_p_cat', 'connection.resp_bytes', 'r_bytes',
                         'attacker_label', 'attack_label']]

result = pd.concat([pca_X, labels_df], axis=1)
result
# Out:
#               0        1        2        3        4        5        6  \
# 0       1.50308 -0.33180  0.02402  0.34127  0.09629 -0.28843  0.28265
# 1       1.35421 -0.31438  0.02189  0.14599 -0.00594  0.02801 -0.13523
# 2      -0.15473  0.71181 -0.24798 -0.59579 -0.61676  1.03360  0.62284
# 3      -0.64287 -1.14888 -0.74269 -0.00669 -0.60354  0.34116 -0.72619
# 4      -1.77951 -0.57163 -0.11010  1.21133 -0.20527 -0.16871  0.01237
# ...         ...      ...      ...      ...      ...      ...      ...
# 472340 -0.10785  1.19700 -0.74652 -0.95247 -0.13114 -0.13982 -0.58200
# 472341 -0.52240  0.98313 -0.69674 -0.71296  0.40128 -0.33839 -0.26450
# 472342  1.88585 -0.42265 -0.08842  0.50287  0.32908 -0.24517  0.03448
# 472343  1.11069 -0.05196 -0.09073 -0.12350 -0.16091  0.59500 -0.50203
# 472344 -0.50180  1.24561  0.25217  0.39445 -0.60831  1.06712  0.67621
#
#               7        8        9       10       11       12       13  \
# ...

# %%
def print_df_func(df, col, func):
    if func == 'count':
        print(df[col].value_counts())
        print('')
    elif func == 'mean':
        col_mean = df[col].mean()
        print(str(col) + ' mean = ' + str(col_mean))
    elif func == 'median':
        col_median = df[col].median()
        print(str(col) + ' median = ' + str(col_median))
    elif func == 'min':
        col_min = df[col].min()
        print(str(col) + ' min = ' + str(col_min))
    elif func == 'max':
        col_max = df[col].max()
        print(str(col) + ' max = ' + str(col_max))
        print('')

# %%
for i in range(OPTIMAL_K + 1):
    result_cluster = result.loc[result['cluster'] == i]
    nok_conns = result_cluster.loc[result_cluster['attacker_label'] == 'Yes']
    not_sure_conns = nok_conns.loc[nok_conns['attack_label'] == 'Not_Specified']
    nok_conns = nok_conns.loc[nok_conns['attack_label'] != 'Not_Specified']
    ok_conns = result_cluster.loc[result_cluster['attacker_label'] == 'No']
      
    plt.scatter(
        ok_conns[0], ok_conns[1],
        s=50, c='green',
        marker='o', edgecolor='black',
        label='Other conns'
    )
    
    plt.scatter(
        not_sure_conns[0], not_sure_conns[1],
        s=50, c='orange',
        marker='o', edgecolor='black',
        label='Questinable conns'
    )
    
    plt.scatter(
        nok_conns[0], nok_conns[1],
        s=50, c='red',
        marker='o', edgecolor='black',
        label='Conns with attacker'
    )
    
    plt.legend(scatterpoints=1)
    plt.title('Cluster ' + str(i))
    plt.grid()
    plt.show()
    
    print('Total num of conns: ' + str(result_cluster.shape[0]) + '\n')
    
    
    print('Attacker conns ratio:')
    print_df_func(result_cluster, 'attacker_label', 'count')
    
    print('Attack conns ratio:')
    print_df_func(result_cluster, 'attack_label', 'count')
    
    print('IPs:')
    print_df_func(result_cluster, 'originated_ip', 'count')
    print_df_func(result_cluster, 'responded_ip', 'count')
    
    nok_conns = pd.concat([nok_conns, not_sure_conns])
    if len(nok_conns) > 0:
        print('Cluster ' + str(i) + ' NOK sample connections:')
        samples = nok_conns.sample(15 if len(nok_conns) >= 15 else len(nok_conns))
        samples = samples.filter(['uid', 'originated_ip', 'responded_ip', 
                             'timestamp', 'connection.time', 
                             'duration', 'connection.duration',
                             'protocol', 'service', 'conn_state',
                             'o_port', 'orig_p_cat', 'o_bytes',
                             'r_port', 'resp_p_cat', 'r_bytes',
                             'attacker_label', 'attack_label'], axis=1)
        display(samples)
    
    if len(ok_conns) > 0:
        print('Cluster ' + str(i) + ' OK sample connections:')
        samples = ok_conns.sample(15 if len(ok_conns) >= 15 else len(ok_conns))
        samples = samples.filter(['uid', 'originated_ip', 'responded_ip', 
                             'timestamp', 'connection.time', 
                             'duration', 'connection.duration',
                             'protocol', 'service', 'conn_state',
                             'o_port', 'orig_p_cat', 'o_bytes',
                             'r_port', 'resp_p_cat', 'r_bytes',
                             'attacker_label', 'attack_label'], axis=1)
        display(samples)
    
    print('  ================================================  \n')
# Out:
# Total num of conns: 41458
#
# Attacker conns ratio:
# No    41458
# Name: attacker_label, dtype: int64
#
# Attack conns ratio:
# Normal    41458
# Name: attack_label, dtype: int64
#
# IPs:
# 4.122.55.5        8301
# 9.66.22.13        7765
# 9.66.44.13        4635
# 9.66.55.13        4338
# 9.66.33.13        3460
#                   ...
# 9.66.22.14           6
# 10.1.4.47            3
# 10.5.5.2             1
# 147.251.48.140       1
# 185.210.219.98       1
# Name: originated_ip, Length: 76, dtype: int64
#
# 4.122.55.3        32556
# 9.66.22.12         1228
# 9.66.33.12         1042
# 9.66.11.12          981
# 9.66.55.12          862
# 9.66.66.12          859
# 9.66.44.12          856
# 9.66.22.13          792
# 9.66.33.13          412
# 9.66.11.13          379
# 9.66.44.13          366
# 9.66.55.13          364
# 9.66.66.13          363
# 9.66.33.14           50
# 9.66.55.14           48
# 172.217.23.206       45
# 9.66.44.14           42
# 9.66.11.14           40
# ...

# %% [markdown]
# ### Silhouette coefficient evaluation
#
# ```
# Silhouette Score = (average distance between points within a cluster - average distance between all clusters) /
#                    max(average distance between all clusters, average distance between points within a cluster)
#
# ```
#
# - intRA-cluster distance = average distance between each point within a cluster
# - intER-cluster distance = average distance between all clusters
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;SilhouetteScore(dataPoint) = \frac{b(dataPoint) - a(dataPoint)}{max\{a(dataPoint),b(dataPoint)\}}" />
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;a(dataPoint) = \frac{1}{|C_i| - 1} * \sum_{j from C_i, i != j} d({i,j)}" />
#
# <img src="https://latex.codecogs.com/svg.latex?\Large&space;b(dataPoint) = min_{k != i} \frac{1}{|C_k|} * \sum_{j from C_k} d({i,j)}" />

# %%
df.columns
# Out:
# Index(['connection.time', 'connection.duration', 'connection.orig_bytes',
#        'connection.orig_pkts', 'connection.resp_bytes', 'connection.resp_pkts',
#        'originated_ip_num', 'responded_ip_num', 'orig_p_cat', 'resp_p_cat',
#        ...
#        'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
#        'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count',
#        'resp_resp_resp_p_dyn_count', 'resp_resp_connection.protocol_mode',
#        'resp_resp_connection.service_mode',
#        'resp_resp_connection.conn_state_mode', 'cluster', 'cluster_cat'],
#       dtype='object', length=111)

# %%
len(df.columns)
# Out:
# 111

# %%
pd.set_option('display.max_columns', None)

# random labels for now:
import numpy as np

df['cluster'] = np.random.randint(0, 11, df.shape[0])

df_numerical = df[['connection.time', 'connection.duration', 'connection.orig_bytes',
       'connection.orig_pkts', 'connection.resp_bytes', 'connection.resp_pkts',
       'originated_ip_num', 'responded_ip_num', 
                   'orig_orig_total', 
                    'orig_orig_connection.time_mean', 
                    'orig_orig_connection.duration_mean',
                    'orig_orig_connection.orig_p_mean', 
                    'orig_orig_connection.orig_pkts_mean',
                    'orig_orig_connection.orig_bytes_mean',
                    'orig_orig_connection.resp_p_mean', 
                    'orig_orig_connection.resp_bytes_mean',
                    'orig_orig_connection.resp_pkts_mean',
                    'orig_orig_orig_p_well_known_count', 'orig_orig_orig_p_reg_or_dyn_count', 'orig_orig_resp_p_21_count', 'orig_orig_resp_p_22_count',
                    'orig_orig_resp_p_53_count', 'orig_orig_resp_p_80_count', 'orig_orig_resp_p_123_count', 'orig_orig_resp_p_443_count', 'orig_orig_resp_p_3389_count',
                    'orig_orig_resp_p_well_known_count', 'orig_orig_resp_p_reg_count', 'orig_orig_resp_p_dyn_count',
                   'orig_resp_total', 
                    'orig_resp_connection.time_mean', 
                    'orig_resp_connection.duration_mean',
                    'orig_resp_connection.orig_p_mean', 
                    'orig_resp_connection.orig_pkts_mean',
                    'orig_resp_connection.orig_bytes_mean',
                    'orig_resp_connection.resp_p_mean', 
                    'orig_resp_connection.resp_bytes_mean',
                    'orig_resp_connection.resp_pkts_mean',
                    'orig_resp_orig_p_well_known_count', 'orig_resp_orig_p_reg_or_dyn_count', 'orig_resp_resp_p_21_count', 'orig_resp_resp_p_22_count',
                    'orig_resp_resp_p_53_count', 'orig_resp_resp_p_80_count', 'orig_resp_resp_p_123_count', 'orig_resp_resp_p_443_count', 'orig_resp_resp_p_3389_count',
                    'orig_resp_resp_p_well_known_count', 'orig_resp_resp_p_reg_count', 'orig_resp_resp_p_dyn_count',
                   'resp_orig_total', 
                    'resp_orig_connection.time_mean', 
                    'resp_orig_connection.duration_mean',
                    'resp_orig_connection.orig_p_mean', 
                    'resp_orig_connection.orig_bytes_mean',
                    'resp_orig_connection.orig_pkts_mean',
                    'resp_orig_connection.resp_p_mean', 
                    'resp_orig_connection.resp_bytes_mean',
                    'resp_orig_connection.resp_pkts_mean',
                    'resp_orig_orig_p_well_known_count', 'resp_orig_orig_p_reg_or_dyn_count', 'resp_orig_resp_p_21_count', 'resp_orig_resp_p_22_count',
                    'resp_orig_resp_p_53_count', 'resp_orig_resp_p_80_count', 'resp_orig_resp_p_123_count', 'resp_orig_resp_p_443_count', 'resp_orig_resp_p_3389_count',
                    'resp_orig_resp_p_well_known_count', 'resp_orig_resp_p_reg_count', 'resp_orig_resp_p_dyn_count',
                   'resp_resp_total',
                    'resp_resp_connection.time_mean', 
                    'resp_resp_connection.duration_mean',
                    'resp_resp_connection.orig_p_mean', 
                    'resp_resp_connection.orig_bytes_mean',
                    'resp_resp_connection.orig_pkts_mean',
                    'resp_resp_connection.resp_p_mean', 
                    'resp_resp_connection.resp_bytes_mean',
                    'resp_resp_connection.resp_pkts_mean',
                    'resp_resp_orig_p_well_known_count', 'resp_resp_orig_p_reg_or_dyn_count', 'resp_resp_resp_p_21_count', 'resp_resp_resp_p_22_count',
                    'resp_resp_resp_p_53_count', 'resp_resp_resp_p_80_count', 'resp_resp_resp_p_123_count', 'resp_resp_resp_p_443_count', 'resp_resp_resp_p_3389_count',
                    'resp_resp_resp_p_well_known_count', 'resp_resp_resp_p_reg_count', 'resp_resp_resp_p_dyn_count',
        'cluster']]

df_categorical = df[['orig_p_cat', 'resp_p_cat',
       'protocol', 'service', 'conn_state', 
       'orig_orig_connection.protocol_mode', 'orig_orig_connection.service_mode', 'orig_orig_connection.conn_state_mode',
       'orig_resp_connection.protocol_mode', 'orig_resp_connection.service_mode', 'orig_resp_connection.conn_state_mode',
       'resp_orig_connection.protocol_mode', 'resp_orig_connection.service_mode', 'resp_orig_connection.conn_state_mode',
       'resp_resp_connection.protocol_mode', 'resp_resp_connection.service_mode', 'resp_resp_connection.conn_state_mode', 'cluster']]

# %%
df_numerical.head(5)
# Out:
#    connection.time  connection.duration  connection.orig_bytes  \
# 0          0.77482              0.00000                0.00000
# 1          0.77749              0.00000                0.00000
# 2          0.76999              0.00001                0.00000
# 3          0.90436              0.00000                0.00000
# 4          0.10761              0.00000                0.00000
#
#    connection.orig_pkts  connection.resp_bytes  connection.resp_pkts  \
# 0               0.00001                0.00000               0.00000
# 1               0.00001                0.00000               0.00000
# 2               0.00003                0.00000               0.00003
# 3               0.00001                0.00000               0.00000
# 4               0.00001                0.00000               0.00001
#
#    originated_ip_num  responded_ip_num  orig_orig_total  \
# 0            0.36686           0.03237          0.64585
# ...

# %%
df_categorical.head(5)
# Out:
#         orig_p_cat resp_p_cat protocol service conn_state  \
# 0  orig_reg_or_dyn   resp_dyn      tcp    none         S0
# 1  orig_reg_or_dyn   resp_reg      tcp    none         S0
# 2  orig_reg_or_dyn    resp_80      tcp    http       RSTO
# 3  orig_reg_or_dyn    resp_53      udp     dns         S0
# 4  orig_reg_or_dyn    resp_53      udp     dns         SF
#
#   orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# 0                                tcp                              none
# 1                                tcp                              none
# 2                                tcp                               ssl
# 3                                udp                               dns
# 4                                udp                               dns
#
#   orig_orig_connection.conn_state_mode orig_resp_connection.protocol_mode  \
# 0                                   S0                               icmp
# ...

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples
# from kmodes.kprototypes import KPrototypes
from kmodes.util.dissim import matching_dissim
from kmodes.util.dissim import euclidean_dissim
from kmodes.util import encode_features

# %%
dfs_list_num = []
dfs_list_cat = []

for i in range(OPTIMAL_K + 1):
    df_i_num = df_numerical.loc[df_numerical['cluster'] == i].sample(10)
    dfs_list_num.append(df_i_num)
    df_i_cat = df_categorical.loc[df_categorical['cluster'] == i].sample(10)
    dfs_list_cat.append(df_i_cat)

print(len(dfs_list_num))
print(type(dfs_list_num[0]))
# Out:
# 10
# <class 'pandas.core.frame.DataFrame'>

# %%
df_num = dfs_list_num[0]
df_cat = dfs_list_cat[0]

for i in range(1, len(dfs_list_num)): 
    df_num = df_num.append(dfs_list_num[i])
    df_cat = df_cat.append(dfs_list_cat[i])

# %%
df_cat
# Out:
#              orig_p_cat       resp_p_cat protocol service conn_state  \
# 66612   orig_well_known  resp_well_known     icmp    none        OTH
# 345878  orig_reg_or_dyn         resp_443      tcp     ssl         SF
# 106247  orig_reg_or_dyn         resp_reg      tcp    none         S0
# 220323  orig_reg_or_dyn  resp_well_known      tcp     ssl         SF
# 245280  orig_reg_or_dyn          resp_53      udp     dns         SF
# ...                 ...              ...      ...     ...        ...
# 353389  orig_reg_or_dyn          resp_53      udp     dns         SF
# 304580  orig_reg_or_dyn         resp_reg      tcp    none         S0
# 333185  orig_reg_or_dyn          resp_53      udp     dns         SF
# 91602   orig_reg_or_dyn         resp_443      tcp    none        REJ
# 194194  orig_reg_or_dyn         resp_443      tcp     ssl       RSTO
#
#        orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# ...

# %%
df_cat = df_cat.drop('cluster', 1)
df_cat
# Out:
#              orig_p_cat       resp_p_cat protocol service conn_state  \
# 66612   orig_well_known  resp_well_known     icmp    none        OTH
# 345878  orig_reg_or_dyn         resp_443      tcp     ssl         SF
# 106247  orig_reg_or_dyn         resp_reg      tcp    none         S0
# 220323  orig_reg_or_dyn  resp_well_known      tcp     ssl         SF
# 245280  orig_reg_or_dyn          resp_53      udp     dns         SF
# ...                 ...              ...      ...     ...        ...
# 353389  orig_reg_or_dyn          resp_53      udp     dns         SF
# 304580  orig_reg_or_dyn         resp_reg      tcp    none         S0
# 333185  orig_reg_or_dyn          resp_53      udp     dns         SF
# 91602   orig_reg_or_dyn         resp_443      tcp    none        REJ
# 194194  orig_reg_or_dyn         resp_443      tcp     ssl       RSTO
#
#        orig_orig_connection.protocol_mode orig_orig_connection.service_mode  \
# ...

# %%
df_cat_arr = np.asanyarray(df_cat)
df_cat_arr[0]
# Out:
# array(['orig_well_known', 'resp_well_known', 'icmp', 'none', 'OTH',
#        'icmp', 'none', 'OTH', 'icmp', 'none', 'OTH', 'udp', 'dns', 'SF',
#        'udp', 'dns', 'SF'], dtype=object)

# %%
df_cat_arr
# Out:
# array([['orig_well_known', 'resp_well_known', 'icmp', ..., 'udp', 'dns',
#         'SF'],
#        ['orig_reg_or_dyn', 'resp_443', 'tcp', ..., 'tcp', 'ssl', 'SF'],
#        ['orig_reg_or_dyn', 'resp_reg', 'tcp', ..., 'tcp', 'ssl', 'RSTR'],
#        ...,
#        ['orig_reg_or_dyn', 'resp_53', 'udp', ..., 'udp', 'dns', 'SF'],
#        ['orig_reg_or_dyn', 'resp_443', 'tcp', ..., 'tcp', 'ssl', 'SF'],
#        ['orig_reg_or_dyn', 'resp_443', 'tcp', ..., 'tcp', 'http', 'SF']],
#       dtype=object)

# %%
df_cat_encoded = encode_features(df_cat_arr)
df_cat_encoded
# Out:
# (array([[1, 7, 0, ..., 2, 0, 4],
#         [0, 2, 1, ..., 1, 4, 4],
#         [0, 6, 1, ..., 1, 4, 2],
#         ...,
#         [0, 3, 2, ..., 2, 0, 4],
#         [0, 2, 1, ..., 1, 4, 4],
#         [0, 2, 1, ..., 1, 1, 4]]),
#  [{'orig_reg_or_dyn': 0, 'orig_well_known': 1},
#   {'resp_123': 0,
#    'resp_22': 1,
#    'resp_443': 2,
#    'resp_53': 3,
#    'resp_80': 4,
#    'resp_dyn': 5,
#    'resp_reg': 6,
#    'resp_well_known': 7},
#   {'icmp': 0, 'tcp': 1, 'udp': 2},
#   {'dhcp': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssh': 5, 'ssl': 6},
#   {'OTH': 0, 'REJ': 1, 'RSTO': 2, 'RSTR': 3, 'S0': 4, 'SF': 5},
#   {'icmp': 0, 'tcp': 1, 'udp': 2},
#   {'dhcp': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssl': 5},
#   {'OTH': 0, 'RSTO': 1, 'RSTR': 2, 'S0': 3, 'SF': 4},
#   {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#   {'-': 0, 'dns': 1, 'none': 2},
#   {'-': 0, 'OTH': 1, 'RSTR': 2, 'S0': 3, 'S3': 4, 'SF': 5},
#   {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
# ...

# %%
print(len(df_cat_encoded[0]))
print(len(df_cat_encoded[0][0]))
# Out:
# 100
# 17

# %%
df_cat_encoded[0]
# Out:
# array([[1, 7, 0, ..., 2, 0, 4],
#        [0, 2, 1, ..., 1, 4, 4],
#        [0, 6, 1, ..., 1, 4, 2],
#        ...,
#        [0, 3, 2, ..., 2, 0, 4],
#        [0, 2, 1, ..., 1, 4, 4],
#        [0, 2, 1, ..., 1, 1, 4]])

# %%
df_cat_encoded[1]
# Out:
# [{'orig_reg_or_dyn': 0, 'orig_well_known': 1},
#  {'resp_123': 0,
#   'resp_22': 1,
#   'resp_443': 2,
#   'resp_53': 3,
#   'resp_80': 4,
#   'resp_dyn': 5,
#   'resp_reg': 6,
#   'resp_well_known': 7},
#  {'icmp': 0, 'tcp': 1, 'udp': 2},
#  {'dhcp': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssh': 5, 'ssl': 6},
#  {'OTH': 0, 'REJ': 1, 'RSTO': 2, 'RSTR': 3, 'S0': 4, 'SF': 5},
#  {'icmp': 0, 'tcp': 1, 'udp': 2},
#  {'dhcp': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssl': 5},
#  {'OTH': 0, 'RSTO': 1, 'RSTR': 2, 'S0': 3, 'SF': 4},
#  {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#  {'-': 0, 'dns': 1, 'none': 2},
#  {'-': 0, 'OTH': 1, 'RSTR': 2, 'S0': 3, 'S3': 4, 'SF': 5},
#  {'-': 0, 'icmp': 1, 'tcp': 2, 'udp': 3},
#  {'-': 0, 'dns': 1, 'http': 2, 'none': 3, 'ntp': 4, 'ssl': 5},
#  {'-': 0, 'OTH': 1, 'S0': 2, 'S3': 3, 'SF': 4},
#  {'icmp': 0, 'tcp': 1, 'udp': 2},
#  {'dns': 0, 'http': 1, 'none': 2, 'ntp': 3, 'ssl': 4},
#  {'OTH': 0, 'RSTO': 1, 'RSTR': 2, 'S0': 3, 'SF': 4}]

# %%
# np.sum([[0, 1], [0, 5]], axis=1)

# %%
# np.sum(df_cat_encoded[0], axis=1)

# %%
# matching_dissim(df_cat_encoded[0], df_num['cluster'].to_numpy())

# %%
def compute_custom_silhouette(df_numerical, df_categorical, cluster_col_name):
    # if string used as metric specifier, one from https://github.com/scikit-learn/scikit-learn/blob/main/sklearn/metrics/pairwise.py has to be used
    num_sim = silhouette_samples(X=df_numerical.to_numpy(), labels=df_numerical[cluster_col_name].to_numpy(), metric='euclidean')
    print(len(num_sim))
    print(num_sim)
    print(silhouette_score(X=df_numerical.to_numpy(), labels=df_numerical[cluster_col_name].to_numpy(), metric='euclidean'))
    
    cat_sim = np.sum(df_categorical, axis=1)
    print(len(cat_sim))
    print(cat_sim)
    
    #return num_sim
#     cat_sim = silhouette_samples(X=df_categorical, labels=df_numerical[cluster_col_name], metric=matching_dissim)
#     print(cat_sim)
    return num_sim, cat_sim

# %%
# sample_vals_num, sample_vals_cat = compute_custom_silhouette(df_num, df_cat_encoded[0], 'cluster')
sample_num_vals, sample_cat_vals = compute_custom_silhouette(df_num, df_cat_encoded[0], 'cluster')
# Out:
# 100
# [ 0.13922625  0.13818097  0.03778339 -0.04640829 -0.00981421 -0.00295172
#   0.03689863  0.02768638  0.10860786  0.08087744  0.19644391  0.17453687
#   0.21020042  0.14048925  0.17420259  0.0988959   0.16648601  0.12667965
#   0.10804605  0.11013887  0.16677533  0.0151076   0.09607388  0.07813722
#   0.06261123  0.01606573  0.1617754   0.09477248  0.06048562  0.02646845
#   0.03417912  0.14631526  0.02115433 -0.10825724  0.05103188  0.12153156
#  -0.12834845  0.13272987 -0.05260696  0.03592447  0.22271681  0.30515557
#   0.31931169  0.32549738  0.33872624  0.20839017  0.23250996  0.14965043
#   0.14520681  0.11880918  0.06332934 -0.09003554  0.05898147  0.03529119
#   0.04222058  0.01351598 -0.09074082  0.00543723  0.07147523  0.06335346
#   0.11811457  0.19352239  0.22283587  0.14638596  0.19564345  0.10653824
#   0.10681136  0.14487983  0.10306851  0.17511471 -0.11889455  0.11188746
#  -0.09336574  0.13702658  0.01865037  0.13447954  0.15023392  0.14431989
# ...

# %%
ultimate_gamma = kprototype.gamma
ultimate_gamma
# Out:
# 0.10987684341100562

# %%
combined_distance = []
for i in range(len(sample_num_vals)):
    combined_distance.append(sample_num_vals[i] + ultimate_gamma * sample_cat_vals[i])

# %%
# best is 1, worst is -1, 0 indicates overlapping clusters
sum(combined_distance) / len(combined_distance)
# Out:
# 3.6239615167805344

# %%
# # Computing Silhouette:
# from kmodes.util.dissim import euclidean_dissim


# def compute_avg_dist_within_cluster(example_num, example_cat, cluster_num, cluster_cat):
#     distance_num = 0
#     distance_cat = 0
    
#     for i in range(0, len(cluster_num)):
#         distance_num += euclidean_dissim(example_num, cluster_num)

        
# def compute_custom_silhouette(dfs_list_num, dfs_list_cat, cluster_col_name):
#     # 1. for each example: average distance to all examples in the same cluster:
    
#     distances = []
#     # for each cluster
#     for cl_i in range(0, len(dfs_list_num)):
#         # for each example in cluster
#         avg_dist = 0
#         for ex_i in range(0, len(dfs_list_num[cl_i])):
#             avg_dist_num, avg_dist_cat += compute_avg_dist_within_cluster(dfs_list_num[cl_i][ex_i], dfs_list_cat[cl_i][ex_i], dfs_list_num[cl_i], dfs_list_cat[cl_i])
#         print('Cluster ' + str(cl_i) + ': ')
#         print('Examples: ' + str(len(dfs_list_num[cl_i])))
#         print('All distances within cluster:' + str(avg_dist_num) + ', ' + str(avg_dist_cat))
#         avg_dist_num = 1 / len(dfs_list_num[cl_i]) * avg_dist_num
#         avg_dist_cat = 1 / len(dfs_list_num[cl_i]) * avg_dist_cat
#         print('Avg distance within cluster:' + str(avg_dist_num) + ', ' + str(avg_dist_cat))
#         distances.append((avg_dist_num, avg_dist_cat))
